# %%
import qancode

# %%
qa = qancode.QANCODE(rc_url="https://v64rc3-master.demo.encodedcc.org/")

# %%
#search terms
qa.check_response_time(item_types=["/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=DNA+binding
# --------- https://www.encodeproject.org/search/?searchTerm=DNA+binding ---------
# Average es_time: 453.056 ± 58.921 ms (n=100)
# Average queue_time: 0.956 ± 0.353 ms (n=100)
# Average render_time: 27.225 ± 6.471 ms (n=100)
# Average wsgi_time: 500.836 ± 59.113 ms (n=100)
# Average total time: 982.073 ± 118.427 ms (n=100)
# --------- https://v64rc3-master.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 273.383 ± 76.592 ms (n=100)
# Average queue_time: 58.365 ± 171.015 ms (n=100)
# Average render_time: 33.815 ± 39.761 ms (n=100)
# Average wsgi_time: 329.219 ± 84.729 ms (n=100)
# Average total time: 694.782 ± 251.41 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=human
# ------------ https://www.encodeproject.org/search/?searchTerm=human ------------
# Average es_time: 292.854 ± 34.983 ms (n=100)
# Average queue_time: 0.967 ± 0.455 ms (n=100)
# Average render_time: 30.27 ± 6.317 ms (n=100)
# Average wsgi_time: 338.867 ± 34.554 ms (n=100)
# Average total time: 662.958 ± 69.41 ms (n=100)
# ------ https://v64rc3-master.demo.encodedcc.org//search/?searchTerm=human ------
# Average es_time: 342.87 ± 167.939 ms (n=100)
# Average queue_time: 84.833 ± 270.846 ms (n=100)
# Average render_time: 41.395 ± 8.827 ms (n=100)
# Average wsgi_time: 410.977 ± 167.069 ms (n=100)
# Average total time: 880.075 ± 457.08 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# ---------- https://www.encodeproject.org/search/?searchTerm=H3K36me3 -----------
# Average es_time: 525.964 ± 36.849 ms (n=100)
# Average queue_time: 0.935 ± 0.418 ms (n=100)
# Average render_time: 126.742 ± 13.336 ms (n=100)
# Average wsgi_time: 725.799 ± 38.966 ms (n=100)
# Average total time: 1379.44 ± 76.974 ms (n=100)
# ---- https://v64rc3-master.demo.encodedcc.org//search/?searchTerm=H3K36me3 -----
# Average es_time: 191.525 ± 88.247 ms (n=100)
# Average queue_time: 47.089 ± 161.415 ms (n=100)
# Average render_time: 31.951 ± 41.64 ms (n=100)
# Average wsgi_time: 239.808 ± 95.907 ms (n=100)
# Average total time: 510.373 ± 311.034 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=CTCF
# ------------ https://www.encodeproject.org/search/?searchTerm=CTCF -------------
# Average es_time: 313.838 ± 32.937 ms (n=100)
# Average queue_time: 0.946 ± 0.462 ms (n=100)
# Average render_time: 33.407 ± 7.341 ms (n=100)
# Average wsgi_time: 367.128 ± 33.064 ms (n=100)
# Average total time: 715.32 ± 66.138 ms (n=100)
# ------ https://v64rc3-master.demo.encodedcc.org//search/?searchTerm=CTCF -------
# Average es_time: 193.603 ± 83.976 ms (n=100)
# Average queue_time: 35.911 ± 168.237 ms (n=100)
# Average render_time: 31.655 ± 6.433 ms (n=100)
# Average wsgi_time: 245.15 ± 84.186 ms (n=100)
# Average total time: 506.32 ± 289.078 ms (n=100)

# %%
#first set of datasets
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/', '/ENCSR344YUA/', '/ENCSR315NAC/', '/ENCSR856JJB/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------------ https://www.encodeproject.org/ENCSR255XZG/ ------------------
# Average es_time: 17.498 ± 6.715 ms (n=100)
# Average queue_time: 0.868 ± 0.176 ms (n=100)
# Average render_time: 132.808 ± 13.263 ms (n=100)
# Average wsgi_time: 296.163 ± 207.527 ms (n=100)
# Average total time: 447.337 ± 209.363 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR255XZG/ ------------
# Average es_time: 48.394 ± 46.032 ms (n=100)
# Average queue_time: 46.43 ± 158.562 ms (n=100)
# Average render_time: 127.959 ± 14.649 ms (n=100)
# Average wsgi_time: 286.994 ± 90.751 ms (n=100)
# Average total time: 509.777 ± 243.756 ms (n=100)
#
#
# *** item_type: /ENCSR749ILN/
# ------------------ https://www.encodeproject.org/ENCSR749ILN/ ------------------
# Average es_time: 9.089 ± 3.706 ms (n=100)
# Average queue_time: 0.946 ± 0.542 ms (n=100)
# Average render_time: 35.174 ± 8.001 ms (n=100)
# Average wsgi_time: 69.061 ± 8.763 ms (n=100)
# Average total time: 114.27 ± 17.291 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR749ILN/ ------------
# Average es_time: 50.989 ± 51.199 ms (n=100)
# Average queue_time: 48.325 ± 102.228 ms (n=100)
# Average render_time: 28.713 ± 5.665 ms (n=100)
# Average wsgi_time: 105.575 ± 52.647 ms (n=100)
# Average total time: 233.601 ± 171.411 ms (n=100)
#
#
# *** item_type: /ENCSR688GVV/
# ------------------ https://www.encodeproject.org/ENCSR688GVV/ ------------------
# Average es_time: 11.913 ± 3.576 ms (n=100)
# Average queue_time: 9.771 ± 69.249 ms (n=100)
# Average render_time: 62.83 ± 9.958 ms (n=100)
# Average wsgi_time: 121.47 ± 11.43 ms (n=100)
# Average total time: 205.984 ± 69.225 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR688GVV/ ------------
# Average es_time: 57.245 ± 58.304 ms (n=100)
# Average queue_time: 23.926 ± 144.716 ms (n=100)
# Average render_time: 61.945 ± 9.898 ms (n=100)
# Average wsgi_time: 173.688 ± 58.576 ms (n=100)
# Average total time: 316.803 ± 235.886 ms (n=100)
#
#
# *** item_type: /ENCSR301HAG/
# ------------------ https://www.encodeproject.org/ENCSR301HAG/ ------------------
# Average es_time: 8.744 ± 3.324 ms (n=100)
# Average queue_time: 0.891 ± 0.327 ms (n=100)
# Average render_time: 13.755 ± 3.285 ms (n=100)
# Average wsgi_time: 35.823 ± 5.898 ms (n=100)
# Average total time: 59.213 ± 10.293 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR301HAG/ ------------
# Average es_time: 32.829 ± 21.102 ms (n=100)
# Average queue_time: 1.333 ± 1.106 ms (n=100)
# Average render_time: 14.575 ± 4.526 ms (n=100)
# Average wsgi_time: 60.125 ± 22.022 ms (n=100)
# Average total time: 108.863 ± 43.441 ms (n=100)
#
#
# *** item_type: /ENCSR344YUA/
# ------------------ https://www.encodeproject.org/ENCSR344YUA/ ------------------
# Average es_time: 8.481 ± 4.131 ms (n=100)
# Average queue_time: 0.873 ± 0.348 ms (n=100)
# Average render_time: 22.178 ± 5.583 ms (n=100)
# Average wsgi_time: 47.171 ± 7.354 ms (n=100)
# Average total time: 78.702 ± 14.15 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR344YUA/ ------------
# Average es_time: 42.557 ± 47.155 ms (n=100)
# Average queue_time: 36.889 ± 160.453 ms (n=100)
# Average render_time: 20.477 ± 5.639 ms (n=100)
# Average wsgi_time: 79.624 ± 48.524 ms (n=100)
# Average total time: 179.546 ± 242.503 ms (n=100)
#
#
# *** item_type: /ENCSR315NAC/
# ------------------ https://www.encodeproject.org/ENCSR315NAC/ ------------------
# Average es_time: 10.208 ± 2.964 ms (n=100)
# Average queue_time: 0.991 ± 0.535 ms (n=100)
# Average render_time: 55.065 ± 9.233 ms (n=100)
# Average wsgi_time: 113.557 ± 92.046 ms (n=100)
# Average total time: 179.82 ± 92.826 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR315NAC/ ------------
# Average es_time: 60.684 ± 55.575 ms (n=100)
# Average queue_time: 71.762 ± 198.551 ms (n=100)
# Average render_time: 50.865 ± 10.156 ms (n=100)
# Average wsgi_time: 156.464 ± 59.173 ms (n=100)
# Average total time: 339.775 ± 282.37 ms (n=100)
#
#
# *** item_type: /ENCSR856JJB/
# ------------------ https://www.encodeproject.org/ENCSR856JJB/ ------------------
# Average es_time: 11.777 ± 9.014 ms (n=100)
# Average queue_time: 0.899 ± 0.295 ms (n=100)
# Average render_time: 46.275 ± 8.522 ms (n=100)
# Average wsgi_time: 93.567 ± 13.497 ms (n=100)
# Average total time: 152.519 ± 25.492 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR856JJB/ ------------
# Average es_time: 52.452 ± 42.692 ms (n=100)
# Average queue_time: 52.925 ± 166.606 ms (n=100)
# Average render_time: 41.596 ± 7.476 ms (n=100)
# Average wsgi_time: 133.067 ± 44.311 ms (n=100)
# Average total time: 280.04 ± 224.933 ms (n=100)

# %%
#second set of datasets
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------------ https://www.encodeproject.org/ENCSR480OHP/ ------------------
# Average es_time: 8.897 ± 1.949 ms (n=100)
# Average queue_time: 0.994 ± 0.512 ms (n=100)
# Average render_time: 33.13 ± 6.242 ms (n=100)
# Average wsgi_time: 74.774 ± 65.466 ms (n=100)
# Average total time: 117.795 ± 65.513 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR480OHP/ ------------
# Average es_time: 52.697 ± 66.697 ms (n=100)
# Average queue_time: 36.184 ± 102.093 ms (n=100)
# Average render_time: 32.513 ± 6.783 ms (n=100)
# Average wsgi_time: 113.569 ± 69.305 ms (n=100)
# Average total time: 234.962 ± 184.784 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ------------------ https://www.encodeproject.org/ENCSR000EMB/ ------------------
# Average es_time: 9.476 ± 2.531 ms (n=100)
# Average queue_time: 0.879 ± 0.174 ms (n=100)
# Average render_time: 49.556 ± 9.138 ms (n=100)
# Average wsgi_time: 103.308 ± 86.9 ms (n=100)
# Average total time: 163.219 ± 90.843 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR000EMB/ ------------
# Average es_time: 61.742 ± 154.292 ms (n=100)
# Average queue_time: 72.092 ± 238.963 ms (n=100)
# Average render_time: 47.364 ± 9.277 ms (n=100)
# Average wsgi_time: 147.692 ± 155.005 ms (n=100)
# Average total time: 328.889 ± 442.917 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------ https://www.encodeproject.org/ENCSR323QIP/ ------------------
# Average es_time: 20.106 ± 5.625 ms (n=100)
# Average queue_time: 1.882 ± 9.347 ms (n=100)
# Average render_time: 151.105 ± 10.259 ms (n=100)
# Average wsgi_time: 317.474 ± 127.218 ms (n=100)
# Average total time: 490.567 ± 129.555 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR323QIP/ ------------
# Average es_time: 74.087 ± 96.618 ms (n=100)
# Average queue_time: 87.481 ± 256.194 ms (n=100)
# Average render_time: 155.769 ± 18.12 ms (n=100)
# Average wsgi_time: 398.297 ± 188.508 ms (n=100)
# Average total time: 715.635 ± 456.485 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------------ https://www.encodeproject.org/ENCSR718AXQ/ ------------------
# Average es_time: 7.928 ± 2.811 ms (n=100)
# Average queue_time: 0.926 ± 0.52 ms (n=100)
# Average render_time: 23.744 ± 5.032 ms (n=100)
# Average wsgi_time: 49.832 ± 7.895 ms (n=100)
# Average total time: 82.43 ± 14.046 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR718AXQ/ ------------
# Average es_time: 58.517 ± 76.691 ms (n=100)
# Average queue_time: 11.128 ± 32.747 ms (n=100)
# Average render_time: 19.573 ± 5.373 ms (n=100)
# Average wsgi_time: 96.394 ± 78.658 ms (n=100)
# Average total time: 185.612 ± 159.63 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------------ https://www.encodeproject.org/ENCSR165BGV/ ------------------
# Average es_time: 8.949 ± 3.788 ms (n=100)
# Average queue_time: 0.912 ± 0.506 ms (n=100)
# Average render_time: 26.373 ± 6.056 ms (n=100)
# Average wsgi_time: 55.035 ± 7.209 ms (n=100)
# Average total time: 91.268 ± 14.082 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR165BGV/ ------------
# Average es_time: 31.241 ± 21.092 ms (n=100)
# Average queue_time: 11.952 ± 93.123 ms (n=100)
# Average render_time: 24.447 ± 6.659 ms (n=100)
# Average wsgi_time: 82.936 ± 86.796 ms (n=100)
# Average total time: 150.576 ± 149.352 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------------ https://www.encodeproject.org/ENCSR384KAN/ ------------------
# Average es_time: 10.306 ± 5.1 ms (n=100)
# Average queue_time: 0.898 ± 0.224 ms (n=100)
# Average render_time: 44.249 ± 7.088 ms (n=100)
# Average wsgi_time: 88.706 ± 9.286 ms (n=100)
# Average total time: 144.16 ± 16.534 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR384KAN/ ------------
# Average es_time: 58.929 ± 60.964 ms (n=100)
# Average queue_time: 59.454 ± 197.286 ms (n=100)
# Average render_time: 41.686 ± 7.483 ms (n=100)
# Average wsgi_time: 145.336 ± 83.912 ms (n=100)
# Average total time: 305.406 ± 291.888 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------------ https://www.encodeproject.org/ENCSR330FXL/ ------------------
# Average es_time: 9.04 ± 4.283 ms (n=100)
# Average queue_time: 0.989 ± 0.553 ms (n=100)
# Average render_time: 31.762 ± 5.667 ms (n=100)
# Average wsgi_time: 64.533 ± 8.166 ms (n=100)
# Average total time: 106.324 ± 14.817 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR330FXL/ ------------
# Average es_time: 47.834 ± 61.813 ms (n=100)
# Average queue_time: 41.749 ± 151.396 ms (n=100)
# Average render_time: 26.846 ± 5.863 ms (n=100)
# Average wsgi_time: 98.149 ± 62.149 ms (n=100)
# Average total time: 214.579 ± 244.218 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------------ https://www.encodeproject.org/ENCSR825UNV/ ------------------
# Average es_time: 22.674 ± 5.927 ms (n=100)
# Average queue_time: 0.887 ± 0.15 ms (n=100)
# Average render_time: 180.458 ± 10.42 ms (n=100)
# Average wsgi_time: 416.173 ± 211.861 ms (n=100)
# Average total time: 620.192 ± 212.012 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR825UNV/ ------------
# Average es_time: 71.98 ± 72.175 ms (n=100)
# Average queue_time: 95.836 ± 240.476 ms (n=100)
# Average render_time: 182.533 ± 21.547 ms (n=100)
# Average wsgi_time: 465.925 ± 216.885 ms (n=100)
# Average total time: 816.274 ± 385.308 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------ https://www.encodeproject.org/ENCSR089EOA/ ------------------
# Average es_time: 13.907 ± 4.212 ms (n=100)
# Average queue_time: 1.156 ± 1.478 ms (n=100)
# Average render_time: 11.298 ± 3.345 ms (n=100)
# Average wsgi_time: 42.953 ± 6.023 ms (n=100)
# Average total time: 69.314 ± 10.882 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCSR089EOA/ ------------
# Average es_time: 48.02 ± 27.971 ms (n=100)
# Average queue_time: 10.076 ± 31.273 ms (n=100)
# Average render_time: 10.2 ± 3.509 ms (n=100)
# Average wsgi_time: 76.314 ± 28.4 ms (n=100)
# Average total time: 144.61 ± 69.592 ms (n=100)

# %%
#antibodies
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ------------------ https://www.encodeproject.org/ENCAB830JLB/ ------------------
# Average es_time: 8.564 ± 3.881 ms (n=100)
# Average queue_time: 0.955 ± 0.463 ms (n=100)
# Average render_time: 26.449 ± 6.011 ms (n=100)
# Average wsgi_time: 52.397 ± 7.485 ms (n=100)
# Average total time: 88.366 ± 14.464 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB830JLB/ ------------
# Average es_time: 34.584 ± 37.581 ms (n=100)
# Average queue_time: 22.389 ± 151.399 ms (n=100)
# Average render_time: 25.752 ± 7.977 ms (n=100)
# Average wsgi_time: 77.153 ± 37.697 ms (n=100)
# Average total time: 159.879 ± 215.249 ms (n=100)
#
#
# *** item_type: /ENCAB000BKR/
# ------------------ https://www.encodeproject.org/ENCAB000BKR/ ------------------
# Average es_time: 8.388 ± 4.24 ms (n=100)
# Average queue_time: 0.921 ± 0.492 ms (n=100)
# Average render_time: 15.707 ± 3.486 ms (n=100)
# Average wsgi_time: 33.704 ± 6.087 ms (n=100)
# Average total time: 58.721 ± 11.847 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB000BKR/ ------------
# Average es_time: 37.121 ± 31.002 ms (n=100)
# Average queue_time: 17.389 ± 61.862 ms (n=100)
# Average render_time: 13.386 ± 3.56 ms (n=100)
# Average wsgi_time: 59.405 ± 31.847 ms (n=100)
# Average total time: 127.302 ± 109.443 ms (n=100)
#
#
# *** item_type: /ENCAB284TTY/
# ------------------ https://www.encodeproject.org/ENCAB284TTY/ ------------------
# Average es_time: 7.556 ± 3.274 ms (n=100)
# Average queue_time: 0.937 ± 0.735 ms (n=100)
# Average render_time: 19.894 ± 4.221 ms (n=100)
# Average wsgi_time: 41.491 ± 6.648 ms (n=100)
# Average total time: 69.878 ± 11.853 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB284TTY/ ------------
# Average es_time: 43.574 ± 42.301 ms (n=100)
# Average queue_time: 66.098 ± 226.093 ms (n=100)
# Average render_time: 18.318 ± 4.75 ms (n=100)
# Average wsgi_time: 74.666 ± 43.082 ms (n=100)
# Average total time: 202.657 ± 294.022 ms (n=100)
#
#
# *** item_type: /ENCAB294YUD/
# ------------------ https://www.encodeproject.org/ENCAB294YUD/ ------------------
# Average es_time: 7.377 ± 2.029 ms (n=100)
# Average queue_time: 0.921 ± 0.364 ms (n=100)
# Average render_time: 10.563 ± 2.784 ms (n=100)
# Average wsgi_time: 25.411 ± 3.737 ms (n=100)
# Average total time: 44.272 ± 7.063 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB294YUD/ ------------
# Average es_time: 32.794 ± 23.195 ms (n=100)
# Average queue_time: 50.701 ± 124.812 ms (n=100)
# Average render_time: 7.895 ± 2.908 ms (n=100)
# Average wsgi_time: 47.432 ± 24.028 ms (n=100)
# Average total time: 138.821 ± 142.8 ms (n=100)
#
#
# *** item_type: /ENCAB000AOC/
# ------------------ https://www.encodeproject.org/ENCAB000AOC/ ------------------
# Average es_time: 7.987 ± 3.041 ms (n=100)
# Average queue_time: 0.972 ± 0.479 ms (n=100)
# Average render_time: 25.172 ± 5.761 ms (n=100)
# Average wsgi_time: 47.719 ± 7.341 ms (n=100)
# Average total time: 81.85 ± 14.098 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB000AOC/ ------------
# Average es_time: 45.086 ± 54.839 ms (n=100)
# Average queue_time: 51.475 ± 125.87 ms (n=100)
# Average render_time: 21.064 ± 4.512 ms (n=100)
# Average wsgi_time: 79.72 ± 54.048 ms (n=100)
# Average total time: 197.345 ± 199.419 ms (n=100)
#
#
# *** item_type: /ENCAB301QZF/
# ------------------ https://www.encodeproject.org/ENCAB301QZF/ ------------------
# Average es_time: 9.665 ± 7.752 ms (n=100)
# Average queue_time: 1.488 ± 3.935 ms (n=100)
# Average render_time: 17.724 ± 3.818 ms (n=100)
# Average wsgi_time: 42.171 ± 49.126 ms (n=100)
# Average total time: 71.047 ± 52.071 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB301QZF/ ------------
# Average es_time: 46.989 ± 46.568 ms (n=100)
# Average queue_time: 35.931 ± 107.968 ms (n=100)
# Average render_time: 14.983 ± 4.052 ms (n=100)
# Average wsgi_time: 71.375 ± 46.874 ms (n=100)
# Average total time: 169.279 ± 183.653 ms (n=100)
#
#
# *** item_type: /ENCAB000ANM/
# ------------------ https://www.encodeproject.org/ENCAB000ANM/ ------------------
# Average es_time: 7.521 ± 2.966 ms (n=100)
# Average queue_time: 0.892 ± 0.171 ms (n=100)
# Average render_time: 20.935 ± 5.338 ms (n=100)
# Average wsgi_time: 40.087 ± 7.06 ms (n=100)
# Average total time: 69.436 ± 13.09 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB000ANM/ ------------
# Average es_time: 36.861 ± 24.262 ms (n=100)
# Average queue_time: 1.448 ± 1.968 ms (n=100)
# Average render_time: 21.221 ± 6.029 ms (n=100)
# Average wsgi_time: 70.519 ± 24.941 ms (n=100)
# Average total time: 130.049 ± 49.454 ms (n=100)
#
#
# *** item_type: /ENCAB000ANU/
# ------------------ https://www.encodeproject.org/ENCAB000ANU/ ------------------
# Average es_time: 8.724 ± 6.082 ms (n=100)
# Average queue_time: 0.99 ± 0.603 ms (n=100)
# Average render_time: 18.275 ± 4.452 ms (n=100)
# Average wsgi_time: 36.853 ± 7.252 ms (n=100)
# Average total time: 64.842 ± 14.386 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB000ANU/ ------------
# Average es_time: 54.536 ± 63.176 ms (n=100)
# Average queue_time: 121.509 ± 364.189 ms (n=100)
# Average render_time: 14.872 ± 3.953 ms (n=100)
# Average wsgi_time: 78.092 ± 63.894 ms (n=100)
# Average total time: 269.009 ± 461.325 ms (n=100)
#
#
# *** item_type: /ENCAB445KMF/
# ------------------ https://www.encodeproject.org/ENCAB445KMF/ ------------------
# Average es_time: 8.103 ± 3.869 ms (n=100)
# Average queue_time: 1.147 ± 1.542 ms (n=100)
# Average render_time: 22.932 ± 36.042 ms (n=100)
# Average wsgi_time: 42.686 ± 36.665 ms (n=100)
# Average total time: 74.868 ± 73.145 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB445KMF/ ------------
# Average es_time: 50.987 ± 53.718 ms (n=100)
# Average queue_time: 53.729 ± 159.668 ms (n=100)
# Average render_time: 19.41 ± 44.525 ms (n=100)
# Average wsgi_time: 80.982 ± 70.303 ms (n=100)
# Average total time: 205.108 ± 249.137 ms (n=100)
#
#
# *** item_type: /ENCAB000BAY/
# ------------------ https://www.encodeproject.org/ENCAB000BAY/ ------------------
# Average es_time: 8.879 ± 4.855 ms (n=100)
# Average queue_time: 0.862 ± 0.106 ms (n=100)
# Average render_time: 25.23 ± 5.418 ms (n=100)
# Average wsgi_time: 48.28 ± 8.197 ms (n=100)
# Average total time: 83.252 ± 15.547 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCAB000BAY/ ------------
# Average es_time: 52.21 ± 69.032 ms (n=100)
# Average queue_time: 43.432 ± 122.935 ms (n=100)
# Average render_time: 20.859 ± 3.77 ms (n=100)
# Average wsgi_time: 86.749 ± 69.184 ms (n=100)
# Average total time: 203.249 ± 225.815 ms (n=100)

# %%
#biosamples
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS841PRW/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/','/ENCBS836RGY/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS787TFV/
# ------------------ https://www.encodeproject.org/ENCBS787TFV/ ------------------
# Average es_time: 7.22 ± 1.614 ms (n=100)
# Average queue_time: 1.105 ± 0.645 ms (n=100)
# Average render_time: 12.972 ± 3.994 ms (n=100)
# Average wsgi_time: 29.735 ± 5.321 ms (n=100)
# Average total time: 51.033 ± 9.744 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS787TFV/ ------------
# Average es_time: 49.901 ± 99.818 ms (n=100)
# Average queue_time: 36.033 ± 164.981 ms (n=100)
# Average render_time: 9.921 ± 4.463 ms (n=100)
# Average wsgi_time: 67.986 ± 100.731 ms (n=100)
# Average total time: 163.842 ± 316.69 ms (n=100)
#
#
# *** item_type: /ENCBS676QAV/
# ------------------ https://www.encodeproject.org/ENCBS676QAV/ ------------------
# Average es_time: 9.663 ± 10.45 ms (n=100)
# Average queue_time: 1.158 ± 1.245 ms (n=100)
# Average render_time: 13.613 ± 4.795 ms (n=100)
# Average wsgi_time: 31.501 ± 11.545 ms (n=100)
# Average total time: 55.934 ± 22.997 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS676QAV/ ------------
# Average es_time: 66.79 ± 99.253 ms (n=100)
# Average queue_time: 114.807 ± 320.881 ms (n=100)
# Average render_time: 9.867 ± 3.17 ms (n=100)
# Average wsgi_time: 83.932 ± 99.646 ms (n=100)
# Average total time: 275.395 ± 481.953 ms (n=100)
#
#
# *** item_type: /ENCBS841PRW/
# ------------------ https://www.encodeproject.org/ENCBS841PRW/ ------------------
# Average es_time: 11.902 ± 8.67 ms (n=100)
# Average queue_time: 1.088 ± 0.609 ms (n=100)
# Average render_time: 13.363 ± 3.462 ms (n=100)
# Average wsgi_time: 34.173 ± 9.825 ms (n=100)
# Average total time: 60.525 ± 18.947 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS841PRW/ ------------
# Average es_time: 77.601 ± 119.578 ms (n=100)
# Average queue_time: 98.025 ± 324.39 ms (n=100)
# Average render_time: 11.078 ± 3.354 ms (n=100)
# Average wsgi_time: 96.592 ± 119.667 ms (n=100)
# Average total time: 283.297 ± 531.335 ms (n=100)
#
#
# *** item_type: /ENCBS996IWU/
# ------------------ https://www.encodeproject.org/ENCBS996IWU/ ------------------
# Average es_time: 7.17 ± 2.392 ms (n=100)
# Average queue_time: 1.072 ± 0.797 ms (n=100)
# Average render_time: 15.895 ± 4.864 ms (n=100)
# Average wsgi_time: 32.027 ± 6.453 ms (n=100)
# Average total time: 56.163 ± 12.077 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS996IWU/ ------------
# Average es_time: 53.093 ± 84.361 ms (n=100)
# Average queue_time: 137.449 ± 707.012 ms (n=100)
# Average render_time: 10.099 ± 2.988 ms (n=100)
# Average wsgi_time: 70.681 ± 85.192 ms (n=100)
# Average total time: 271.322 ± 784.721 ms (n=100)
#
#
# *** item_type: /ENCBS913XJP/
# ------------------ https://www.encodeproject.org/ENCBS913XJP/ ------------------
# Average es_time: 7.99 ± 3.577 ms (n=100)
# Average queue_time: 1.246 ± 1.016 ms (n=100)
# Average render_time: 13.168 ± 4.195 ms (n=100)
# Average wsgi_time: 30.351 ± 5.841 ms (n=100)
# Average total time: 52.756 ± 11.232 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS913XJP/ ------------
# Average es_time: 44.354 ± 64.854 ms (n=100)
# Average queue_time: 37.092 ± 203.388 ms (n=100)
# Average render_time: 11.331 ± 3.148 ms (n=100)
# Average wsgi_time: 64.836 ± 65.067 ms (n=100)
# Average total time: 157.614 ± 284.456 ms (n=100)
#
#
# *** item_type: /ENCBS565NTN/
# ------------------ https://www.encodeproject.org/ENCBS565NTN/ ------------------
# Average es_time: 7.693 ± 1.441 ms (n=100)
# Average queue_time: 1.177 ± 0.78 ms (n=100)
# Average render_time: 12.868 ± 3.633 ms (n=100)
# Average wsgi_time: 30.014 ± 4.714 ms (n=100)
# Average total time: 51.752 ± 8.455 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS565NTN/ ------------
# Average es_time: 55.997 ± 78.525 ms (n=100)
# Average queue_time: 75.565 ± 245.393 ms (n=100)
# Average render_time: 11.027 ± 2.755 ms (n=100)
# Average wsgi_time: 75.277 ± 79.151 ms (n=100)
# Average total time: 217.867 ± 352.621 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ------------------ https://www.encodeproject.org/ENCBS896YZO/ ------------------
# Average es_time: 8.152 ± 2.276 ms (n=100)
# Average queue_time: 1.19 ± 0.772 ms (n=100)
# Average render_time: 19.54 ± 4.741 ms (n=100)
# Average wsgi_time: 39.294 ± 6.268 ms (n=100)
# Average total time: 68.176 ± 11.43 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS896YZO/ ------------
# Average es_time: 57.972 ± 79.727 ms (n=100)
# Average queue_time: 84.392 ± 252.976 ms (n=100)
# Average render_time: 17.326 ± 4.344 ms (n=100)
# Average wsgi_time: 85.345 ± 79.671 ms (n=100)
# Average total time: 245.036 ± 379.322 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ------------------ https://www.encodeproject.org/ENCBS280NYD/ ------------------
# Average es_time: 7.118 ± 1.453 ms (n=100)
# Average queue_time: 1.254 ± 0.889 ms (n=100)
# Average render_time: 12.171 ± 3.319 ms (n=100)
# Average wsgi_time: 29.152 ± 4.832 ms (n=100)
# Average total time: 49.695 ± 8.633 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS280NYD/ ------------
# Average es_time: 45.062 ± 90.27 ms (n=100)
# Average queue_time: 62.305 ± 234.295 ms (n=100)
# Average render_time: 9.046 ± 2.958 ms (n=100)
# Average wsgi_time: 61.925 ± 90.988 ms (n=100)
# Average total time: 178.337 ± 345.197 ms (n=100)
#
#
# *** item_type: /ENCBS836RGY/
# ------------------ https://www.encodeproject.org/ENCBS836RGY/ ------------------
# Average es_time: 7.612 ± 2.836 ms (n=100)
# Average queue_time: 1.179 ± 0.758 ms (n=100)
# Average render_time: 13.975 ± 3.075 ms (n=100)
# Average wsgi_time: 30.976 ± 4.958 ms (n=100)
# Average total time: 53.741 ± 8.88 ms (n=100)
# ------------ https://v64rc3-master.demo.encodedcc.org//ENCBS836RGY/ ------------
# Average es_time: 31.387 ± 36.355 ms (n=100)
# Average queue_time: 16.085 ± 52.032 ms (n=100)
# Average render_time: 10.723 ± 2.552 ms (n=100)
# Average wsgi_time: 49.802 ± 36.963 ms (n=100)
# Average total time: 107.996 ± 86.699 ms (n=100)

# %%
#qa.compare_facets(users=['Public'], browsers=['Chrome'], item_types=['/search/?type=Experiment'], browser_comparison=False)

# %%
#.find_differences(users=['encoded.test4@gmail.com'], browsers=['Safari'])

# %%
#qa.find_differences(users=['encoded.test4@gmail.com'], browsers=['Chrome'], item_types=['/experiments/ENCSR524OCB/'])

# %%
#qa.show_differences()

# %%
#qa.check_downloads(browsers=['Safari'], users=['Public'])

# %%
#qa.check_trackhubs(browsers=['Safari'], users=['Public'])

# %%
#qa.check_permissions(browsers=['Chrome'], users=['Public'])

# %%
#qa.check_permissions(browsers=['Chrome'], users=['encoded.test@gmail.com'])

# %%
#qa.check_permissions(browsers=['Chrome'], users=['encoded.test2@gmail.com'])

# %%
qa.check_permissions(browsers=['Chrome'], users=['encoded.test4@gmail.com'])
# Out:
# Running check permissions
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /experiments/ENCSR524OCB/
# Loading complete
# Taking picture of https://www.encodeproject.org/experiments/ENCSR524OCB/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod71836285591631832109397899890241912356.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /experiments/ENCSR000EFT/
# Loading complete
# Taking picture of https://www.encodeproject.org/experiments/ENCSR000EFT/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod261326007487115517194714421328558130798.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /biosamples/ENCBS643IYW/
# Loading complete
# Taking picture of https://www.encodeproject.org/biosamples/ENCBS643IYW/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod158410621506804420748804559903518207700.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /experiments/ENCSR466YGC/
# Loading complete
# Taking picture of https://www.encodeproject.org/experiments/ENCSR466YGC/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod109757459675961780637040077165716798246.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /experiments/ENCSR723PGJ/
# Loading complete
# Taking picture of https://www.encodeproject.org/experiments/ENCSR723PGJ/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod293504581487732106329500428315531607822.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /experiments/ENCSR313NYZ/
# Loading complete
# Taking picture of https://www.encodeproject.org/experiments/ENCSR313NYZ/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod250979494904429275032064274474430845542.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /files/ENCFF752JWY/
# Loading complete
# Taking picture of https://www.encodeproject.org/files/ENCFF752JWY/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod103235290435064390296731436927918882295.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /targets/2L52.1-celegans/
# Loading complete
# Taking picture of https://www.encodeproject.org/targets/2L52.1-celegans/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod48147279722917992459607773893907431099.png
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /targets/CG15455-dmelanogaster/
# Loading complete
# Taking picture of https://www.encodeproject.org/targets/CG15455-dmelanogaster/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod230552930935158473349209106553500345855.png
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /software/dnase-eval-bam-se/
# Loading complete
# Taking picture of https://www.encodeproject.org/software/dnase-eval-bam-se/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod307897011231180472182422424772571463023.png
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /software/atac-seq-software-tools/
# Loading complete
# Taking picture of https://www.encodeproject.org/software/atac-seq-software-tools/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod49816148622173694088569314155760016188.png
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /software/trimAdapters.py/
# Loading complete
# Taking picture of https://www.encodeproject.org/software/trimAdapters.py/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod102365972632577957504823035367980156668.png
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /software/bigwigaverageoverbed/
# Loading complete
# Taking picture of https://www.encodeproject.org/software/bigwigaverageoverbed/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod248770763304985652969211284135628068612.png
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /pipelines/ENCPL493SGC/
# Loading complete
# Taking picture of https://www.encodeproject.org/pipelines/ENCPL493SGC/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod145470590762754768746338656177999305987.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /pipelines/ENCPL035XIO/
# Loading complete
# Taking picture of https://www.encodeproject.org/pipelines/ENCPL035XIO/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod298815385525128982483460458540572068663.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /pipelines/ENCPL568PWV/
# Loading complete
# Taking picture of https://www.encodeproject.org/pipelines/ENCPL568PWV/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod161956481533012346547415128974440925471.png
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /pipelines/e02448b1-9706-4e7c-b31b-78c921d58f0b/
# Loading complete
# Taking picture of https://www.encodeproject.org/pipelines/e02448b1-9706-4e7c-b31b-78c921d58f0b/
# /var/folders/jk/xshb4qqs3gs4s661529s_bt80000gp/T/tmpu77y0_8t/prod263730119549937236070680391190261613467.png
# Stitching screenshot
# Opening https://www.encodeproject.org in Chrome
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /pipelines/ENCPL734EDH/

# %%
#qa.check_requests()

# %%
#qa.check_tools()
