# %%
import qancode

# %%
qa = qancode.QANCODE(prod_url="https://comparison-master-60286d0e2-idan.demo.encodedcc.org", rc_url="https://encd-3757-chip-audit-f6dd91518-idan.demo.encodedcc.org")

# %%
#public view of site
qa.compare_facets(users=['Public'], browsers=['Safari'], item_types=['/search/?type=Experiment', '/search/?type=File', '/search/?type=Annotation'], browser_comparison=False)
# Out:
# Opening https://comparison-master-60286d0e2-idan.demo.encodedcc.org in Safari
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://comparison-master-60286d0e2-idan.demo.encodedcc.org in Safari
# Getting type: /search/?type=File
# Search page detected
# Opening https://comparison-master-60286d0e2-idan.demo.encodedcc.org in Safari
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://encd-3757-chip-audit-f6dd91518-idan.demo.encodedcc.org in Safari
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-chip-audit-f6dd91518-idan.demo.encodedcc.org in Safari
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3757-chip-audit-f6dd91518-idan.demo.encodedcc.org in Safari
# Getting type: /search/?type=Annotation
# Search page detected
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: Public
# ...

# %%
#admin view of site
qa.compare_facets(users=['encoded.test4@gmail.com'], browsers=['Safari'], item_types=['/search/?type=Experiment', '/search/?type=File', '/search/?type=Annotation'], browser_comparison=False)
# Out:
# Opening https://comparison-master-60286d0e2-idan.demo.encodedcc.org in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://comparison-master-60286d0e2-idan.demo.encodedcc.org in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://comparison-master-60286d0e2-idan.demo.encodedcc.org in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://encd-3757-chip-audit-f6dd91518-idan.demo.encodedcc.org in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-chip-audit-f6dd91518-idan.demo.encodedcc.org in Safari
# Logging in as encoded.test4@gmail.com
# ...
