# %%
import sys
sys.path.append('../..')
import qancode

# %%
#comparing to v65rc2 site
qa = qancode.QANCODE(rc_url="https://v91rc1-master.demo.encodedcc.org/", prod_url="https://v91rc3-master.demo.encodedcc.org/")

# %%
qa.check_response_time(item_types=["/","/search/?type=Experiment"], n=100)
# Out:
# Checking response time
#
# *** item_type: /
# ------------------ https://v91rc3-master.demo.encodedcc.org// ------------------
# Average es_time: 125.349 ± 81.953 ms (n=100)
# Average queue_time: 9.671 ± 46.998 ms (n=100)
# Average render_time: 4.545 ± 24.559 ms (n=100)
# Average wsgi_time: 133.359 ± 85.967 ms (n=100)
# Average total time: 272.924 ± 170.128 ms (n=100)
# ------------------ https://v91rc1-master.demo.encodedcc.org// ------------------
# Average es_time: 125.433 ± 122.564 ms (n=100)
# Average queue_time: 0.299 ± 0.032 ms (n=100)
# Average render_time: 1.545 ± 0.247 ms (n=100)
# Average wsgi_time: 130.183 ± 122.494 ms (n=100)
# Average total time: 257.461 ± 245.039 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment
# ------ https://v91rc3-master.demo.encodedcc.org//search/?type=Experiment -------
# Average es_time: 302.821 ± 127.502 ms (n=100)
# Average queue_time: 0.375 ± 0.032 ms (n=100)
# Average render_time: 88.481 ± 8.248 ms (n=100)
# Average wsgi_time: 434.907 ± 128.926 ms (n=100)
# Average total time: 826.584 ± 257.68 ms (n=100)
# ------ https://v91rc1-master.demo.encodedcc.org//search/?type=Experiment -------
# Average es_time: 310.072 ± 99.314 ms (n=100)
# Average queue_time: 58.12 ± 211.253 ms (n=100)
# Average render_time: 98.845 ± 51.073 ms (n=100)
# Average wsgi_time: 461.398 ± 111.375 ms (n=100)
# Average total time: 928.436 ± 275.455 ms (n=100)

# %%
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ------ https://v91rc3-master.demo.encodedcc.org//search/?searchTerm=K562 -------
# Average es_time: 996.339 ± 296.528 ms (n=100)
# Average queue_time: 21.393 ± 101.859 ms (n=100)
# Average render_time: 24.027 ± 37.191 ms (n=100)
# Average wsgi_time: 1040.132 ± 301.72 ms (n=100)
# Average total time: 2081.891 ± 579.985 ms (n=100)
# ------ https://v91rc1-master.demo.encodedcc.org//search/?searchTerm=K562 -------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-6ca8da27d1f7> in <module>()
# ----> 1 qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in check_response_time(self, urls, item_types, n)
#     492                 if item is not None:
#     493                     url = url + item
# --> 494                 self._average_time_for_get(url, n)
#     495             print()
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _average_time_for_get(self, url, n)
#     472     def _average_time_for_get(self, url, n):
#     473         self._print_header(url)
# --> 474         time_headers = self._get_time_headers(url, n)
#     475         parsed_headers = [self._parse_header(h) for h in time_headers]
#     476         for key in sorted(parsed_headers[0].keys()):
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _get_time_headers(url, n)
#     438         for i in range(n):
#     439             r = requests.get(url)
# --> 440             assert r.status_code == 200
#     441             time_headers.append(r.headers)
#     442         return time_headers
#
# AssertionError:

# %%
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------------- https://test.encodedcc.org//ENCSR255XZG/ -------------------
# Average es_time: 13.01 ± 1.976 ms (n=100)
# Average queue_time: 0.48 ± 0.036 ms (n=100)
# Average render_time: 117.148 ± 6.335 ms (n=100)
# Average wsgi_time: 225.437 ± 110.076 ms (n=100)
# Average total time: 356.075 ± 111.526 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR255XZG/ ------------
# Average es_time: 11.754 ± 4.162 ms (n=100)
# Average queue_time: 0.473 ± 0.018 ms (n=100)
# Average render_time: 109.36 ± 6.365 ms (n=100)
# Average wsgi_time: 205.708 ± 55.147 ms (n=100)
# Average total time: 327.295 ± 56.641 ms (n=100)
#
#
# *** item_type: /ENCSR749ILN/
# ------------------- https://test.encodedcc.org//ENCSR749ILN/ -------------------
# Average es_time: 5.651 ± 0.31 ms (n=100)
# Average queue_time: 0.47 ± 0.032 ms (n=100)
# Average render_time: 34.913 ± 4.789 ms (n=100)
# Average wsgi_time: 59.295 ± 4.951 ms (n=100)
# Average total time: 100.328 ± 9.668 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR749ILN/ ------------
# Average es_time: 5.627 ± 0.605 ms (n=100)
# Average queue_time: 0.459 ± 0.024 ms (n=100)
# Average render_time: 30.443 ± 4.97 ms (n=100)
# Average wsgi_time: 69.345 ± 104.501 ms (n=100)
# Average total time: 105.874 ± 104.757 ms (n=100)
#
#
# *** item_type: /ENCSR688GVV/
# ------------------- https://test.encodedcc.org//ENCSR688GVV/ -------------------
# Average es_time: 11.68 ± 2.061 ms (n=100)
# Average queue_time: 0.483 ± 0.035 ms (n=100)
# Average render_time: 66.847 ± 5.011 ms (n=100)
# Average wsgi_time: 122.691 ± 5.585 ms (n=100)
# Average total time: 201.7 ± 10.929 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR688GVV/ ------------
# Average es_time: 11.879 ± 5.102 ms (n=100)
# Average queue_time: 0.474 ± 0.017 ms (n=100)
# Average render_time: 63.167 ± 5.46 ms (n=100)
# Average wsgi_time: 129.356 ± 78.66 ms (n=100)
# Average total time: 204.875 ± 79.259 ms (n=100)
#
#
# *** item_type: /ENCSR301HAG/
# ------------------- https://test.encodedcc.org//ENCSR301HAG/ -------------------
# Average es_time: 3.122 ± 0.149 ms (n=100)
# Average queue_time: 0.465 ± 0.015 ms (n=100)
# Average render_time: 11.974 ± 5.726 ms (n=100)
# Average wsgi_time: 20.819 ± 5.764 ms (n=100)
# Average total time: 36.38 ± 11.508 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR301HAG/ ------------
# Average es_time: 3.093 ± 0.078 ms (n=100)
# Average queue_time: 0.474 ± 0.021 ms (n=100)
# Average render_time: 9.091 ± 2.555 ms (n=100)
# Average wsgi_time: 17.899 ± 2.749 ms (n=100)
# Average total time: 30.556 ± 5.273 ms (n=100)
#
#
# *** item_type: /ENCSR315NAC/
# ------------------- https://test.encodedcc.org//ENCSR315NAC/ -------------------
# Average es_time: 8.938 ± 2.33 ms (n=100)
# Average queue_time: 0.46 ± 0.021 ms (n=100)
# Average render_time: 51.138 ± 6.462 ms (n=100)
# Average wsgi_time: 97.203 ± 50.053 ms (n=100)
# Average total time: 157.739 ± 51.741 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR315NAC/ ------------
# Average es_time: 9.613 ± 5.057 ms (n=100)
# Average queue_time: 0.466 ± 0.021 ms (n=100)
# Average render_time: 49.99 ± 5.765 ms (n=100)
# Average wsgi_time: 96.104 ± 43.537 ms (n=100)
# Average total time: 156.172 ± 46.008 ms (n=100)
#
#
# *** item_type: /ENCSR856JJB/
# ------------------- https://test.encodedcc.org//ENCSR856JJB/ -------------------
# Average es_time: 7.394 ± 0.798 ms (n=100)
# Average queue_time: 0.461 ± 0.016 ms (n=100)
# Average render_time: 46.195 ± 6.454 ms (n=100)
# Average wsgi_time: 80.896 ± 6.632 ms (n=100)
# Average total time: 134.946 ± 13.233 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR856JJB/ ------------
# Average es_time: 8.427 ± 0.161 ms (n=100)
# Average queue_time: 0.465 ± 0.027 ms (n=100)
# Average render_time: 43.103 ± 6.219 ms (n=100)
# Average wsgi_time: 78.958 ± 6.274 ms (n=100)
# Average total time: 130.952 ± 12.44 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------------- https://test.encodedcc.org//ENCSR480OHP/ -------------------
# Average es_time: 5.873 ± 1.95 ms (n=100)
# Average queue_time: 0.455 ± 0.014 ms (n=100)
# Average render_time: 46.45 ± 5.539 ms (n=100)
# Average wsgi_time: 92.999 ± 90.626 ms (n=100)
# Average total time: 145.777 ± 91.222 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR480OHP/ ------------
# Average es_time: 6.912 ± 5.146 ms (n=100)
# Average queue_time: 0.452 ± 0.021 ms (n=100)
# Average render_time: 42.995 ± 4.913 ms (n=100)
# Average wsgi_time: 89.177 ± 81.967 ms (n=100)
# Average total time: 139.536 ± 82.469 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ------------------- https://test.encodedcc.org//ENCSR000EMB/ -------------------
# Average es_time: 7.942 ± 3.308 ms (n=100)
# Average queue_time: 0.458 ± 0.018 ms (n=100)
# Average render_time: 48.343 ± 6.585 ms (n=100)
# Average wsgi_time: 92.638 ± 86.933 ms (n=100)
# Average total time: 149.382 ± 87.082 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR000EMB/ ------------
# Average es_time: 8.96 ± 2.77 ms (n=100)
# Average queue_time: 0.468 ± 0.022 ms (n=100)
# Average render_time: 44.549 ± 6.358 ms (n=100)
# Average wsgi_time: 81.06 ± 6.881 ms (n=100)
# Average total time: 135.037 ± 13.612 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------- https://test.encodedcc.org//ENCSR323QIP/ -------------------
# Average es_time: 18.097 ± 3.054 ms (n=100)
# Average queue_time: 0.467 ± 0.017 ms (n=100)
# Average render_time: 136.435 ± 4.56 ms (n=100)
# Average wsgi_time: 278.618 ± 146.403 ms (n=100)
# Average total time: 433.617 ± 146.668 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR323QIP/ ------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-fe7b77c906a4> in <module>()
# ----> 1 qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in check_response_time(self, urls, item_types, n)
#     492                 if item is not None:
#     493                     url = url + item
# --> 494                 self._average_time_for_get(url, n)
#     495             print()
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _average_time_for_get(self, url, n)
#     472     def _average_time_for_get(self, url, n):
#     473         self._print_header(url)
# --> 474         time_headers = self._get_time_headers(url, n)
#     475         parsed_headers = [self._parse_header(h) for h in time_headers]
#     476         for key in sorted(parsed_headers[0].keys()):
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _get_time_headers(url, n)
#     438         for i in range(n):
#     439             r = requests.get(url)
# --> 440             assert r.status_code == 200
#     441             time_headers.append(r.headers)
#     442         return time_headers
#
# AssertionError:

# %%
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ------------------- https://test.encodedcc.org//ENCAB830JLB/ -------------------
# Average es_time: 3.641 ± 0.588 ms (n=100)
# Average queue_time: 0.445 ± 0.014 ms (n=100)
# Average render_time: 48.184 ± 5.886 ms (n=100)
# Average wsgi_time: 77.284 ± 6.366 ms (n=100)
# Average total time: 129.553 ± 12.186 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB830JLB/ ------------
# Average es_time: 4.022 ± 0.147 ms (n=100)
# Average queue_time: 0.439 ± 0.02 ms (n=100)
# Average render_time: 39.692 ± 6.411 ms (n=100)
# Average wsgi_time: 68.649 ± 6.515 ms (n=100)
# Average total time: 112.802 ± 12.918 ms (n=100)
#
#
# *** item_type: /ENCAB000BKR/
# ------------------- https://test.encodedcc.org//ENCAB000BKR/ -------------------
# Average es_time: 2.827 ± 0.484 ms (n=100)
# Average queue_time: 0.442 ± 0.014 ms (n=100)
# Average render_time: 20.994 ± 7.188 ms (n=100)
# Average wsgi_time: 35.146 ± 7.301 ms (n=100)
# Average total time: 59.409 ± 14.493 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB000BKR/ ------------
# Average es_time: 2.792 ± 0.386 ms (n=100)
# Average queue_time: 0.442 ± 0.02 ms (n=100)
# Average render_time: 18.934 ± 5.421 ms (n=100)
# Average wsgi_time: 32.854 ± 5.487 ms (n=100)
# Average total time: 55.023 ± 10.885 ms (n=100)
#
#
# *** item_type: /ENCAB284TTY/
# ------------------- https://test.encodedcc.org//ENCAB284TTY/ -------------------
# Average es_time: 4.513 ± 0.964 ms (n=100)
# Average queue_time: 0.444 ± 0.013 ms (n=100)
# Average render_time: 52.432 ± 4.794 ms (n=100)
# Average wsgi_time: 91.504 ± 4.914 ms (n=100)
# Average total time: 148.893 ± 9.585 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB284TTY/ ------------
# Average es_time: 4.627 ± 1.038 ms (n=100)
# Average queue_time: 0.435 ± 0.022 ms (n=100)
# Average render_time: 50.796 ± 4.824 ms (n=100)
# Average wsgi_time: 90.083 ± 5.243 ms (n=100)
# Average total time: 145.941 ± 10.108 ms (n=100)
#
#
# *** item_type: /ENCAB294YUD/
# ------------------- https://test.encodedcc.org//ENCAB294YUD/ -------------------
# Average es_time: 2.417 ± 1.598 ms (n=100)
# Average queue_time: 0.465 ± 0.019 ms (n=100)
# Average render_time: 7.173 ± 2.18 ms (n=100)
# Average wsgi_time: 12.826 ± 2.658 ms (n=100)
# Average total time: 22.881 ± 5.302 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB294YUD/ ------------
# Average es_time: 2.333 ± 1.92 ms (n=100)
# Average queue_time: 0.376 ± 0.031 ms (n=100)
# Average render_time: 5.378 ± 1.252 ms (n=100)
# Average wsgi_time: 10.653 ± 2.299 ms (n=100)
# Average total time: 18.74 ± 4.538 ms (n=100)
#
#
# *** item_type: /ENCAB000AOC/
# ------------------- https://test.encodedcc.org//ENCAB000AOC/ -------------------
# Average es_time: 3.125 ± 0.571 ms (n=100)
# Average queue_time: 0.443 ± 0.015 ms (n=100)
# Average render_time: 32.368 ± 6.97 ms (n=100)
# Average wsgi_time: 57.044 ± 77.728 ms (n=100)
# Average total time: 92.981 ± 79.576 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB000AOC/ ------------
# Average es_time: 3.018 ± 0.407 ms (n=100)
# Average queue_time: 0.427 ± 0.026 ms (n=100)
# Average render_time: 27.76 ± 5.575 ms (n=100)
# Average wsgi_time: 44.384 ± 5.749 ms (n=100)
# Average total time: 75.589 ± 11.395 ms (n=100)
#
#
# *** item_type: /ENCAB301QZF/
# ------------------- https://test.encodedcc.org//ENCAB301QZF/ -------------------
# Average es_time: 2.529 ± 0.557 ms (n=100)
# Average queue_time: 0.435 ± 0.011 ms (n=100)
# Average render_time: 13.351 ± 4.587 ms (n=100)
# Average wsgi_time: 21.135 ± 4.748 ms (n=100)
# Average total time: 37.451 ± 9.516 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB301QZF/ ------------
# Average es_time: 2.317 ± 0.199 ms (n=100)
# Average queue_time: 0.412 ± 0.026 ms (n=100)
# Average render_time: 11.543 ± 3.061 ms (n=100)
# Average wsgi_time: 18.933 ± 3.086 ms (n=100)
# Average total time: 33.205 ± 6.145 ms (n=100)
#
#
# *** item_type: /ENCAB000ANM/
# ------------------- https://test.encodedcc.org//ENCAB000ANM/ -------------------
# Average es_time: 3.365 ± 0.543 ms (n=100)
# Average queue_time: 0.449 ± 0.019 ms (n=100)
# Average render_time: 25.649 ± 6.054 ms (n=100)
# Average wsgi_time: 41.631 ± 6.094 ms (n=100)
# Average total time: 71.094 ± 12.164 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB000ANM/ ------------
# Average es_time: 2.976 ± 0.374 ms (n=100)
# Average queue_time: 0.433 ± 0.026 ms (n=100)
# Average render_time: 24.657 ± 5.193 ms (n=100)
# Average wsgi_time: 40.138 ± 5.301 ms (n=100)
# Average total time: 68.204 ± 10.516 ms (n=100)
#
#
# *** item_type: /ENCAB000ANU/
# ------------------- https://test.encodedcc.org//ENCAB000ANU/ -------------------
# Average es_time: 2.821 ± 0.68 ms (n=100)
# Average queue_time: 0.443 ± 0.012 ms (n=100)
# Average render_time: 22.802 ± 8.603 ms (n=100)
# Average wsgi_time: 35.033 ± 8.642 ms (n=100)
# Average total time: 61.099 ± 17.157 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB000ANU/ ------------
# Average es_time: 2.9 ± 0.094 ms (n=100)
# Average queue_time: 0.427 ± 0.028 ms (n=100)
# Average render_time: 17.907 ± 5.177 ms (n=100)
# Average wsgi_time: 30.139 ± 5.14 ms (n=100)
# Average total time: 51.373 ± 10.3 ms (n=100)
#
#
# *** item_type: /ENCAB445KMF/
# ------------------- https://test.encodedcc.org//ENCAB445KMF/ -------------------
# Average es_time: 2.5 ± 0.377 ms (n=100)
# Average queue_time: 0.439 ± 0.012 ms (n=100)
# Average render_time: 19.915 ± 7.131 ms (n=100)
# Average wsgi_time: 30.476 ± 7.11 ms (n=100)
# Average total time: 53.329 ± 14.249 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB445KMF/ ------------
# Average es_time: 2.517 ± 0.333 ms (n=100)
# Average queue_time: 0.414 ± 0.026 ms (n=100)
# Average render_time: 15.434 ± 3.951 ms (n=100)
# Average wsgi_time: 25.738 ± 4.017 ms (n=100)
# Average total time: 44.103 ± 8.02 ms (n=100)
#
#
# *** item_type: /ENCAB000BAY/
# ------------------- https://test.encodedcc.org//ENCAB000BAY/ -------------------
# Average es_time: 2.909 ± 0.624 ms (n=100)
# Average queue_time: 0.437 ± 0.013 ms (n=100)
# Average render_time: 29.224 ± 6.951 ms (n=100)
# Average wsgi_time: 44.764 ± 6.986 ms (n=100)
# Average total time: 77.334 ± 13.869 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCAB000BAY/ ------------
# Average es_time: 2.921 ± 0.525 ms (n=100)
# Average queue_time: 0.426 ± 0.027 ms (n=100)
# Average render_time: 26.102 ± 5.384 ms (n=100)
# Average wsgi_time: 41.435 ± 5.525 ms (n=100)
# Average total time: 70.882 ± 10.943 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS787TFV/
# ------------------- https://test.encodedcc.org//ENCBS787TFV/ -------------------
# Average es_time: 2.403 ± 0.42 ms (n=100)
# Average queue_time: 0.445 ± 0.02 ms (n=100)
# Average render_time: 7.142 ± 1.97 ms (n=100)
# Average wsgi_time: 13.338 ± 2.337 ms (n=100)
# Average total time: 23.328 ± 4.28 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS787TFV/ ------------
# Average es_time: 2.538 ± 0.657 ms (n=100)
# Average queue_time: 0.433 ± 0.025 ms (n=100)
# Average render_time: 6.216 ± 1.706 ms (n=100)
# Average wsgi_time: 12.281 ± 2.349 ms (n=100)
# Average total time: 21.467 ± 4.413 ms (n=100)
#
#
# *** item_type: /ENCBS676QAV/
# ------------------- https://test.encodedcc.org//ENCBS676QAV/ -------------------
# Average es_time: 5.192 ± 7.029 ms (n=100)
# Average queue_time: 0.438 ± 0.019 ms (n=100)
# Average render_time: 7.877 ± 2.036 ms (n=100)
# Average wsgi_time: 17.079 ± 8.361 ms (n=100)
# Average total time: 30.587 ± 16.553 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS676QAV/ ------------
# Average es_time: 2.942 ± 3.495 ms (n=100)
# Average queue_time: 0.388 ± 0.029 ms (n=100)
# Average render_time: 6.245 ± 1.047 ms (n=100)
# Average wsgi_time: 12.918 ± 4.359 ms (n=100)
# Average total time: 22.492 ± 8.517 ms (n=100)
#
#
# *** item_type: /ENCBS996IWU/
# ------------------- https://test.encodedcc.org//ENCBS996IWU/ -------------------
# Average es_time: 2.267 ± 0.249 ms (n=100)
# Average queue_time: 0.438 ± 0.013 ms (n=100)
# Average render_time: 8.137 ± 1.523 ms (n=100)
# Average wsgi_time: 13.991 ± 1.669 ms (n=100)
# Average total time: 24.833 ± 3.233 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS996IWU/ ------------
# Average es_time: 3.038 ± 3.2 ms (n=100)
# Average queue_time: 0.397 ± 0.026 ms (n=100)
# Average render_time: 7.34 ± 0.962 ms (n=100)
# Average wsgi_time: 13.823 ± 3.716 ms (n=100)
# Average total time: 24.598 ± 7.356 ms (n=100)
#
#
# *** item_type: /ENCBS913XJP/
# ------------------- https://test.encodedcc.org//ENCBS913XJP/ -------------------
# Average es_time: 2.319 ± 0.201 ms (n=100)
# Average queue_time: 0.447 ± 0.018 ms (n=100)
# Average render_time: 5.89 ± 1.142 ms (n=100)
# Average wsgi_time: 11.781 ± 1.193 ms (n=100)
# Average total time: 20.438 ± 2.332 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS913XJP/ ------------
# Average es_time: 2.47 ± 0.221 ms (n=100)
# Average queue_time: 0.432 ± 0.026 ms (n=100)
# Average render_time: 5.988 ± 1.381 ms (n=100)
# Average wsgi_time: 11.897 ± 1.491 ms (n=100)
# Average total time: 20.787 ± 2.911 ms (n=100)
#
#
# *** item_type: /ENCBS565NTN/
# ------------------- https://test.encodedcc.org//ENCBS565NTN/ -------------------
# Average es_time: 2.216 ± 0.301 ms (n=100)
# Average queue_time: 0.438 ± 0.014 ms (n=100)
# Average render_time: 6.133 ± 1.348 ms (n=100)
# Average wsgi_time: 11.808 ± 1.464 ms (n=100)
# Average total time: 20.594 ± 2.821 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS565NTN/ ------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-b4dee72d97bb> in <module>()
# ----> 1 qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=100)
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in check_response_time(self, urls, item_types, n)
#     492                 if item is not None:
#     493                     url = url + item
# --> 494                 self._average_time_for_get(url, n)
#     495             print()
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _average_time_for_get(self, url, n)
#     472     def _average_time_for_get(self, url, n):
#     473         self._print_header(url)
# --> 474         time_headers = self._get_time_headers(url, n)
#     475         parsed_headers = [self._parse_header(h) for h in time_headers]
#     476         for key in sorted(parsed_headers[0].keys()):
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _get_time_headers(url, n)
#     438         for i in range(n):
#     439             r = requests.get(url)
# --> 440             assert r.status_code == 200
#     441             time_headers.append(r.headers)
#     442         return time_headers
#
# AssertionError:

# %%
qa.check_response_time(item_types=['/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS565NTN/
# ------------------- https://test.encodedcc.org//ENCBS565NTN/ -------------------
# Average es_time: 2.219 ± 0.136 ms (n=100)
# Average queue_time: 0.442 ± 0.021 ms (n=100)
# Average render_time: 5.749 ± 1.163 ms (n=100)
# Average wsgi_time: 20.038 ± 86.771 ms (n=100)
# Average total time: 28.447 ± 86.733 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS565NTN/ ------------
# Average es_time: 2.36 ± 0.089 ms (n=100)
# Average queue_time: 0.425 ± 0.033 ms (n=100)
# Average render_time: 5.309 ± 0.394 ms (n=100)
# Average wsgi_time: 10.975 ± 0.438 ms (n=100)
# Average total time: 19.069 ± 0.789 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ------------------- https://test.encodedcc.org//ENCBS896YZO/ -------------------
# Average es_time: 5.197 ± 6.644 ms (n=100)
# Average queue_time: 0.437 ± 0.014 ms (n=100)
# Average render_time: 11.909 ± 3.419 ms (n=100)
# Average wsgi_time: 21.76 ± 7.552 ms (n=100)
# Average total time: 39.303 ± 14.927 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS896YZO/ ------------
# Average es_time: 3.033 ± 3.455 ms (n=100)
# Average queue_time: 0.403 ± 0.031 ms (n=100)
# Average render_time: 12.625 ± 3.998 ms (n=100)
# Average wsgi_time: 19.969 ± 5.233 ms (n=100)
# Average total time: 36.03 ± 10.391 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ------------------- https://test.encodedcc.org//ENCBS280NYD/ -------------------
# Average es_time: 6.19 ± 9.361 ms (n=100)
# Average queue_time: 0.428 ± 0.013 ms (n=100)
# Average render_time: 5.695 ± 1.007 ms (n=100)
# Average wsgi_time: 15.325 ± 9.702 ms (n=100)
# Average total time: 27.639 ± 19.246 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCBS280NYD/ ------------
# Average es_time: 2.44 ± 2.423 ms (n=100)
# Average queue_time: 0.377 ± 0.03 ms (n=100)
# Average render_time: 5.559 ± 1.28 ms (n=100)
# Average wsgi_time: 11.122 ± 2.931 ms (n=100)
# Average total time: 19.498 ± 5.765 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------- https://test.encodedcc.org//ENCSR323QIP/ -------------------
# Average es_time: 18.436 ± 3.353 ms (n=100)
# Average queue_time: 0.502 ± 0.038 ms (n=100)
# Average render_time: 139.399 ± 5.342 ms (n=100)
# Average wsgi_time: 269.148 ± 88.498 ms (n=100)
# Average total time: 427.485 ± 89.72 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR323QIP/ ------------
# Average es_time: 15.842 ± 3.518 ms (n=100)
# Average queue_time: 0.473 ± 0.021 ms (n=100)
# Average render_time: 137.326 ± 5.019 ms (n=100)
# Average wsgi_time: 276.052 ± 140.644 ms (n=100)
# Average total time: 429.693 ± 142.372 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------------- https://test.encodedcc.org//ENCSR718AXQ/ -------------------
# Average es_time: 5.518 ± 0.471 ms (n=100)
# Average queue_time: 0.483 ± 0.037 ms (n=100)
# Average render_time: 25.164 ± 7.685 ms (n=100)
# Average wsgi_time: 41.21 ± 7.735 ms (n=100)
# Average total time: 72.375 ± 15.422 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR718AXQ/ ------------
# Average es_time: 6.655 ± 3.107 ms (n=100)
# Average queue_time: 0.471 ± 0.021 ms (n=100)
# Average render_time: 17.897 ± 6.613 ms (n=100)
# Average wsgi_time: 34.738 ± 7.684 ms (n=100)
# Average total time: 59.761 ± 15.09 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------------- https://test.encodedcc.org//ENCSR165BGV/ -------------------
# Average es_time: 3.497 ± 1.819 ms (n=100)
# Average queue_time: 0.48 ± 0.035 ms (n=100)
# Average render_time: 21.242 ± 8.361 ms (n=100)
# Average wsgi_time: 36.226 ± 8.561 ms (n=100)
# Average total time: 61.445 ± 17.05 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR165BGV/ ------------
# Average es_time: 3.543 ± 2.666 ms (n=100)
# Average queue_time: 0.462 ± 0.021 ms (n=100)
# Average render_time: 18.487 ± 5.864 ms (n=100)
# Average wsgi_time: 33.147 ± 6.39 ms (n=100)
# Average total time: 55.638 ± 12.723 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------------- https://test.encodedcc.org//ENCSR384KAN/ -------------------
# Average es_time: 8.253 ± 1.709 ms (n=100)
# Average queue_time: 0.492 ± 0.037 ms (n=100)
# Average render_time: 50.718 ± 7.612 ms (n=100)
# Average wsgi_time: 110.959 ± 119.528 ms (n=100)
# Average total time: 170.421 ± 120.354 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR384KAN/ ------------
# Average es_time: 8.045 ± 0.787 ms (n=100)
# Average queue_time: 0.481 ± 0.038 ms (n=100)
# Average render_time: 49.812 ± 6.276 ms (n=100)
# Average wsgi_time: 96.158 ± 39.425 ms (n=100)
# Average total time: 154.496 ± 39.854 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------------- https://test.encodedcc.org//ENCSR330FXL/ -------------------
# Average es_time: 6.449 ± 7.617 ms (n=100)
# Average queue_time: 0.469 ± 0.031 ms (n=100)
# Average render_time: 28.098 ± 7.847 ms (n=100)
# Average wsgi_time: 48.727 ± 12.311 ms (n=100)
# Average total time: 83.743 ± 24.285 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR330FXL/ ------------
# Average es_time: 4.021 ± 3.05 ms (n=100)
# Average queue_time: 0.478 ± 0.036 ms (n=100)
# Average render_time: 22.992 ± 4.531 ms (n=100)
# Average wsgi_time: 41.206 ± 6.162 ms (n=100)
# Average total time: 68.697 ± 12.029 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------

# %%
qa.check_response_time(item_types=['/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 22.765 ± 5.139 ms (n=100)
# Average queue_time: 0.464 ± 0.015 ms (n=100)
# Average render_time: 217.639 ± 8.502 ms (n=100)
# Average wsgi_time: 430.781 ± 184.704 ms (n=100)
# Average total time: 671.648 ± 188.428 ms (n=100)
# ------------ https://v79rc1-master.demo.encodedcc.org//ENCSR825UNV/ ------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-29540e2acd7e> in <module>()
# ----> 1 qa.check_response_time(item_types=['/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in check_response_time(self, urls, item_types, n)
#     492                 if item is not None:
#     493                     url = url + item
# --> 494                 self._average_time_for_get(url, n)
#     495             print()
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _average_time_for_get(self, url, n)
#     472     def _average_time_for_get(self, url, n):
#     473         self._print_header(url)
# --> 474         time_headers = self._get_time_headers(url, n)
#     475         parsed_headers = [self._parse_header(h) for h in time_headers]
#     476         for key in sorted(parsed_headers[0].keys()):
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _get_time_headers(url, n)
#     438         for i in range(n):
#     439             r = requests.get(url)
# --> 440             assert r.status_code == 200
#     441             time_headers.append(r.headers)
#     442         return time_headers
#
# AssertionError:
