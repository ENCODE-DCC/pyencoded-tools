# %%
import sys
sys.path.append('../..')
import qancode

# %%
#comparing to v65rc2 site
qa = qancode.QANCODE(rc_url="https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org/", prod_url="https://test.encodedcc.org/")

# %%
qa.check_response_time(item_types=["/","/search/?type=Experiment"], n=100)
# Out:
# Checking response time
#
# *** item_type: /
# ------------------------- https://test.encodedcc.org// -------------------------
# Average es_time: 1.915 ± 0.233 ms (n=100)
# Average queue_time: 0.391 ± 0.031 ms (n=100)
# Average render_time: 3.135 ± 0.393 ms (n=100)
# Average wsgi_time: 8.659 ± 0.551 ms (n=100)
# Average total time: 14.101 ± 1.0 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org// ---------
# Average es_time: 1.088 ± 0.209 ms (n=100)
# Average queue_time: 0.487 ± 0.065 ms (n=100)
# Average render_time: 9.869 ± 33.666 ms (n=100)
# Average wsgi_time: 15.121 ± 34.174 ms (n=100)
# Average total time: 26.565 ± 67.978 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment
# ------------- https://test.encodedcc.org//search/?type=Experiment --------------
# Average es_time: 20.969 ± 9.192 ms (n=100)
# Average queue_time: 0.47 ± 0.024 ms (n=100)
# Average render_time: 87.358 ± 12.029 ms (n=100)
# Average wsgi_time: 124.399 ± 18.056 ms (n=100)
# Average total time: 233.196 ± 36.003 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//search/?type=Experiment ---------
# Average es_time: 20.673 ± 4.24 ms (n=100)
# Average queue_time: 0.588 ± 0.042 ms (n=100)
# Average render_time: 225.548 ± 26.266 ms (n=100)
# Average wsgi_time: 283.885 ± 27.902 ms (n=100)
# Average total time: 530.694 ± 55.649 ms (n=100)

# %%
qa.check_response_time(item_types=["/search/?type=Experiment&format=json"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?type=Experiment&format=json
# ------- https://test.encodedcc.org//search/?type=Experiment&format=json --------
# Average es_time: 19.862 ± 5.717 ms (n=100)
# Average queue_time: 0.342 ± 0.034 ms (n=100)
# Average wsgi_time: 35.668 ± 5.76 ms (n=100)
# Average total time: 55.871 ± 11.454 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//search/?type=Experiment&format=json ---------
# Average es_time: 19.875 ± 1.154 ms (n=100)
# Average queue_time: 0.557 ± 0.016 ms (n=100)
# Average wsgi_time: 57.542 ± 1.43 ms (n=100)
# Average total time: 77.974 ± 2.503 ms (n=100)

# %%
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ------------- https://test.encodedcc.org//search/?searchTerm=K562 --------------
# Average es_time: 198.93 ± 15.137 ms (n=100)
# Average queue_time: 0.457 ± 0.043 ms (n=100)
# Average render_time: 15.517 ± 4.796 ms (n=100)
# Average wsgi_time: 222.234 ± 18.068 ms (n=100)
# Average total time: 437.138 ± 35.862 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//search/?searchTerm=K562 ---------
# Average es_time: 146.722 ± 16.097 ms (n=100)
# Average queue_time: 0.572 ± 0.038 ms (n=100)
# Average render_time: 14.681 ± 4.484 ms (n=100)
# Average wsgi_time: 170.195 ± 19.637 ms (n=100)
# Average total time: 332.171 ± 36.986 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# ---------- https://test.encodedcc.org//search/?searchTerm=DNA+binding ----------
# Average es_time: 297.705 ± 15.626 ms (n=100)
# Average queue_time: 0.479 ± 0.034 ms (n=100)
# Average render_time: 17.381 ± 3.389 ms (n=100)
# Average wsgi_time: 327.234 ± 17.595 ms (n=100)
# Average total time: 642.799 ± 33.664 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 244.165 ± 29.034 ms (n=100)
# Average queue_time: 0.578 ± 0.038 ms (n=100)
# Average render_time: 14.939 ± 3.249 ms (n=100)
# Average wsgi_time: 270.592 ± 30.013 ms (n=100)
# Average total time: 530.274 ± 58.858 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=human
# ------------- https://test.encodedcc.org//search/?searchTerm=human -------------
# Average es_time: 208.531 ± 14.03 ms (n=100)
# Average queue_time: 0.425 ± 0.038 ms (n=100)
# Average render_time: 16.12 ± 3.34 ms (n=100)
# Average wsgi_time: 231.721 ± 14.904 ms (n=100)
# Average total time: 456.798 ± 29.649 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//search/?searchTerm=human ---------
# Average es_time: 148.216 ± 22.332 ms (n=100)
# Average queue_time: 0.586 ± 0.03 ms (n=100)
# Average render_time: 15.498 ± 3.023 ms (n=100)
# Average wsgi_time: 171.119 ± 23.1 ms (n=100)
# Average total time: 335.42 ± 45.85 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# ----------- https://test.encodedcc.org//search/?searchTerm=H3K36me3 ------------
# Average es_time: 208.557 ± 11.52 ms (n=100)
# Average queue_time: 0.471 ± 0.037 ms (n=100)
# Average render_time: 17.685 ± 3.662 ms (n=100)
# Average wsgi_time: 234.242 ± 12.458 ms (n=100)
# Average total time: 460.954 ± 24.811 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//search/?searchTerm=H3K36me3 ---------
# Average es_time: 152.384 ± 15.633 ms (n=100)
# Average queue_time: 0.588 ± 0.034 ms (n=100)
# Average render_time: 16.052 ± 3.488 ms (n=100)
# Average wsgi_time: 176.549 ± 16.8 ms (n=100)
# Average total time: 345.574 ± 33.488 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=CTCF
# ------------- https://test.encodedcc.org//search/?searchTerm=CTCF --------------
# Average es_time: 208.617 ± 12.94 ms (n=100)
# Average queue_time: 0.463 ± 0.039 ms (n=100)
# Average render_time: 13.536 ± 2.98 ms (n=100)
# Average wsgi_time: 229.376 ± 14.041 ms (n=100)
# Average total time: 451.992 ± 27.934 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//search/?searchTerm=CTCF ---------
# Average es_time: 148.839 ± 19.799 ms (n=100)
# Average queue_time: 0.58 ± 0.039 ms (n=100)
# Average render_time: 12.616 ± 2.924 ms (n=100)
# Average wsgi_time: 168.828 ± 19.941 ms (n=100)
# Average total time: 330.864 ± 39.79 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------------- https://test.encodedcc.org//ENCSR255XZG/ -------------------
# Average es_time: 11.251 ± 3.626 ms (n=100)
# Average queue_time: 0.44 ± 0.024 ms (n=100)
# Average render_time: 97.539 ± 2.084 ms (n=100)
# Average wsgi_time: 203.79 ± 118.893 ms (n=100)
# Average total time: 313.02 ± 119.048 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//ENCSR255XZG/ ---------
# Average es_time: 4.064 ± 1.188 ms (n=100)
# Average queue_time: 0.489 ± 0.028 ms (n=100)
# Average render_time: 96.888 ± 2.006 ms (n=100)
# Average wsgi_time: 189.038 ± 79.509 ms (n=100)
# Average total time: 290.48 ± 79.913 ms (n=100)
#
#
# *** item_type: /ENCSR749ILN/
# ------------------- https://test.encodedcc.org//ENCSR749ILN/ -------------------
# Average es_time: 5.245 ± 0.215 ms (n=100)
# Average queue_time: 0.426 ± 0.028 ms (n=100)
# Average render_time: 24.45 ± 2.036 ms (n=100)
# Average wsgi_time: 47.515 ± 2.43 ms (n=100)
# Average total time: 77.636 ± 4.393 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//ENCSR749ILN/ ---------
# Average es_time: 2.473 ± 1.171 ms (n=100)
# Average queue_time: 0.474 ± 0.018 ms (n=100)
# Average render_time: 24.53 ± 2.082 ms (n=100)
# Average wsgi_time: 51.429 ± 63.805 ms (n=100)
# Average total time: 78.906 ± 63.789 ms (n=100)
#
#
# *** item_type: /ENCSR688GVV/
# ------------------- https://test.encodedcc.org//ENCSR688GVV/ -------------------
# Average es_time: 9.465 ± 3.99 ms (n=100)
# Average queue_time: 0.446 ± 0.027 ms (n=100)
# Average render_time: 57.479 ± 24.122 ms (n=100)
# Average wsgi_time: 116.875 ± 60.204 ms (n=100)
# Average total time: 184.266 ± 72.89 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//ENCSR688GVV/ ---------
# Average es_time: 3.816 ± 1.23 ms (n=100)
# Average queue_time: 0.489 ± 0.021 ms (n=100)
# Average render_time: 53.736 ± 2.972 ms (n=100)
# Average wsgi_time: 103.155 ± 37.05 ms (n=100)
# Average total time: 161.196 ± 37.32 ms (n=100)
#
#
# *** item_type: /ENCSR301HAG/
# ------------------- https://test.encodedcc.org//ENCSR301HAG/ -------------------
# Average es_time: 2.656 ± 0.349 ms (n=100)
# Average queue_time: 0.445 ± 0.024 ms (n=100)
# Average render_time: 6.884 ± 1.152 ms (n=100)
# Average wsgi_time: 15.267 ± 1.786 ms (n=100)
# Average total time: 25.253 ± 2.882 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//ENCSR301HAG/ ---------
# Average es_time: 1.347 ± 0.066 ms (n=100)
# Average queue_time: 0.486 ± 0.025 ms (n=100)
# Average render_time: 6.695 ± 0.707 ms (n=100)
# Average wsgi_time: 13.733 ± 1.093 ms (n=100)
# Average total time: 22.261 ± 1.741 ms (n=100)
#
#
# *** item_type: /ENCSR315NAC/
# ------------------- https://test.encodedcc.org//ENCSR315NAC/ -------------------
# Average es_time: 7.302 ± 1.894 ms (n=100)
# Average queue_time: 0.444 ± 0.022 ms (n=100)
# Average render_time: 41.724 ± 2.752 ms (n=100)
# Average wsgi_time: 80.637 ± 3.584 ms (n=100)
# Average total time: 130.107 ± 6.815 ms (n=100)
# --------- https://encd-3657-typeahead-facets-only-a2c4cb666-emmao.demo.encodedcc.org//ENCSR315NAC/ ---------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-99c9a58cb783> in <module>()
# ----> 1 qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=100)
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in check_response_time(self, urls, item_types, n)
#     492                 if item is not None:
#     493                     url = url + item
# --> 494                 self._average_time_for_get(url, n)
#     495             print()
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _average_time_for_get(self, url, n)
#     472     def _average_time_for_get(self, url, n):
#     473         self._print_header(url)
# --> 474         time_headers = self._get_time_headers(url, n)
#     475         parsed_headers = [self._parse_header(h) for h in time_headers]
#     476         for key in sorted(parsed_headers[0].keys()):
#
# /Users/hitz/Documents/workspace/pyencoded-tools/qancode/qancode.py in _get_time_headers(url, n)
#     437         time_headers = []
#     438         for i in range(n):
# --> 439             r = requests.get(url)
#     440             assert r.status_code == 200
#     441             time_headers.append(r.headers)
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Users/hitz/pyvenvs/jupyter/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /Users/hitz/.pyenv/versions/3.5.1/lib/python3.5/http/client.py in getresponse(self)
#    1172         try:
#    1173             try:
# -> 1174                 response.begin()
#    1175             except ConnectionError:
#    1176                 self.close()
#
# /Users/hitz/.pyenv/versions/3.5.1/lib/python3.5/http/client.py in begin(self)
#     280         # read until we get a non-100 response
#     281         while True:
# --> 282             version, status, reason = self._read_status()
#     283             if status != CONTINUE:
#     284                 break
#
# /Users/hitz/.pyenv/versions/3.5.1/lib/python3.5/http/client.py in _read_status(self)
#     241
#     242     def _read_status(self):
# --> 243         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     244         if len(line) > _MAXLINE:
#     245             raise LineTooLong("status line")
#
# /Users/hitz/.pyenv/versions/3.5.1/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# /Users/hitz/.pyenv/versions/3.5.1/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     922                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     923                   self.__class__)
# --> 924             return self.read(nbytes, buffer)
#     925         else:
#     926             return socket.recv_into(self, buffer, nbytes, flags)
#
# /Users/hitz/.pyenv/versions/3.5.1/lib/python3.5/ssl.py in read(self, len, buffer)
#     784             raise ValueError("Read on closed or unwrapped SSL socket.")
#     785         try:
# --> 786             return self._sslobj.read(len, buffer)
#     787         except SSLError as x:
#     788             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /Users/hitz/.pyenv/versions/3.5.1/lib/python3.5/ssl.py in read(self, len, buffer)
#     568         """
#     569         if buffer is not None:
# --> 570             v = self._sslobj.read(len, buffer)
#     571         else:
#     572             v = self._sslobj.read(len or 1024)
#
# KeyboardInterrupt:

# %%
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------------- https://test.encodedcc.org//ENCSR480OHP/ -------------------
# Average es_time: 5.931 ± 3.909 ms (n=100)
# Average queue_time: 0.434 ± 0.023 ms (n=100)
# Average render_time: 37.605 ± 2.688 ms (n=100)
# Average wsgi_time: 81.322 ± 71.988 ms (n=100)
# Average total time: 125.293 ± 72.456 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR480OHP/ ---------
# Average es_time: 5.852 ± 2.982 ms (n=100)
# Average queue_time: 0.448 ± 0.029 ms (n=100)
# Average render_time: 37.788 ± 2.565 ms (n=100)
# Average wsgi_time: 74.387 ± 4.053 ms (n=100)
# Average total time: 118.476 ± 7.929 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ------------------- https://test.encodedcc.org//ENCSR000EMB/ -------------------
# Average es_time: 7.885 ± 2.682 ms (n=100)
# Average queue_time: 0.443 ± 0.019 ms (n=100)
# Average render_time: 36.183 ± 2.761 ms (n=100)
# Average wsgi_time: 78.617 ± 77.716 ms (n=100)
# Average total time: 123.129 ± 78.002 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR000EMB/ ---------
# Average es_time: 6.757 ± 3.481 ms (n=100)
# Average queue_time: 0.468 ± 0.035 ms (n=100)
# Average render_time: 36.064 ± 2.637 ms (n=100)
# Average wsgi_time: 69.743 ± 4.932 ms (n=100)
# Average total time: 113.033 ± 9.706 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------- https://test.encodedcc.org//ENCSR323QIP/ -------------------
# Average es_time: 15.421 ± 3.586 ms (n=100)
# Average queue_time: 0.458 ± 0.02 ms (n=100)
# Average render_time: 119.45 ± 2.584 ms (n=100)
# Average wsgi_time: 252.027 ± 117.666 ms (n=100)
# Average total time: 387.356 ± 118.201 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR323QIP/ ---------
# Average es_time: 13.371 ± 2.394 ms (n=100)
# Average queue_time: 0.495 ± 0.039 ms (n=100)
# Average render_time: 119.345 ± 1.976 ms (n=100)
# Average wsgi_time: 278.21 ± 178.792 ms (n=100)
# Average total time: 411.42 ± 179.714 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------------- https://test.encodedcc.org//ENCSR718AXQ/ -------------------
# Average es_time: 5.596 ± 4.633 ms (n=100)
# Average queue_time: 0.449 ± 0.021 ms (n=100)
# Average render_time: 12.874 ± 1.296 ms (n=100)
# Average wsgi_time: 27.931 ± 5.265 ms (n=100)
# Average total time: 46.85 ± 10.441 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR718AXQ/ ---------
# Average es_time: 5.742 ± 6.164 ms (n=100)
# Average queue_time: 0.49 ± 0.038 ms (n=100)
# Average render_time: 13.359 ± 1.417 ms (n=100)
# Average wsgi_time: 28.853 ± 6.752 ms (n=100)
# Average total time: 48.444 ± 13.372 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------------- https://test.encodedcc.org//ENCSR165BGV/ -------------------
# Average es_time: 5.487 ± 0.65 ms (n=100)
# Average queue_time: 0.445 ± 0.021 ms (n=100)
# Average render_time: 23.343 ± 1.912 ms (n=100)
# Average wsgi_time: 45.364 ± 2.361 ms (n=100)
# Average total time: 74.641 ± 4.38 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR165BGV/ ---------
# Average es_time: 5.098 ± 0.203 ms (n=100)
# Average queue_time: 0.459 ± 0.033 ms (n=100)
# Average render_time: 23.273 ± 1.765 ms (n=100)
# Average wsgi_time: 45.008 ± 2.118 ms (n=100)
# Average total time: 73.839 ± 3.801 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------------- https://test.encodedcc.org//ENCSR384KAN/ -------------------
# Average es_time: 7.192 ± 0.114 ms (n=100)
# Average queue_time: 0.439 ± 0.02 ms (n=100)
# Average render_time: 40.453 ± 2.856 ms (n=100)
# Average wsgi_time: 80.399 ± 3.039 ms (n=100)
# Average total time: 128.483 ± 5.819 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR384KAN/ ---------
# Average es_time: 5.826 ± 0.763 ms (n=100)
# Average queue_time: 0.464 ± 0.029 ms (n=100)
# Average render_time: 40.591 ± 2.573 ms (n=100)
# Average wsgi_time: 94.446 ± 104.017 ms (n=100)
# Average total time: 141.327 ± 104.102 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------------- https://test.encodedcc.org//ENCSR330FXL/ -------------------
# Average es_time: 3.737 ± 2.844 ms (n=100)
# Average queue_time: 0.42 ± 0.02 ms (n=100)
# Average render_time: 17.86 ± 1.718 ms (n=100)
# Average wsgi_time: 45.42 ± 76.252 ms (n=100)
# Average total time: 67.438 ± 76.391 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR330FXL/ ---------
# Average es_time: 3.61 ± 3.31 ms (n=100)
# Average queue_time: 0.465 ± 0.043 ms (n=100)
# Average render_time: 18.371 ± 1.853 ms (n=100)
# Average wsgi_time: 35.837 ± 4.174 ms (n=100)
# Average total time: 58.283 ± 8.01 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 25.137 ± 3.099 ms (n=100)
# Average queue_time: 0.468 ± 0.018 ms (n=100)
# Average render_time: 197.621 ± 3.192 ms (n=100)
# Average wsgi_time: 430.701 ± 174.495 ms (n=100)
# Average total time: 653.928 ± 175.388 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR825UNV/ ---------
# Average es_time: 20.776 ± 4.472 ms (n=100)
# Average queue_time: 0.509 ± 0.04 ms (n=100)
# Average render_time: 196.003 ± 2.997 ms (n=100)
# Average wsgi_time: 451.879 ± 237.041 ms (n=100)
# Average total time: 669.167 ± 239.662 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
# Average es_time: 4.049 ± 0.74 ms (n=100)
# Average queue_time: 0.459 ± 0.017 ms (n=100)
# Average render_time: 6.477 ± 1.099 ms (n=100)
# Average wsgi_time: 19.835 ± 1.974 ms (n=100)
# Average total time: 30.82 ± 3.277 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR089EOA/ ---------
# Average es_time: 3.928 ± 0.665 ms (n=100)
# Average queue_time: 0.473 ± 0.039 ms (n=100)
# Average render_time: 6.58 ± 1.163 ms (n=100)
# Average wsgi_time: 19.921 ± 1.983 ms (n=100)
# Average total time: 30.903 ± 3.394 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ------------------- https://test.encodedcc.org//ENCAB830JLB/ -------------------
# Average es_time: 3.552 ± 0.72 ms (n=100)
# Average queue_time: 0.416 ± 0.02 ms (n=100)
# Average render_time: 33.703 ± 3.127 ms (n=100)
# Average wsgi_time: 62.057 ± 3.572 ms (n=100)
# Average total time: 99.728 ± 6.721 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB830JLB/ ---------
# Average es_time: 3.435 ± 0.601 ms (n=100)
# Average queue_time: 0.417 ± 0.025 ms (n=100)
# Average render_time: 34.204 ± 3.254 ms (n=100)
# Average wsgi_time: 71.114 ± 86.194 ms (n=100)
# Average total time: 109.17 ± 86.637 ms (n=100)
#
#
# *** item_type: /ENCAB000BKR/
# ------------------- https://test.encodedcc.org//ENCAB000BKR/ -------------------
# Average es_time: 3.248 ± 2.389 ms (n=100)
# Average queue_time: 0.408 ± 0.026 ms (n=100)
# Average render_time: 15.095 ± 1.157 ms (n=100)
# Average wsgi_time: 29.443 ± 2.901 ms (n=100)
# Average total time: 48.193 ± 5.676 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB000BKR/ ---------
# Average es_time: 2.61 ± 0.417 ms (n=100)
# Average queue_time: 0.414 ± 0.027 ms (n=100)
# Average render_time: 14.832 ± 1.196 ms (n=100)
# Average wsgi_time: 28.507 ± 1.36 ms (n=100)
# Average total time: 46.362 ± 2.518 ms (n=100)
#
#
# *** item_type: /ENCAB284TTY/
# ------------------- https://test.encodedcc.org//ENCAB284TTY/ -------------------
# Average es_time: 4.948 ± 0.697 ms (n=100)
# Average queue_time: 0.409 ± 0.024 ms (n=100)
# Average render_time: 44.011 ± 3.292 ms (n=100)
# Average wsgi_time: 83.549 ± 3.664 ms (n=100)
# Average total time: 132.918 ± 7.075 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB284TTY/ ---------
# Average es_time: 4.145 ± 0.728 ms (n=100)
# Average queue_time: 0.411 ± 0.022 ms (n=100)
# Average render_time: 43.721 ± 3.082 ms (n=100)
# Average wsgi_time: 82.073 ± 3.457 ms (n=100)
# Average total time: 130.351 ± 6.635 ms (n=100)
#
#
# *** item_type: /ENCAB294YUD/
# ------------------- https://test.encodedcc.org//ENCAB294YUD/ -------------------
# Average es_time: 1.943 ± 0.525 ms (n=100)
# Average queue_time: 0.347 ± 0.031 ms (n=100)
# Average render_time: 3.173 ± 0.566 ms (n=100)
# Average wsgi_time: 7.87 ± 0.931 ms (n=100)
# Average total time: 13.333 ± 1.799 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB294YUD/ ---------
# Average es_time: 2.035 ± 0.329 ms (n=100)
# Average queue_time: 0.387 ± 0.035 ms (n=100)
# Average render_time: 3.773 ± 0.785 ms (n=100)
# Average wsgi_time: 8.818 ± 1.078 ms (n=100)
# Average total time: 15.012 ± 1.961 ms (n=100)
#
#
# *** item_type: /ENCAB000AOC/
# ------------------- https://test.encodedcc.org//ENCAB000AOC/ -------------------
# Average es_time: 2.755 ± 0.5 ms (n=100)
# Average queue_time: 0.407 ± 0.026 ms (n=100)
# Average render_time: 20.172 ± 2.412 ms (n=100)
# Average wsgi_time: 36.603 ± 2.609 ms (n=100)
# Average total time: 59.936 ± 5.093 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB000AOC/ ---------
# Average es_time: 2.937 ± 1.67 ms (n=100)
# Average queue_time: 0.41 ± 0.022 ms (n=100)
# Average render_time: 19.265 ± 2.703 ms (n=100)
# Average wsgi_time: 43.943 ± 80.763 ms (n=100)
# Average total time: 66.556 ± 80.804 ms (n=100)
#
#
# *** item_type: /ENCAB301QZF/
# ------------------- https://test.encodedcc.org//ENCAB301QZF/ -------------------
# Average es_time: 2.014 ± 0.337 ms (n=100)
# Average queue_time: 0.382 ± 0.024 ms (n=100)
# Average render_time: 7.67 ± 1.024 ms (n=100)
# Average wsgi_time: 14.576 ± 1.128 ms (n=100)
# Average total time: 24.643 ± 2.192 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB301QZF/ ---------
# Average es_time: 2.254 ± 0.577 ms (n=100)
# Average queue_time: 0.392 ± 0.029 ms (n=100)
# Average render_time: 7.763 ± 1.258 ms (n=100)
# Average wsgi_time: 14.999 ± 1.414 ms (n=100)
# Average total time: 25.408 ± 2.797 ms (n=100)
#
#
# *** item_type: /ENCAB000ANM/
# ------------------- https://test.encodedcc.org//ENCAB000ANM/ -------------------
# Average es_time: 2.75 ± 0.481 ms (n=100)
# Average queue_time: 0.401 ± 0.022 ms (n=100)
# Average render_time: 17.095 ± 2.382 ms (n=100)
# Average wsgi_time: 36.615 ± 44.998 ms (n=100)
# Average total time: 56.861 ± 45.302 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB000ANM/ ---------
# Average es_time: 2.995 ± 0.304 ms (n=100)
# Average queue_time: 0.405 ± 0.025 ms (n=100)
# Average render_time: 17.398 ± 2.339 ms (n=100)
# Average wsgi_time: 32.627 ± 2.519 ms (n=100)
# Average total time: 53.425 ± 4.881 ms (n=100)
#
#
# *** item_type: /ENCAB000ANU/
# ------------------- https://test.encodedcc.org//ENCAB000ANU/ -------------------
# Average es_time: 2.557 ± 0.522 ms (n=100)
# Average queue_time: 0.406 ± 0.025 ms (n=100)
# Average render_time: 12.68 ± 1.301 ms (n=100)
# Average wsgi_time: 24.479 ± 1.616 ms (n=100)
# Average total time: 40.122 ± 2.998 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB000ANU/ ---------
# Average es_time: 2.727 ± 1.753 ms (n=100)
# Average queue_time: 0.405 ± 0.025 ms (n=100)
# Average render_time: 12.797 ± 1.027 ms (n=100)
# Average wsgi_time: 24.81 ± 2.161 ms (n=100)
# Average total time: 40.739 ± 4.025 ms (n=100)
#
#
# *** item_type: /ENCAB445KMF/
# ------------------- https://test.encodedcc.org//ENCAB445KMF/ -------------------
# Average es_time: 2.632 ± 2.165 ms (n=100)
# Average queue_time: 0.389 ± 0.026 ms (n=100)
# Average render_time: 10.951 ± 1.313 ms (n=100)
# Average wsgi_time: 21.243 ± 2.487 ms (n=100)
# Average total time: 35.216 ± 4.91 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB445KMF/ ---------
# Average es_time: 2.285 ± 0.611 ms (n=100)
# Average queue_time: 0.397 ± 0.024 ms (n=100)
# Average render_time: 10.923 ± 1.321 ms (n=100)
# Average wsgi_time: 20.957 ± 1.57 ms (n=100)
# Average total time: 34.561 ± 2.989 ms (n=100)
#
#
# *** item_type: /ENCAB000BAY/
# ------------------- https://test.encodedcc.org//ENCAB000BAY/ -------------------
# Average es_time: 2.873 ± 0.303 ms (n=100)
# Average queue_time: 0.396 ± 0.024 ms (n=100)
# Average render_time: 18.387 ± 2.616 ms (n=100)
# Average wsgi_time: 33.722 ± 2.68 ms (n=100)
# Average total time: 55.378 ± 5.279 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCAB000BAY/ ---------
# Average es_time: 2.607 ± 0.462 ms (n=100)
# Average queue_time: 0.405 ± 0.03 ms (n=100)
# Average render_time: 18.213 ± 2.413 ms (n=100)
# Average wsgi_time: 33.131 ± 2.62 ms (n=100)
# Average total time: 54.357 ± 5.098 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS787TFV/
# ------------------- https://test.encodedcc.org//ENCBS787TFV/ -------------------
# Average es_time: 2.306 ± 0.251 ms (n=100)
# Average queue_time: 0.402 ± 0.03 ms (n=100)
# Average render_time: 3.616 ± 0.504 ms (n=100)
# Average wsgi_time: 9.276 ± 0.965 ms (n=100)
# Average total time: 15.601 ± 1.588 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS787TFV/ ---------
# Average es_time: 2.299 ± 0.298 ms (n=100)
# Average queue_time: 0.408 ± 0.023 ms (n=100)
# Average render_time: 3.725 ± 0.467 ms (n=100)
# Average wsgi_time: 9.442 ± 0.922 ms (n=100)
# Average total time: 15.874 ± 1.536 ms (n=100)
#
#
# *** item_type: /ENCBS676QAV/
# ------------------- https://test.encodedcc.org//ENCBS676QAV/ -------------------
# Average es_time: 2.466 ± 2.78 ms (n=100)
# Average queue_time: 0.36 ± 0.024 ms (n=100)
# Average render_time: 4.105 ± 0.338 ms (n=100)
# Average wsgi_time: 10.19 ± 3.07 ms (n=100)
# Average total time: 17.12 ± 6.018 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS676QAV/ ---------
# Average es_time: 2.744 ± 3.917 ms (n=100)
# Average queue_time: 0.385 ± 0.027 ms (n=100)
# Average render_time: 4.361 ± 0.691 ms (n=100)
# Average wsgi_time: 10.784 ± 4.219 ms (n=100)
# Average total time: 18.274 ± 8.376 ms (n=100)
#
#
# *** item_type: /ENCBS996IWU/
# ------------------- https://test.encodedcc.org//ENCBS996IWU/ -------------------
# Average es_time: 2.08 ± 0.413 ms (n=100)
# Average queue_time: 0.361 ± 0.031 ms (n=100)
# Average render_time: 4.567 ± 0.413 ms (n=100)
# Average wsgi_time: 9.963 ± 0.784 ms (n=100)
# Average total time: 16.971 ± 1.426 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS996IWU/ ---------
# Average es_time: 2.096 ± 0.389 ms (n=100)
# Average queue_time: 0.388 ± 0.026 ms (n=100)
# Average render_time: 4.737 ± 0.644 ms (n=100)
# Average wsgi_time: 10.238 ± 1.054 ms (n=100)
# Average total time: 17.46 ± 1.895 ms (n=100)
#
#
# *** item_type: /ENCBS913XJP/
# ------------------- https://test.encodedcc.org//ENCBS913XJP/ -------------------
# Average es_time: 2.119 ± 0.356 ms (n=100)
# Average queue_time: 0.399 ± 0.028 ms (n=100)
# Average render_time: 3.418 ± 0.227 ms (n=100)
# Average wsgi_time: 8.792 ± 0.559 ms (n=100)
# Average total time: 14.728 ± 0.963 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS913XJP/ ---------
# Average es_time: 2.224 ± 0.355 ms (n=100)
# Average queue_time: 0.4 ± 0.031 ms (n=100)
# Average render_time: 3.649 ± 0.433 ms (n=100)
# Average wsgi_time: 9.126 ± 0.634 ms (n=100)
# Average total time: 15.4 ± 1.153 ms (n=100)
#
#
# *** item_type: /ENCBS565NTN/
# ------------------- https://test.encodedcc.org//ENCBS565NTN/ -------------------
# Average es_time: 2.008 ± 0.428 ms (n=100)
# Average queue_time: 0.381 ± 0.031 ms (n=100)
# Average render_time: 3.477 ± 0.185 ms (n=100)
# Average wsgi_time: 8.566 ± 0.6 ms (n=100)
# Average total time: 14.434 ± 1.094 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS565NTN/ ---------
# Average es_time: 2.039 ± 0.346 ms (n=100)
# Average queue_time: 0.398 ± 0.026 ms (n=100)
# Average render_time: 3.776 ± 0.603 ms (n=100)
# Average wsgi_time: 8.996 ± 0.848 ms (n=100)
# Average total time: 15.208 ± 1.558 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ------------------- https://test.encodedcc.org//ENCBS896YZO/ -------------------
# Average es_time: 3.096 ± 3.639 ms (n=100)
# Average queue_time: 0.381 ± 0.029 ms (n=100)
# Average render_time: 7.408 ± 1.153 ms (n=100)
# Average wsgi_time: 14.788 ± 3.825 ms (n=100)
# Average total time: 25.672 ± 7.588 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS896YZO/ ---------
# Average es_time: 2.916 ± 3.188 ms (n=100)
# Average queue_time: 0.391 ± 0.028 ms (n=100)
# Average render_time: 7.513 ± 1.496 ms (n=100)
# Average wsgi_time: 14.731 ± 3.637 ms (n=100)
# Average total time: 25.551 ± 7.222 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ------------------- https://test.encodedcc.org//ENCBS280NYD/ -------------------
# Average es_time: 2.483 ± 2.779 ms (n=100)
# Average queue_time: 0.36 ± 0.03 ms (n=100)
# Average render_time: 3.609 ± 0.595 ms (n=100)
# Average wsgi_time: 9.24 ± 2.995 ms (n=100)
# Average total time: 15.692 ± 5.887 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS280NYD/ ---------
# Average es_time: 2.486 ± 2.902 ms (n=100)
# Average queue_time: 0.384 ± 0.036 ms (n=100)
# Average render_time: 3.68 ± 0.418 ms (n=100)
# Average wsgi_time: 9.407 ± 3.014 ms (n=100)
# Average total time: 15.957 ± 5.938 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS565NTN/
# ------------------- https://test.encodedcc.org//ENCBS565NTN/ -------------------
# Average es_time: 2.02 ± 0.198 ms (n=100)
# Average queue_time: 0.385 ± 0.026 ms (n=100)
# Average render_time: 3.575 ± 0.31 ms (n=100)
# Average wsgi_time: 8.715 ± 0.481 ms (n=100)
# Average total time: 14.695 ± 0.823 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS565NTN/ ---------
# Average es_time: 1.991 ± 0.221 ms (n=100)
# Average queue_time: 0.402 ± 0.032 ms (n=100)
# Average render_time: 3.604 ± 0.251 ms (n=100)
# Average wsgi_time: 8.724 ± 0.416 ms (n=100)
# Average total time: 14.722 ± 0.707 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ------------------- https://test.encodedcc.org//ENCBS896YZO/ -------------------
# Average es_time: 2.444 ± 0.103 ms (n=100)
# Average queue_time: 0.373 ± 0.027 ms (n=100)
# Average render_time: 6.959 ± 1.187 ms (n=100)
# Average wsgi_time: 13.634 ± 1.174 ms (n=100)
# Average total time: 23.411 ± 2.337 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS896YZO/ ---------
# Average es_time: 2.31 ± 0.109 ms (n=100)
# Average queue_time: 0.393 ± 0.032 ms (n=100)
# Average render_time: 7.647 ± 1.304 ms (n=100)
# Average wsgi_time: 14.278 ± 1.465 ms (n=100)
# Average total time: 24.628 ± 2.763 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ------------------- https://test.encodedcc.org//ENCBS280NYD/ -------------------
# Average es_time: 1.997 ± 0.097 ms (n=100)
# Average queue_time: 0.35 ± 0.023 ms (n=100)
# Average render_time: 3.238 ± 0.302 ms (n=100)
# Average wsgi_time: 8.353 ± 0.567 ms (n=100)
# Average total time: 13.938 ± 0.795 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCBS280NYD/ ---------
# Average es_time: 2.069 ± 0.123 ms (n=100)
# Average queue_time: 0.387 ± 0.03 ms (n=100)
# Average render_time: 3.711 ± 0.546 ms (n=100)
# Average wsgi_time: 9.041 ± 0.806 ms (n=100)
# Average total time: 15.208 ± 1.334 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------- https://test.encodedcc.org//ENCSR323QIP/ -------------------
# Average es_time: 14.968 ± 3.024 ms (n=100)
# Average queue_time: 0.452 ± 0.019 ms (n=100)
# Average render_time: 119.411 ± 2.117 ms (n=100)
# Average wsgi_time: 254.518 ± 134.706 ms (n=100)
# Average total time: 389.349 ± 134.863 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR323QIP/ ---------
# Average es_time: 13.088 ± 2.205 ms (n=100)
# Average queue_time: 0.456 ± 0.022 ms (n=100)
# Average render_time: 119.378 ± 2.313 ms (n=100)
# Average wsgi_time: 260.109 ± 152.737 ms (n=100)
# Average total time: 393.031 ± 153.498 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------------- https://test.encodedcc.org//ENCSR718AXQ/ -------------------
# Average es_time: 4.741 ± 0.503 ms (n=100)
# Average queue_time: 0.438 ± 0.02 ms (n=100)
# Average render_time: 13.093 ± 1.401 ms (n=100)
# Average wsgi_time: 27.403 ± 1.793 ms (n=100)
# Average total time: 45.675 ± 3.166 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR718AXQ/ ---------
# Average es_time: 4.602 ± 1.731 ms (n=100)
# Average queue_time: 0.454 ± 0.032 ms (n=100)
# Average render_time: 13.068 ± 1.504 ms (n=100)
# Average wsgi_time: 27.252 ± 2.503 ms (n=100)
# Average total time: 45.377 ± 4.882 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------------- https://test.encodedcc.org//ENCSR165BGV/ -------------------
# Average es_time: 5.477 ± 0.644 ms (n=100)
# Average queue_time: 0.438 ± 0.019 ms (n=100)
# Average render_time: 23.099 ± 1.981 ms (n=100)
# Average wsgi_time: 45.148 ± 2.476 ms (n=100)
# Average total time: 74.161 ± 4.406 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR165BGV/ ---------
# Average es_time: 12.847 ± 76.0 ms (n=100)
# Average queue_time: 0.457 ± 0.036 ms (n=100)
# Average render_time: 23.216 ± 1.857 ms (n=100)
# Average wsgi_time: 52.899 ± 75.88 ms (n=100)
# Average total time: 89.419 ± 151.858 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------------- https://test.encodedcc.org//ENCSR384KAN/ -------------------
# Average es_time: 7.194 ± 0.116 ms (n=100)
# Average queue_time: 0.435 ± 0.022 ms (n=100)
# Average render_time: 40.15 ± 2.731 ms (n=100)
# Average wsgi_time: 80.11 ± 2.824 ms (n=100)
# Average total time: 127.889 ± 5.473 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR384KAN/ ---------
# Average es_time: 5.763 ± 0.734 ms (n=100)
# Average queue_time: 0.452 ± 0.036 ms (n=100)
# Average render_time: 40.149 ± 2.616 ms (n=100)
# Average wsgi_time: 78.814 ± 2.815 ms (n=100)
# Average total time: 125.178 ± 5.389 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------------- https://test.encodedcc.org//ENCSR330FXL/ -------------------
# Average es_time: 3.236 ± 0.113 ms (n=100)
# Average queue_time: 0.422 ± 0.016 ms (n=100)
# Average render_time: 18.236 ± 1.518 ms (n=100)
# Average wsgi_time: 34.814 ± 1.725 ms (n=100)
# Average total time: 56.708 ± 3.137 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR330FXL/ ---------
# Average es_time: 3.008 ± 0.423 ms (n=100)
# Average queue_time: 0.455 ± 0.045 ms (n=100)
# Average render_time: 18.537 ± 1.728 ms (n=100)
# Average wsgi_time: 35.252 ± 2.081 ms (n=100)
# Average total time: 57.252 ± 3.815 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 24.62 ± 2.15 ms (n=100)
# Average queue_time: 0.467 ± 0.018 ms (n=100)
# Average render_time: 196.698 ± 2.628 ms (n=100)
# Average wsgi_time: 425.498 ± 208.403 ms (n=100)
# Average total time: 647.283 ± 209.21 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR825UNV/ ---------
# Average es_time: 19.892 ± 3.872 ms (n=100)
# Average queue_time: 0.493 ± 0.039 ms (n=100)
# Average render_time: 195.302 ± 2.801 ms (n=100)
# Average wsgi_time: 433.02 ± 209.648 ms (n=100)
# Average total time: 648.707 ± 210.618 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
# Average es_time: 3.978 ± 0.684 ms (n=100)
# Average queue_time: 0.459 ± 0.018 ms (n=100)
# Average render_time: 6.386 ± 1.11 ms (n=100)
# Average wsgi_time: 19.541 ± 1.383 ms (n=100)
# Average total time: 30.364 ± 2.584 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR089EOA/ ---------
# Average es_time: 3.855 ± 0.579 ms (n=100)
# Average queue_time: 0.483 ± 0.041 ms (n=100)
# Average render_time: 6.647 ± 1.003 ms (n=100)
# Average wsgi_time: 19.864 ± 1.537 ms (n=100)
# Average total time: 30.849 ± 2.686 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 24.711 ± 2.108 ms (n=100)
# Average queue_time: 0.469 ± 0.015 ms (n=100)
# Average render_time: 197.89 ± 2.165 ms (n=100)
# Average wsgi_time: 472.459 ± 274.878 ms (n=100)
# Average total time: 695.529 ± 274.874 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR825UNV/ ---------
# Average es_time: 20.325 ± 4.916 ms (n=100)
# Average queue_time: 0.496 ± 0.041 ms (n=100)
# Average render_time: 196.222 ± 2.727 ms (n=100)
# Average wsgi_time: 485.868 ± 275.985 ms (n=100)
# Average total time: 702.911 ± 276.546 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
# Average es_time: 3.966 ± 0.673 ms (n=100)
# Average queue_time: 0.461 ± 0.015 ms (n=100)
# Average render_time: 6.347 ± 1.106 ms (n=100)
# Average wsgi_time: 19.589 ± 1.563 ms (n=100)
# Average total time: 30.363 ± 2.67 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org//ENCSR089EOA/ ---------
# Average es_time: 4.066 ± 1.982 ms (n=100)
# Average queue_time: 0.487 ± 0.037 ms (n=100)
# Average render_time: 6.545 ± 1.002 ms (n=100)
# Average wsgi_time: 20.145 ± 2.333 ms (n=100)
# Average total time: 31.243 ± 4.486 ms (n=100)

# %%
qa.check_response_time(item_types=['publication-data/ENCSR825UNV?format=json','publication-data/ENCSR089EOA?format=json'], n=100)
# Out:
# Checking response time
#
# *** item_type: publication-data/ENCSR825UNV?format=json
# ----- https://test.encodedcc.org/publication-data/ENCSR825UNV?format=json ------
# Average es_time: 25.261 ± 2.708 ms (n=100)
# Average queue_time: 0.461 ± 0.016 ms (n=100)
# Average wsgi_time: 276.555 ± 265.552 ms (n=100)
# Average total time: 302.277 ± 265.39 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org/publication-data/ENCSR825UNV?format=json ---------
# Average es_time: 21.717 ± 4.556 ms (n=100)
# Average queue_time: 0.473 ± 0.027 ms (n=100)
# Average wsgi_time: 255.384 ± 250.199 ms (n=100)
# Average total time: 277.574 ± 250.748 ms (n=100)
#
#
# *** item_type: publication-data/ENCSR089EOA?format=json
# ----- https://test.encodedcc.org/publication-data/ENCSR089EOA?format=json ------
# Average es_time: 3.754 ± 0.699 ms (n=100)
# Average queue_time: 0.368 ± 0.045 ms (n=100)
# Average wsgi_time: 12.637 ± 1.137 ms (n=100)
# Average total time: 16.759 ± 1.71 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org/publication-data/ENCSR089EOA?format=json ---------
# Average es_time: 3.794 ± 0.607 ms (n=100)
# Average queue_time: 0.37 ± 0.041 ms (n=100)
# Average wsgi_time: 12.863 ± 1.294 ms (n=100)
# Average total time: 17.027 ± 1.608 ms (n=100)

# %%
qa.check_response_time(item_types=['experiments/ENCSR323QIP/?format=json','experiments/ENCSR718AXQ/?format=json'], n=100)
# Out:
# Checking response time
#
# *** item_type: experiments/ENCSR323QIP/?format=json
# ------- https://test.encodedcc.org/experiments/ENCSR323QIP/?format=json --------
# Average es_time: 16.339 ± 5.408 ms (n=100)
# Average queue_time: 0.447 ± 0.044 ms (n=100)
# Average wsgi_time: 131.665 ± 113.345 ms (n=100)
# Average total time: 148.451 ± 113.898 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org/experiments/ENCSR323QIP/?format=json ---------
# Average es_time: 16.338 ± 5.028 ms (n=100)
# Average queue_time: 0.524 ± 0.047 ms (n=100)
# Average wsgi_time: 140.484 ± 130.188 ms (n=100)
# Average total time: 157.346 ± 129.976 ms (n=100)
#
#
# *** item_type: experiments/ENCSR718AXQ/?format=json
# ------- https://test.encodedcc.org/experiments/ENCSR718AXQ/?format=json --------
# Average es_time: 5.704 ± 4.427 ms (n=100)
# Average queue_time: 0.358 ± 0.04 ms (n=100)
# Average wsgi_time: 15.28 ± 4.703 ms (n=100)
# Average total time: 21.342 ± 9.069 ms (n=100)
# --------- https://encd-4449-annotation-files-embedding-a75e5da90-hitz.demo.encodedcc.org/experiments/ENCSR718AXQ/?format=json ---------
# Average es_time: 5.442 ± 4.766 ms (n=100)
# Average queue_time: 0.401 ± 0.063 ms (n=100)
# Average wsgi_time: 15.263 ± 5.257 ms (n=100)
# Average total time: 21.106 ± 9.963 ms (n=100)
