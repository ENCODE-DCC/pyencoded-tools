# %%
import sys
sys.path.append('../..')
import qancode

# %%
#comparing to v65rc2 site
qa = qancode.QANCODE(rc_url="https://facet-performance-fytanaka.demo.encodedcc.org/", prod_url="https://test.encodedcc.org/")

# %%
qa.check_response_time(item_types=["/", "/search/?type=Experiment"], n=100)
# Out:
# Checking response time
#
# *** item_type: /
# ------------------------- https://test.encodedcc.org// -------------------------
# Average es_time: 1.738 ± 0.095 ms (n=100)
# Average queue_time: 0.43 ± 0.042 ms (n=100)
# Average render_time: 3.617 ± 0.923 ms (n=100)
# Average wsgi_time: 9.185 ± 1.161 ms (n=100)
# Average total time: 14.971 ± 2.118 ms (n=100)
# ----------- https://facet-performance-fytanaka.demo.encodedcc.org// ------------
# Average es_time: 1.338 ± 0.875 ms (n=100)
# Average queue_time: 0.565 ± 0.037 ms (n=100)
# Average render_time: 6.443 ± 24.828 ms (n=100)
# Average wsgi_time: 11.715 ± 25.889 ms (n=100)
# Average total time: 20.061 ± 51.617 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment
# ------------- https://test.encodedcc.org//search/?type=Experiment --------------
# Average es_time: 52.522 ± 7.638 ms (n=100)
# Average queue_time: 0.535 ± 0.052 ms (n=100)
# Average render_time: 57.133 ± 11.633 ms (n=100)
# Average wsgi_time: 123.558 ± 37.141 ms (n=100)
# Average total time: 233.747 ± 44.144 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//search/?type=Experiment ---------
# Average es_time: 43.181 ± 9.412 ms (n=100)
# Average queue_time: 0.571 ± 0.053 ms (n=100)
# Average render_time: 57.275 ± 12.874 ms (n=100)
# Average wsgi_time: 111.401 ± 17.164 ms (n=100)
# Average total time: 212.428 ± 33.924 ms (n=100)

# %%
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ------------- https://test.encodedcc.org//search/?searchTerm=K562 --------------
# Average es_time: 70.956 ± 11.54 ms (n=100)
# Average queue_time: 0.479 ± 0.031 ms (n=100)
# Average render_time: 11.387 ± 2.092 ms (n=100)
# Average wsgi_time: 87.588 ± 11.922 ms (n=100)
# Average total time: 170.41 ± 23.591 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//search/?searchTerm=K562 ---------
# Average es_time: 47.498 ± 5.282 ms (n=100)
# Average queue_time: 0.565 ± 0.022 ms (n=100)
# Average render_time: 13.612 ± 26.905 ms (n=100)
# Average wsgi_time: 68.319 ± 34.768 ms (n=100)
# Average total time: 129.994 ± 58.971 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# ---------- https://test.encodedcc.org//search/?searchTerm=DNA+binding ----------
# Average es_time: 77.761 ± 10.753 ms (n=100)
# Average queue_time: 0.406 ± 0.033 ms (n=100)
# Average render_time: 10.558 ± 1.995 ms (n=100)
# Average wsgi_time: 92.798 ± 10.99 ms (n=100)
# Average total time: 181.523 ± 22.006 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 49.909 ± 3.543 ms (n=100)
# Average queue_time: 0.562 ± 0.012 ms (n=100)
# Average render_time: 10.868 ± 2.378 ms (n=100)
# Average wsgi_time: 65.552 ± 4.33 ms (n=100)
# Average total time: 126.89 ± 8.681 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=human
# ------------- https://test.encodedcc.org//search/?searchTerm=human -------------
# Average es_time: 78.502 ± 12.276 ms (n=100)
# Average queue_time: 0.474 ± 0.046 ms (n=100)
# Average render_time: 13.975 ± 2.478 ms (n=100)
# Average wsgi_time: 97.434 ± 12.466 ms (n=100)
# Average total time: 190.386 ± 24.872 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//search/?searchTerm=human ---------
# Average es_time: 57.411 ± 5.894 ms (n=100)
# Average queue_time: 0.568 ± 0.023 ms (n=100)
# Average render_time: 16.413 ± 26.947 ms (n=100)
# Average wsgi_time: 85.955 ± 60.965 ms (n=100)
# Average total time: 160.347 ± 79.832 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# ----------- https://test.encodedcc.org//search/?searchTerm=H3K36me3 ------------
# Average es_time: 79.282 ± 11.685 ms (n=100)
# Average queue_time: 0.413 ± 0.052 ms (n=100)
# Average render_time: 10.857 ± 2.396 ms (n=100)
# Average wsgi_time: 98.591 ± 39.154 ms (n=100)
# Average total time: 189.143 ± 43.379 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//search/?searchTerm=H3K36me3 ---------
# Average es_time: 51.724 ± 4.843 ms (n=100)
# Average queue_time: 0.567 ± 0.014 ms (n=100)
# Average render_time: 11.895 ± 2.818 ms (n=100)
# Average wsgi_time: 68.586 ± 5.288 ms (n=100)
# Average total time: 132.771 ± 10.582 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=CTCF
# ------------- https://test.encodedcc.org//search/?searchTerm=CTCF --------------
# Average es_time: 85.113 ± 10.595 ms (n=100)
# Average queue_time: 0.421 ± 0.049 ms (n=100)
# Average render_time: 11.39 ± 2.003 ms (n=100)
# Average wsgi_time: 101.249 ± 11.11 ms (n=100)
# Average total time: 198.173 ± 22.162 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//search/?searchTerm=CTCF ---------
# Average es_time: 53.019 ± 5.046 ms (n=100)
# Average queue_time: 0.567 ± 0.016 ms (n=100)
# Average render_time: 11.891 ± 2.129 ms (n=100)
# Average wsgi_time: 72.173 ± 23.536 ms (n=100)
# Average total time: 137.65 ± 25.094 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------------- https://test.encodedcc.org//ENCSR255XZG/ -------------------
# Average es_time: 11.969 ± 5.512 ms (n=50)
# Average queue_time: 0.505 ± 0.067 ms (n=50)
# Average render_time: 144.079 ± 81.526 ms (n=50)
# Average wsgi_time: 276.356 ± 123.263 ms (n=50)
# Average total time: 432.909 ± 199.95 ms (n=50)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR255XZG/ ------
# Average es_time: 6.363 ± 3.125 ms (n=50)
# Average queue_time: 0.583 ± 0.043 ms (n=50)
# Average render_time: 144.736 ± 81.83 ms (n=50)
# Average wsgi_time: 270.54 ± 122.956 ms (n=50)
# Average total time: 422.223 ± 191.929 ms (n=50)
#
#
# *** item_type: /ENCSR749ILN/
# ------------------- https://test.encodedcc.org//ENCSR749ILN/ -------------------
# Average es_time: 5.396 ± 2.886 ms (n=50)
# Average queue_time: 0.474 ± 0.039 ms (n=50)
# Average render_time: 24.744 ± 2.086 ms (n=50)
# Average wsgi_time: 50.458 ± 4.409 ms (n=50)
# Average total time: 81.072 ± 8.536 ms (n=50)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR749ILN/ ------
# Average es_time: 3.404 ± 2.128 ms (n=50)
# Average queue_time: 0.572 ± 0.014 ms (n=50)
# Average render_time: 25.422 ± 2.162 ms (n=50)
# Average wsgi_time: 49.916 ± 3.815 ms (n=50)
# Average total time: 79.315 ± 6.857 ms (n=50)
#
#
# *** item_type: /ENCSR688GVV/
# ------------------- https://test.encodedcc.org//ENCSR688GVV/ -------------------
# Average es_time: 9.881 ± 3.884 ms (n=50)
# Average queue_time: 0.491 ± 0.034 ms (n=50)
# Average render_time: 54.772 ± 2.919 ms (n=50)
# Average wsgi_time: 126.569 ± 99.777 ms (n=50)
# Average total time: 191.714 ± 100.406 ms (n=50)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR688GVV/ ------
# Average es_time: 5.465 ± 1.671 ms (n=50)
# Average queue_time: 0.572 ± 0.015 ms (n=50)
# Average render_time: 55.823 ± 2.967 ms (n=50)
# Average wsgi_time: 110.399 ± 3.701 ms (n=50)
# Average total time: 172.259 ± 7.167 ms (n=50)
#
#
# *** item_type: /ENCSR301HAG/
# ------------------- https://test.encodedcc.org//ENCSR301HAG/ -------------------
# Average es_time: 3.069 ± 1.83 ms (n=50)
# Average queue_time: 0.492 ± 0.04 ms (n=50)
# Average render_time: 11.964 ± 34.543 ms (n=50)
# Average wsgi_time: 21.53 ± 36.692 ms (n=50)
# Average total time: 37.056 ± 73.072 ms (n=50)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR301HAG/ ------
# Average es_time: 1.709 ± 0.04 ms (n=50)
# Average queue_time: 0.56 ± 0.02 ms (n=50)
# Average render_time: 6.84 ± 0.86 ms (n=50)
# Average wsgi_time: 15.249 ± 1.359 ms (n=50)
# Average total time: 24.358 ± 2.167 ms (n=50)
#
#
# *** item_type: /ENCSR315NAC/
# ------------------- https://test.encodedcc.org//ENCSR315NAC/ -------------------
# Average es_time: 10.597 ± 6.435 ms (n=50)
# Average queue_time: 0.547 ± 0.057 ms (n=50)
# Average render_time: 119.388 ± 113.965 ms (n=50)
# Average wsgi_time: 167.401 ± 118.798 ms (n=50)
# Average total time: 297.934 ± 236.046 ms (n=50)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR315NAC/ ------
# Average es_time: 7.916 ± 5.109 ms (n=50)
# Average queue_time: 0.633 ± 0.076 ms (n=50)
# Average render_time: 148.537 ± 125.353 ms (n=50)
# Average wsgi_time: 196.948 ± 132.41 ms (n=50)
# Average total time: 354.034 ± 261.415 ms (n=50)
#
#
# *** item_type: /ENCSR856JJB/
# ------------------- https://test.encodedcc.org//ENCSR856JJB/ -------------------
# Average es_time: 11.658 ± 7.002 ms (n=50)
# Average queue_time: 0.584 ± 0.063 ms (n=50)
# Average render_time: 146.696 ± 122.561 ms (n=50)
# Average wsgi_time: 190.858 ± 130.254 ms (n=50)
# Average total time: 349.795 ± 258.645 ms (n=50)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR856JJB/ ------
# Average es_time: 6.177 ± 4.068 ms (n=50)
# Average queue_time: 0.622 ± 0.06 ms (n=50)
# Average render_time: 125.794 ± 121.257 ms (n=50)
# Average wsgi_time: 164.852 ± 125.907 ms (n=50)
# Average total time: 297.446 ± 249.904 ms (n=50)

# %%
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------------- https://test.encodedcc.org//ENCSR480OHP/ -------------------
# Average es_time: 5.778 ± 3.032 ms (n=100)
# Average queue_time: 0.474 ± 0.053 ms (n=100)
# Average render_time: 47.942 ± 48.158 ms (n=100)
# Average wsgi_time: 87.858 ± 50.993 ms (n=100)
# Average total time: 142.051 ± 101.142 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR480OHP/ ------
# Average es_time: 3.483 ± 2.207 ms (n=100)
# Average queue_time: 0.565 ± 0.037 ms (n=100)
# Average render_time: 48.841 ± 49.791 ms (n=100)
# Average wsgi_time: 87.379 ± 52.279 ms (n=100)
# Average total time: 140.268 ± 103.514 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ------------------- https://test.encodedcc.org//ENCSR000EMB/ -------------------
# Average es_time: 6.848 ± 2.198 ms (n=100)
# Average queue_time: 0.485 ± 0.04 ms (n=100)
# Average render_time: 35.628 ± 2.392 ms (n=100)
# Average wsgi_time: 72.937 ± 3.76 ms (n=100)
# Average total time: 115.898 ± 7.186 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR000EMB/ ------
# Average es_time: 4.064 ± 1.582 ms (n=100)
# Average queue_time: 0.561 ± 0.017 ms (n=100)
# Average render_time: 35.897 ± 2.837 ms (n=100)
# Average wsgi_time: 78.774 ± 81.502 ms (n=100)
# Average total time: 119.297 ± 82.247 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------- https://test.encodedcc.org//ENCSR323QIP/ -------------------
# Average es_time: 15.152 ± 22.973 ms (n=100)
# Average queue_time: 0.487 ± 0.041 ms (n=100)
# Average render_time: 125.148 ± 48.562 ms (n=100)
# Average wsgi_time: 264.265 ± 125.846 ms (n=100)
# Average total time: 405.052 ± 155.662 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR323QIP/ ------
# Average es_time: 6.447 ± 2.028 ms (n=100)
# Average queue_time: 0.56 ± 0.028 ms (n=100)
# Average render_time: 122.264 ± 35.578 ms (n=100)
# Average wsgi_time: 271.403 ± 160.112 ms (n=100)
# Average total time: 400.675 ± 172.315 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------------- https://test.encodedcc.org//ENCSR718AXQ/ -------------------
# Average es_time: 5.341 ± 2.599 ms (n=100)
# Average queue_time: 0.473 ± 0.039 ms (n=100)
# Average render_time: 12.406 ± 1.229 ms (n=100)
# Average wsgi_time: 29.156 ± 3.357 ms (n=100)
# Average total time: 47.377 ± 6.426 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR718AXQ/ ------
# Average es_time: 3.284 ± 1.705 ms (n=100)
# Average queue_time: 0.556 ± 0.019 ms (n=100)
# Average render_time: 12.219 ± 1.106 ms (n=100)
# Average wsgi_time: 27.077 ± 2.767 ms (n=100)
# Average total time: 43.136 ± 5.068 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------------- https://test.encodedcc.org//ENCSR165BGV/ -------------------
# Average es_time: 6.0 ± 2.561 ms (n=100)
# Average queue_time: 0.489 ± 0.055 ms (n=100)
# Average render_time: 42.991 ± 67.413 ms (n=100)
# Average wsgi_time: 68.188 ± 70.003 ms (n=100)
# Average total time: 117.668 ± 139.09 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR165BGV/ ------
# Average es_time: 3.618 ± 1.654 ms (n=100)
# Average queue_time: 0.569 ± 0.046 ms (n=100)
# Average render_time: 46.662 ± 73.326 ms (n=100)
# Average wsgi_time: 69.871 ± 74.975 ms (n=100)
# Average total time: 120.72 ± 149.216 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------------- https://test.encodedcc.org//ENCSR384KAN/ -------------------
# Average es_time: 7.046 ± 2.65 ms (n=100)
# Average queue_time: 0.477 ± 0.052 ms (n=100)
# Average render_time: 47.711 ± 42.004 ms (n=100)
# Average wsgi_time: 91.585 ± 43.255 ms (n=100)
# Average total time: 146.82 ± 85.979 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR384KAN/ ------
# Average es_time: 4.689 ± 2.725 ms (n=100)
# Average queue_time: 0.577 ± 0.044 ms (n=100)
# Average render_time: 54.786 ± 55.73 ms (n=100)
# Average wsgi_time: 97.275 ± 59.222 ms (n=100)
# Average total time: 157.326 ± 117.169 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------------- https://test.encodedcc.org//ENCSR330FXL/ -------------------
# Average es_time: 3.134 ± 3.188 ms (n=100)
# Average queue_time: 0.441 ± 0.042 ms (n=100)
# Average render_time: 19.425 ± 1.881 ms (n=100)
# Average wsgi_time: 38.925 ± 4.032 ms (n=100)
# Average total time: 61.924 ± 7.887 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR330FXL/ ------
# Average es_time: 1.87 ± 1.522 ms (n=100)
# Average queue_time: 0.558 ± 0.014 ms (n=100)
# Average render_time: 19.205 ± 1.62 ms (n=100)
# Average wsgi_time: 37.309 ± 2.567 ms (n=100)
# Average total time: 58.942 ± 4.798 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 25.935 ± 7.256 ms (n=100)
# Average queue_time: 0.595 ± 0.063 ms (n=100)
# Average render_time: 308.278 ± 124.055 ms (n=100)
# Average wsgi_time: 638.445 ± 190.687 ms (n=100)
# Average total time: 973.253 ± 220.238 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR825UNV/ ------
# Average es_time: 16.933 ± 5.644 ms (n=100)
# Average queue_time: 0.702 ± 0.053 ms (n=100)
# Average render_time: 345.672 ± 125.76 ms (n=100)
# Average wsgi_time: 686.916 ± 243.49 ms (n=100)
# Average total time: 1050.223 ± 370.914 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
# Average es_time: 3.742 ± 1.802 ms (n=100)
# Average queue_time: 0.526 ± 0.072 ms (n=100)
# Average render_time: 14.452 ± 40.811 ms (n=100)
# Average wsgi_time: 28.613 ± 42.616 ms (n=100)
# Average total time: 47.333 ± 84.904 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR089EOA/ ------
# Average es_time: 2.365 ± 1.623 ms (n=100)
# Average queue_time: 0.586 ± 0.032 ms (n=100)
# Average render_time: 15.018 ± 43.645 ms (n=100)
# Average wsgi_time: 28.011 ± 44.566 ms (n=100)
# Average total time: 45.979 ± 88.778 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ------------------- https://test.encodedcc.org//ENCAB830JLB/ -------------------
# Average es_time: 3.149 ± 1.252 ms (n=100)
# Average queue_time: 0.462 ± 0.039 ms (n=100)
# Average render_time: 33.066 ± 2.898 ms (n=100)
# Average wsgi_time: 64.594 ± 3.608 ms (n=100)
# Average total time: 101.27 ± 6.633 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB830JLB/ ------
# Average es_time: 1.704 ± 0.154 ms (n=100)
# Average queue_time: 0.577 ± 0.018 ms (n=100)
# Average render_time: 34.741 ± 3.452 ms (n=100)
# Average wsgi_time: 73.564 ± 71.539 ms (n=100)
# Average total time: 110.586 ± 72.0 ms (n=100)
#
#
# *** item_type: /ENCAB000BKR/
# ------------------- https://test.encodedcc.org//ENCAB000BKR/ -------------------
# Average es_time: 2.297 ± 0.286 ms (n=100)
# Average queue_time: 0.432 ± 0.045 ms (n=100)
# Average render_time: 13.293 ± 1.062 ms (n=100)
# Average wsgi_time: 27.541 ± 1.484 ms (n=100)
# Average total time: 43.563 ± 2.507 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB000BKR/ ------
# Average es_time: 1.42 ± 0.16 ms (n=100)
# Average queue_time: 0.574 ± 0.015 ms (n=100)
# Average render_time: 13.849 ± 0.9 ms (n=100)
# Average wsgi_time: 27.748 ± 1.454 ms (n=100)
# Average total time: 43.59 ± 2.27 ms (n=100)
#
#
# *** item_type: /ENCAB284TTY/
# ------------------- https://test.encodedcc.org//ENCAB284TTY/ -------------------
# Average es_time: 3.664 ± 0.442 ms (n=100)
# Average queue_time: 0.436 ± 0.04 ms (n=100)
# Average render_time: 42.146 ± 2.037 ms (n=100)
# Average wsgi_time: 97.491 ± 104.217 ms (n=100)
# Average total time: 143.738 ± 104.4 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB284TTY/ ------
# Average es_time: 2.06 ± 0.042 ms (n=100)
# Average queue_time: 0.568 ± 0.014 ms (n=100)
# Average render_time: 43.738 ± 2.866 ms (n=100)
# Average wsgi_time: 84.746 ± 3.131 ms (n=100)
# Average total time: 131.112 ± 5.886 ms (n=100)
#
#
# *** item_type: /ENCAB294YUD/
# ------------------- https://test.encodedcc.org//ENCAB294YUD/ -------------------
# Average es_time: 1.606 ± 0.349 ms (n=100)
# Average queue_time: 0.392 ± 0.036 ms (n=100)
# Average render_time: 3.074 ± 0.528 ms (n=100)
# Average wsgi_time: 7.418 ± 0.673 ms (n=100)
# Average total time: 12.49 ± 1.303 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB294YUD/ ------
# Average es_time: 1.17 ± 0.24 ms (n=100)
# Average queue_time: 0.571 ± 0.02 ms (n=100)
# Average render_time: 3.03 ± 0.442 ms (n=100)
# Average wsgi_time: 7.123 ± 0.692 ms (n=100)
# Average total time: 11.892 ± 1.138 ms (n=100)
#
#
# *** item_type: /ENCAB000AOC/
# ------------------- https://test.encodedcc.org//ENCAB000AOC/ -------------------
# Average es_time: 2.53 ± 0.266 ms (n=100)
# Average queue_time: 0.443 ± 0.043 ms (n=100)
# Average render_time: 20.123 ± 1.94 ms (n=100)
# Average wsgi_time: 37.703 ± 2.303 ms (n=100)
# Average total time: 60.8 ± 4.225 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB000AOC/ ------
# Average es_time: 1.55 ± 0.137 ms (n=100)
# Average queue_time: 0.571 ± 0.023 ms (n=100)
# Average render_time: 21.182 ± 1.86 ms (n=100)
# Average wsgi_time: 38.603 ± 2.241 ms (n=100)
# Average total time: 61.906 ± 3.954 ms (n=100)
#
#
# *** item_type: /ENCAB301QZF/
# ------------------- https://test.encodedcc.org//ENCAB301QZF/ -------------------
# Average es_time: 1.798 ± 0.283 ms (n=100)
# Average queue_time: 0.386 ± 0.044 ms (n=100)
# Average render_time: 6.78 ± 0.442 ms (n=100)
# Average wsgi_time: 13.779 ± 0.639 ms (n=100)
# Average total time: 22.744 ± 1.17 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB301QZF/ ------
# Average es_time: 1.224 ± 0.14 ms (n=100)
# Average queue_time: 0.555 ± 0.014 ms (n=100)
# Average render_time: 6.999 ± 0.529 ms (n=100)
# Average wsgi_time: 13.874 ± 0.767 ms (n=100)
# Average total time: 22.653 ± 1.197 ms (n=100)
#
#
# *** item_type: /ENCAB000ANM/
# ------------------- https://test.encodedcc.org//ENCAB000ANM/ -------------------
# Average es_time: 2.419 ± 0.213 ms (n=100)
# Average queue_time: 0.45 ± 0.037 ms (n=100)
# Average render_time: 15.737 ± 1.221 ms (n=100)
# Average wsgi_time: 31.466 ± 1.669 ms (n=100)
# Average total time: 50.073 ± 2.882 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB000ANM/ ------
# Average es_time: 1.471 ± 0.127 ms (n=100)
# Average queue_time: 0.564 ± 0.019 ms (n=100)
# Average render_time: 16.331 ± 1.166 ms (n=100)
# Average wsgi_time: 31.469 ± 1.642 ms (n=100)
# Average total time: 49.835 ± 2.608 ms (n=100)
#
#
# *** item_type: /ENCAB000ANU/
# ------------------- https://test.encodedcc.org//ENCAB000ANU/ -------------------
# Average es_time: 2.267 ± 0.275 ms (n=100)
# Average queue_time: 0.428 ± 0.04 ms (n=100)
# Average render_time: 11.424 ± 0.727 ms (n=100)
# Average wsgi_time: 23.507 ± 1.125 ms (n=100)
# Average total time: 37.626 ± 1.847 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB000ANU/ ------
# Average es_time: 1.425 ± 0.545 ms (n=100)
# Average queue_time: 0.563 ± 0.019 ms (n=100)
# Average render_time: 11.856 ± 0.796 ms (n=100)
# Average wsgi_time: 23.468 ± 1.341 ms (n=100)
# Average total time: 37.312 ± 2.159 ms (n=100)
#
#
# *** item_type: /ENCAB445KMF/
# ------------------- https://test.encodedcc.org//ENCAB445KMF/ -------------------
# Average es_time: 1.983 ± 0.249 ms (n=100)
# Average queue_time: 0.399 ± 0.03 ms (n=100)
# Average render_time: 10.224 ± 0.471 ms (n=100)
# Average wsgi_time: 20.805 ± 0.851 ms (n=100)
# Average total time: 33.411 ± 1.257 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB445KMF/ ------
# Average es_time: 1.319 ± 0.105 ms (n=100)
# Average queue_time: 0.556 ± 0.014 ms (n=100)
# Average render_time: 10.681 ± 0.913 ms (n=100)
# Average wsgi_time: 21.018 ± 1.411 ms (n=100)
# Average total time: 33.575 ± 2.256 ms (n=100)
#
#
# *** item_type: /ENCAB000BAY/
# ------------------- https://test.encodedcc.org//ENCAB000BAY/ -------------------
# Average es_time: 2.37 ± 0.288 ms (n=100)
# Average queue_time: 0.401 ± 0.03 ms (n=100)
# Average render_time: 16.52 ± 1.277 ms (n=100)
# Average wsgi_time: 32.302 ± 1.46 ms (n=100)
# Average total time: 51.593 ± 2.704 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCAB000BAY/ ------
# Average es_time: 1.435 ± 0.043 ms (n=100)
# Average queue_time: 0.556 ± 0.016 ms (n=100)
# Average render_time: 17.059 ± 1.506 ms (n=100)
# Average wsgi_time: 32.455 ± 1.821 ms (n=100)
# Average total time: 51.506 ± 3.197 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS787TFV/
# ------------------- https://test.encodedcc.org//ENCBS787TFV/ -------------------
# Average es_time: 2.098 ± 2.092 ms (n=100)
# Average queue_time: 0.41 ± 0.035 ms (n=100)
# Average render_time: 3.619 ± 0.464 ms (n=100)
# Average wsgi_time: 9.142 ± 2.769 ms (n=100)
# Average total time: 15.268 ± 5.111 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS787TFV/ ------
# Average es_time: 1.419 ± 1.589 ms (n=100)
# Average queue_time: 0.568 ± 0.017 ms (n=100)
# Average render_time: 3.831 ± 0.432 ms (n=100)
# Average wsgi_time: 8.896 ± 2.202 ms (n=100)
# Average total time: 14.714 ± 4.041 ms (n=100)
#
#
# *** item_type: /ENCBS676QAV/
# ------------------- https://test.encodedcc.org//ENCBS676QAV/ -------------------
# Average es_time: 2.27 ± 3.58 ms (n=100)
# Average queue_time: 0.387 ± 0.038 ms (n=100)
# Average render_time: 4.299 ± 0.376 ms (n=100)
# Average wsgi_time: 10.326 ± 3.877 ms (n=100)
# Average total time: 17.282 ± 7.64 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS676QAV/ ------
# Average es_time: 1.477 ± 1.747 ms (n=100)
# Average queue_time: 0.561 ± 0.021 ms (n=100)
# Average render_time: 4.495 ± 0.369 ms (n=100)
# Average wsgi_time: 10.022 ± 2.129 ms (n=100)
# Average total time: 16.555 ± 4.044 ms (n=100)
#
#
# *** item_type: /ENCBS996IWU/
# ------------------- https://test.encodedcc.org//ENCBS996IWU/ -------------------
# Average es_time: 2.14 ± 2.195 ms (n=100)
# Average queue_time: 0.394 ± 0.036 ms (n=100)
# Average render_time: 3.813 ± 0.273 ms (n=100)
# Average wsgi_time: 9.206 ± 2.422 ms (n=100)
# Average total time: 15.552 ± 4.752 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS996IWU/ ------
# Average es_time: 1.509 ± 2.03 ms (n=100)
# Average queue_time: 0.558 ± 0.015 ms (n=100)
# Average render_time: 4.008 ± 0.298 ms (n=100)
# Average wsgi_time: 13.583 ± 46.111 ms (n=100)
# Average total time: 19.658 ± 46.222 ms (n=100)
#
#
# *** item_type: /ENCBS913XJP/
# ------------------- https://test.encodedcc.org//ENCBS913XJP/ -------------------
# Average es_time: 1.846 ± 0.206 ms (n=100)
# Average queue_time: 0.402 ± 0.044 ms (n=100)
# Average render_time: 3.436 ± 0.131 ms (n=100)
# Average wsgi_time: 8.516 ± 0.36 ms (n=100)
# Average total time: 14.2 ± 0.605 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS913XJP/ ------
# Average es_time: 1.219 ± 0.152 ms (n=100)
# Average queue_time: 0.559 ± 0.016 ms (n=100)
# Average render_time: 3.651 ± 0.13 ms (n=100)
# Average wsgi_time: 8.414 ± 0.357 ms (n=100)
# Average total time: 13.843 ± 0.493 ms (n=100)
#
#
# *** item_type: /ENCBS565NTN/
# ------------------- https://test.encodedcc.org//ENCBS565NTN/ -------------------
# Average es_time: 2.225 ± 2.942 ms (n=100)
# Average queue_time: 0.401 ± 0.041 ms (n=100)
# Average render_time: 3.537 ± 0.217 ms (n=100)
# Average wsgi_time: 8.904 ± 3.13 ms (n=100)
# Average total time: 15.066 ± 6.176 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS565NTN/ ------
# Average es_time: 1.421 ± 1.536 ms (n=100)
# Average queue_time: 0.561 ± 0.014 ms (n=100)
# Average render_time: 3.772 ± 0.397 ms (n=100)
# Average wsgi_time: 8.583 ± 1.788 ms (n=100)
# Average total time: 14.336 ± 3.427 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ------------------- https://test.encodedcc.org//ENCBS896YZO/ -------------------
# Average es_time: 2.155 ± 1.771 ms (n=100)
# Average queue_time: 0.377 ± 0.035 ms (n=100)
# Average render_time: 6.102 ± 0.343 ms (n=100)
# Average wsgi_time: 12.657 ± 2.037 ms (n=100)
# Average total time: 21.292 ± 3.931 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS896YZO/ ------
# Average es_time: 1.575 ± 1.57 ms (n=100)
# Average queue_time: 0.558 ± 0.014 ms (n=100)
# Average render_time: 6.599 ± 0.806 ms (n=100)
# Average wsgi_time: 12.885 ± 1.995 ms (n=100)
# Average total time: 21.617 ± 3.828 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ------------------- https://test.encodedcc.org//ENCBS280NYD/ -------------------
# Average es_time: 2.075 ± 2.124 ms (n=100)
# Average queue_time: 0.381 ± 0.038 ms (n=100)
# Average render_time: 3.415 ± 0.148 ms (n=100)
# Average wsgi_time: 8.733 ± 2.315 ms (n=100)
# Average total time: 14.604 ± 4.502 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS280NYD/ ------
# Average es_time: 1.327 ± 1.3 ms (n=100)
# Average queue_time: 0.552 ± 0.015 ms (n=100)
# Average render_time: 3.557 ± 0.231 ms (n=100)
# Average wsgi_time: 8.379 ± 1.492 ms (n=100)
# Average total time: 13.816 ± 2.768 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS565NTN/
# ------------------- https://test.encodedcc.org//ENCBS565NTN/ -------------------
# Average es_time: 1.71 ± 0.088 ms (n=100)
# Average queue_time: 0.383 ± 0.044 ms (n=100)
# Average render_time: 3.471 ± 0.167 ms (n=100)
# Average wsgi_time: 8.272 ± 0.316 ms (n=100)
# Average total time: 13.836 ± 0.503 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS565NTN/ ------
# Average es_time: 1.17 ± 0.036 ms (n=100)
# Average queue_time: 0.564 ± 0.016 ms (n=100)
# Average render_time: 3.703 ± 0.255 ms (n=100)
# Average wsgi_time: 8.28 ± 0.336 ms (n=100)
# Average total time: 13.717 ± 0.554 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ------------------- https://test.encodedcc.org//ENCBS896YZO/ -------------------
# Average es_time: 1.881 ± 0.099 ms (n=100)
# Average queue_time: 0.381 ± 0.029 ms (n=100)
# Average render_time: 6.175 ± 0.616 ms (n=100)
# Average wsgi_time: 12.464 ± 0.734 ms (n=100)
# Average total time: 20.9 ± 1.319 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS896YZO/ ------
# Average es_time: 1.301 ± 0.044 ms (n=100)
# Average queue_time: 0.558 ± 0.013 ms (n=100)
# Average render_time: 6.427 ± 0.572 ms (n=100)
# Average wsgi_time: 12.394 ± 0.658 ms (n=100)
# Average total time: 20.68 ± 1.18 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ------------------- https://test.encodedcc.org//ENCBS280NYD/ -------------------
# Average es_time: 1.683 ± 0.097 ms (n=100)
# Average queue_time: 0.372 ± 0.038 ms (n=100)
# Average render_time: 3.398 ± 0.154 ms (n=100)
# Average wsgi_time: 8.273 ± 0.356 ms (n=100)
# Average total time: 13.726 ± 0.525 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCBS280NYD/ ------
# Average es_time: 1.139 ± 0.055 ms (n=100)
# Average queue_time: 0.554 ± 0.013 ms (n=100)
# Average render_time: 3.536 ± 0.267 ms (n=100)
# Average wsgi_time: 8.192 ± 0.573 ms (n=100)
# Average total time: 13.422 ± 0.753 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------- https://test.encodedcc.org//ENCSR323QIP/ -------------------
# Average es_time: 13.124 ± 2.48 ms (n=100)
# Average queue_time: 0.476 ± 0.045 ms (n=100)
# Average render_time: 115.058 ± 2.794 ms (n=100)
# Average wsgi_time: 276.338 ± 181.55 ms (n=100)
# Average total time: 404.996 ± 182.198 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR323QIP/ ------
# Average es_time: 6.624 ± 1.529 ms (n=100)
# Average queue_time: 0.563 ± 0.015 ms (n=100)
# Average render_time: 118.778 ± 4.557 ms (n=100)
# Average wsgi_time: 259.144 ± 147.235 ms (n=100)
# Average total time: 385.107 ± 148.491 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------------- https://test.encodedcc.org//ENCSR718AXQ/ -------------------
# Average es_time: 4.806 ± 0.183 ms (n=100)
# Average queue_time: 0.449 ± 0.032 ms (n=100)
# Average render_time: 12.017 ± 1.107 ms (n=100)
# Average wsgi_time: 27.9 ± 1.35 ms (n=100)
# Average total time: 45.172 ± 2.404 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR718AXQ/ ------
# Average es_time: 3.089 ± 0.114 ms (n=100)
# Average queue_time: 0.565 ± 0.016 ms (n=100)
# Average render_time: 15.388 ± 26.22 ms (n=100)
# Average wsgi_time: 30.194 ± 26.5 ms (n=100)
# Average total time: 49.236 ± 52.704 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------------- https://test.encodedcc.org//ENCSR165BGV/ -------------------
# Average es_time: 5.924 ± 2.393 ms (n=100)
# Average queue_time: 0.481 ± 0.055 ms (n=100)
# Average render_time: 42.699 ± 67.525 ms (n=100)
# Average wsgi_time: 67.735 ± 69.935 ms (n=100)
# Average total time: 116.839 ± 139.116 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR165BGV/ ------
# Average es_time: 4.108 ± 2.652 ms (n=100)
# Average queue_time: 0.592 ± 0.056 ms (n=100)
# Average render_time: 50.227 ± 78.336 ms (n=100)
# Average wsgi_time: 74.481 ± 82.436 ms (n=100)
# Average total time: 129.407 ± 162.983 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------------- https://test.encodedcc.org//ENCSR384KAN/ -------------------
# Average es_time: 6.729 ± 3.183 ms (n=100)
# Average queue_time: 0.428 ± 0.033 ms (n=100)
# Average render_time: 45.325 ± 34.653 ms (n=100)
# Average wsgi_time: 91.968 ± 50.955 ms (n=100)
# Average total time: 144.45 ± 78.987 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR384KAN/ ------
# Average es_time: 4.386 ± 2.216 ms (n=100)
# Average queue_time: 0.567 ± 0.024 ms (n=100)
# Average render_time: 51.45 ± 49.89 ms (n=100)
# Average wsgi_time: 93.475 ± 52.174 ms (n=100)
# Average total time: 149.878 ± 103.533 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------------- https://test.encodedcc.org//ENCSR330FXL/ -------------------
# Average es_time: 3.009 ± 2.75 ms (n=100)
# Average queue_time: 0.422 ± 0.031 ms (n=100)
# Average render_time: 19.215 ± 1.664 ms (n=100)
# Average wsgi_time: 38.281 ± 3.601 ms (n=100)
# Average total time: 60.927 ± 6.935 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR330FXL/ ------
# Average es_time: 1.8 ± 1.27 ms (n=100)
# Average queue_time: 0.563 ± 0.013 ms (n=100)
# Average render_time: 19.38 ± 1.605 ms (n=100)
# Average wsgi_time: 42.56 ± 46.923 ms (n=100)
# Average total time: 64.302 ± 47.045 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 25.31 ± 7.559 ms (n=100)
# Average queue_time: 0.584 ± 0.071 ms (n=100)
# Average render_time: 277.92 ± 121.003 ms (n=100)
# Average wsgi_time: 604.707 ± 201.355 ms (n=100)
# Average total time: 908.522 ± 245.136 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR825UNV/ ------
# Average es_time: 17.299 ± 5.585 ms (n=100)
# Average queue_time: 0.696 ± 0.056 ms (n=100)
# Average render_time: 354.703 ± 125.519 ms (n=100)
# Average wsgi_time: 705.204 ± 234.297 ms (n=100)
# Average total time: 1077.903 ± 362.351 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
# Average es_time: 3.9 ± 3.202 ms (n=100)
# Average queue_time: 0.484 ± 0.037 ms (n=100)
# Average render_time: 16.76 ± 47.04 ms (n=100)
# Average wsgi_time: 30.57 ± 49.55 ms (n=100)
# Average total time: 51.714 ± 98.705 ms (n=100)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR089EOA/ ------
# Average es_time: 2.346 ± 1.648 ms (n=100)
# Average queue_time: 0.583 ± 0.034 ms (n=100)
# Average render_time: 14.978 ± 42.938 ms (n=100)
# Average wsgi_time: 27.916 ± 44.361 ms (n=100)
# Average total time: 45.823 ± 88.406 ms (n=100)

# %%
qa.check_response_time(item_types=['/matrix/?type=Experiment','/search/?type=Experiment&status=released&assay_title=Control+ChIP-seq&award.project=modENCODE'], n=100)
# Out:
# Checking response time
#
# *** item_type: /matrix/?type=Experiment
# ------------- https://test.encodedcc.org//matrix/?type=Experiment --------------
# Average es_time: 22.493 ± 14.854 ms (n=100)
# Average queue_time: 0.479 ± 0.038 ms (n=100)
# Average render_time: 109.357 ± 52.047 ms (n=100)
# Average wsgi_time: 202.398 ± 69.817 ms (n=100)
# Average total time: 334.728 ± 124.419 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//matrix/?type=Experiment ---------
# Average es_time: 16.064 ± 9.719 ms (n=100)
# Average queue_time: 0.569 ± 0.02 ms (n=100)
# Average render_time: 103.784 ± 19.951 ms (n=100)
# Average wsgi_time: 191.746 ± 50.349 ms (n=100)
# Average total time: 312.163 ± 70.216 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment&status=released&assay_title=Control+ChIP-seq&award.project=modENCODE
# --------- https://test.encodedcc.org//search/?type=Experiment&status=released&assay_title=Control+ChIP-seq&award.project=modENCODE ---------
# Average es_time: 28.257 ± 6.477 ms (n=100)
# Average queue_time: 0.438 ± 0.084 ms (n=100)
# Average render_time: 22.521 ± 27.416 ms (n=100)
# Average wsgi_time: 60.711 ± 29.112 ms (n=100)
# Average total time: 111.928 ± 58.041 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//search/?type=Experiment&status=released&assay_title=Control+ChIP-seq&award.project=modENCODE ---------
# Average es_time: 21.352 ± 4.57 ms (n=100)
# Average queue_time: 0.565 ± 0.014 ms (n=100)
# Average render_time: 20.583 ± 5.914 ms (n=100)
# Average wsgi_time: 52.122 ± 8.367 ms (n=100)
# Average total time: 94.622 ± 16.461 ms (n=100)

# %%
qa.check_response_time(item_types=['reference-epigenome-matrix/?type=Experiment&related_series.@type=ReferenceEpigenome&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens','/entex-matrix/?type=Experiment&status=released&internal_tags=ENTEx'], n=100)
# Out:
# Checking response time
#
# *** item_type: reference-epigenome-matrix/?type=Experiment&related_series.@type=ReferenceEpigenome&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens
# --------- https://test.encodedcc.org/reference-epigenome-matrix/?type=Experiment&related_series.@type=ReferenceEpigenome&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens ---------
# Average es_time: 16.562 ± 14.555 ms (n=100)
# Average queue_time: 0.48 ± 0.04 ms (n=100)
# Average render_time: 60.545 ± 28.101 ms (n=100)
# Average wsgi_time: 125.578 ± 42.945 ms (n=100)
# Average total time: 203.165 ± 75.344 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org/reference-epigenome-matrix/?type=Experiment&related_series.@type=ReferenceEpigenome&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens ---------
# Average es_time: 9.423 ± 10.013 ms (n=100)
# Average queue_time: 0.578 ± 0.03 ms (n=100)
# Average render_time: 59.435 ± 6.75 ms (n=100)
# Average wsgi_time: 116.828 ± 15.085 ms (n=100)
# Average total time: 186.263 ± 28.808 ms (n=100)
#
#
# *** item_type: /entex-matrix/?type=Experiment&status=released&internal_tags=ENTEx
# --------- https://test.encodedcc.org//entex-matrix/?type=Experiment&status=released&internal_tags=ENTEx ---------
# Average es_time: 18.062 ± 13.983 ms (n=100)
# Average queue_time: 0.494 ± 0.043 ms (n=100)
# Average render_time: 77.343 ± 52.135 ms (n=100)
# Average wsgi_time: 166.851 ± 73.687 ms (n=100)
# Average total time: 262.75 ± 123.782 ms (n=100)
# --------- https://facet-performance-fytanaka.demo.encodedcc.org//entex-matrix/?type=Experiment&status=released&internal_tags=ENTEx ---------
# Average es_time: 11.243 ± 12.659 ms (n=100)
# Average queue_time: 0.597 ± 0.047 ms (n=100)
# Average render_time: 85.137 ± 65.862 ms (n=100)
# Average wsgi_time: 176.022 ± 100.383 ms (n=100)
# Average total time: 272.999 ± 162.292 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR825UNV/','/ENCSR089EOA/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /ENCSR825UNV/
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 24.59 ± 7.152 ms (n=50)
# Average queue_time: 0.586 ± 0.053 ms (n=50)
# Average render_time: 316.157 ± 122.948 ms (n=50)
# Average wsgi_time: 670.891 ± 189.505 ms (n=50)
# Average total time: 1012.224 ± 194.718 ms (n=50)
# ----- https://facet-performance-fytanaka.demo.encodedcc.org//ENCSR825UNV/ ------
# Average es_time: 20.982 ± 11.51 ms (n=50)
# Average queue_time: 0.624 ± 0.08 ms (n=50)
# Average render_time: 339.04 ± 122.664 ms (n=50)
# Average wsgi_time: 678.887 ± 238.863 ms (n=50)
# Average total time: 1039.534 ± 357.202 ms (n=50)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-46c0d0e2ecee> in <module>
# ----> 1 qa.check_response_time(item_types=['/ENCSR825UNV/','/ENCSR089EOA/'], n=50)
#
# ~/Documents/workspace/pyencoded-tools/qancode/qancode.py in check_response_time(self, urls, item_types, n)
#     492                 if item is not None:
#     493                     url = url + item
# --> 494                 self._average_time_for_get(url, n)
#     495             print()
#
# ~/Documents/workspace/pyencoded-tools/qancode/qancode.py in _average_time_for_get(self, url, n)
#     472     def _average_time_for_get(self, url, n):
#     473         self._print_header(url)
# --> 474         time_headers = self._get_time_headers(url, n)
#     475         parsed_headers = [self._parse_header(h) for h in time_headers]
#     476         for key in sorted(parsed_headers[0].keys()):
#
# ~/Documents/workspace/pyencoded-tools/qancode/qancode.py in _get_time_headers(url, n)
#     437         time_headers = []
#     438         for i in range(n):
# --> 439             r = requests.get(url)
#     440             assert r.status_code == 200
#     441             time_headers.append(r.headers)
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/pyvenvs/jupyter/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
qa.check_response_time(item_types=['/ENCSR089EOA/'], n=10)
# Out:
# Checking response time
#
# *** item_type: /ENCSR089EOA/
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
