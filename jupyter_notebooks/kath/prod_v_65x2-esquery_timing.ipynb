# %%
import sys
sys.path.append('../..')
import qancode

# %%
qa = qancode.QANCODE(rc_url='https://65x2-esquery-rc-master.demo.encodedcc.org')

# %%
qa.check_response_time(
    item_types=[
        '/',
        '/search/?type=Experiment'
    ],
    n=100
)
# Out:
# Checking response time
#
# *** item_type: /
# ------------------------ https://www.encodeproject.org/ ------------------------
# Average es_time: 9.326 ± 1.377 ms (n=100)
# Average queue_time: 0.903 ± 0.353 ms (n=100)
# Average render_time: 8.889 ± 2.486 ms (n=100)
# Average wsgi_time: 26.998 ± 3.057 ms (n=100)
# Average total time: 46.116 ± 5.828 ms (n=100)
# -------------- https://65x2-esquery-rc-master.demo.encodedcc.org/ --------------
# Average es_time: 60.103 ± 29.528 ms (n=100)
# Average queue_time: 1.487 ± 1.201 ms (n=100)
# Average render_time: 8.058 ± 2.195 ms (n=100)
# Average wsgi_time: 79.171 ± 30.509 ms (n=100)
# Average total time: 148.819 ± 59.85 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment
# ------------ https://www.encodeproject.org/search/?type=Experiment -------------
# Average es_time: 117.551 ± 32.973 ms (n=100)
# Average queue_time: 0.949 ± 0.253 ms (n=100)
# Average render_time: 144.296 ± 51.893 ms (n=100)
# ...

# %%
qa.check_response_time(
    item_types=[
        '/search/?searchTerm=K562',
        '/search/?searchTerm=DNA+binding',
        '/search/?searchTerm=human',
        '/search/?searchTerm=H3K36me3',
        '/search/?searchTerm=CTCF'
    ],
    n=100
)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ------------ https://www.encodeproject.org/search/?searchTerm=K562 -------------
# Average es_time: 312.842 ± 67.663 ms (n=100)
# Average queue_time: 1.423 ± 4.819 ms (n=100)
# Average render_time: 32.579 ± 8.494 ms (n=100)
# Average wsgi_time: 360.96 ± 67.252 ms (n=100)
# Average total time: 707.803 ± 134.48 ms (n=100)
# --------- https://65x2-esquery-rc-master.demo.encodedcc.org/search/?searchTerm=K562 ---------
# Average es_time: 417.675 ± 238.573 ms (n=100)
# Average queue_time: 1.327 ± 0.792 ms (n=100)
# Average render_time: 34.202 ± 9.335 ms (n=100)
# Average wsgi_time: 470.85 ± 239.941 ms (n=100)
# Average total time: 924.054 ± 479.13 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# --------- https://www.encodeproject.org/search/?searchTerm=DNA+binding ---------
# Average es_time: 474.052 ± 108.656 ms (n=100)
# Average queue_time: 0.908 ± 0.303 ms (n=100)
# ...

# %%
qa.check_response_time(
    item_types=[
        '/ENCSR255XZG/',
        '/ENCSR749ILN/',
        '/ENCSR688GVV/',
        '/ENCSR301HAG/',
        '/ENCSR315NAC/',
        '/ENCSR856JJB/'
    ],
    n=100
)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------------ https://www.encodeproject.org/ENCSR255XZG/ ------------------
# Average es_time: 18.539 ± 5.202 ms (n=100)
# Average queue_time: 0.948 ± 0.179 ms (n=100)
# Average render_time: 128.209 ± 13.997 ms (n=100)
# Average wsgi_time: 250.613 ± 86.864 ms (n=100)
# Average total time: 398.308 ± 95.509 ms (n=100)
# -------- https://65x2-esquery-rc-master.demo.encodedcc.org/ENCSR255XZG/ --------
# Average es_time: 77.187 ± 42.285 ms (n=100)
# Average queue_time: 1.384 ± 1.562 ms (n=100)
# Average render_time: 148.429 ± 56.551 ms (n=100)
# Average wsgi_time: 359.771 ± 165.284 ms (n=100)
# Average total time: 586.771 ± 205.745 ms (n=100)
#
#
# *** item_type: /ENCSR749ILN/
# ------------------ https://www.encodeproject.org/ENCSR749ILN/ ------------------
# Average es_time: 12.988 ± 1.658 ms (n=100)
# Average queue_time: 0.92 ± 0.368 ms (n=100)
# Average render_time: 31.695 ± 6.436 ms (n=100)
# ...

# %%
qa.check_response_time(
    item_types=[
        '/ENCSR480OHP/',
        '/ENCSR000EMB/',
        '/ENCSR323QIP/',
        '/ENCSR718AXQ/',
        '/ENCSR165BGV/',
        '/ENCSR384KAN/',
        '/ENCSR330FXL/',
        '/ENCSR825UNV/',
        '/ENCSR089EOA/'
    ],
    n=100
)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------------ https://www.encodeproject.org/ENCSR480OHP/ ------------------
# Average es_time: 13.782 ± 1.465 ms (n=100)
# Average queue_time: 0.953 ± 0.414 ms (n=100)
# Average render_time: 33.842 ± 6.684 ms (n=100)
# Average wsgi_time: 80.225 ± 69.82 ms (n=100)
# Average total time: 128.802 ± 70.429 ms (n=100)
# -------- https://65x2-esquery-rc-master.demo.encodedcc.org/ENCSR480OHP/ --------
# Average es_time: 76.663 ± 41.065 ms (n=100)
# Average queue_time: 33.09 ± 219.609 ms (n=100)
# Average render_time: 35.396 ± 7.709 ms (n=100)
# Average wsgi_time: 142.128 ± 43.977 ms (n=100)
# Average total time: 287.277 ± 243.503 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ------------------ https://www.encodeproject.org/ENCSR000EMB/ ------------------
# Average es_time: 12.735 ± 3.504 ms (n=100)
# Average queue_time: 1.119 ± 1.567 ms (n=100)
# Average render_time: 51.498 ± 8.412 ms (n=100)
# ...

# %%
qa.check_response_time(
    item_types=[
        '/ENCAB830JLB/',
        '/ENCAB000BKR/',
        '/ENCAB284TTY/',
        '/ENCAB294YUD/',
        '/ENCAB000AOC/',
        '/ENCAB301QZF/',
        '/ENCAB000ANM/',
        '/ENCAB000ANU/',
        '/ENCAB445KMF/',
        '/ENCAB000BAY/'
    ],
    n=100
)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ------------------ https://www.encodeproject.org/ENCAB830JLB/ ------------------
# Average es_time: 10.272 ± 2.763 ms (n=100)
# Average queue_time: 0.985 ± 0.42 ms (n=100)
# Average render_time: 24.316 ± 4.276 ms (n=100)
# Average wsgi_time: 50.841 ± 5.88 ms (n=100)
# Average total time: 86.415 ± 10.508 ms (n=100)
# -------- https://65x2-esquery-rc-master.demo.encodedcc.org/ENCAB830JLB/ --------
# Average es_time: 72.699 ± 39.317 ms (n=100)
# Average queue_time: 1.656 ± 1.297 ms (n=100)
# Average render_time: 27.265 ± 6.594 ms (n=100)
# Average wsgi_time: 117.806 ± 40.414 ms (n=100)
# Average total time: 219.427 ± 80.205 ms (n=100)
#
#
# *** item_type: /ENCAB000BKR/
# ------------------ https://www.encodeproject.org/ENCAB000BKR/ ------------------
# Average es_time: 9.607 ± 1.661 ms (n=100)
# Average queue_time: 0.935 ± 0.321 ms (n=100)
# Average render_time: 15.747 ± 4.398 ms (n=100)
# ...

# %%
qa.check_response_time(
    item_types=[
        '/ENCBS787TFV/',
        '/ENCBS676QAV/',
        '/ENCBS996IWU/',
        '/ENCBS913XJP/',
        '/ENCBS565NTN/',
        '/ENCBS896YZO/',
        '/ENCBS280NYD/'
    ],
    n=100
)
# Out:
# Checking response time
#
# *** item_type: /ENCBS787TFV/
# ------------------ https://www.encodeproject.org/ENCBS787TFV/ ------------------
# Average es_time: 19.584 ± 21.691 ms (n=100)
# Average queue_time: 0.976 ± 0.361 ms (n=100)
# Average render_time: 11.11 ± 4.228 ms (n=100)
# Average wsgi_time: 38.262 ± 21.725 ms (n=100)
# Average total time: 69.932 ± 43.423 ms (n=100)
# -------- https://65x2-esquery-rc-master.demo.encodedcc.org/ENCBS787TFV/ --------
# Average es_time: 79.739 ± 49.039 ms (n=100)
# Average queue_time: 1.508 ± 1.399 ms (n=100)
# Average render_time: 10.623 ± 1.887 ms (n=100)
# Average wsgi_time: 100.766 ± 49.416 ms (n=100)
# Average total time: 192.635 ± 98.532 ms (n=100)
#
#
# *** item_type: /ENCBS676QAV/
# ------------------ https://www.encodeproject.org/ENCBS676QAV/ ------------------
# Average es_time: 9.077 ± 2.897 ms (n=100)
# Average queue_time: 0.871 ± 0.364 ms (n=100)
# Average render_time: 12.072 ± 2.899 ms (n=100)
# ...
