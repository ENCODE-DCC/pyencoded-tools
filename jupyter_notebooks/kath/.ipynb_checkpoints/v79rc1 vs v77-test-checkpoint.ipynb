# %%
import qancode
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-a72ff66ecca3> in <module>()
# ----> 1 import qancode
#
# ImportError: No module named 'qancode'

# %%
#comparing to v65rc2 site
qa = qancode.QANCODE(rc_url="https://v79rc1-master.demo.encodedcc.org/", prod_url="https://test.encodedcc.org/")

# %%
qa.check_response_time(item_types=["/","/search/?type=Experiment"], n=100)
# Out:
# Checking response time
#
# *** item_type: /
# ---------------- https://dup-v64rc0-master.demo.encodedcc.org// ----------------
# Average es_time: 5.795 ± 1.025 ms (n=100)
# Average queue_time: 1.213 ± 0.848 ms (n=100)
# Average render_time: 9.313 ± 2.746 ms (n=100)
# Average wsgi_time: 24.869 ± 4.139 ms (n=100)
# Average total time: 41.19 ± 6.85 ms (n=100)
# ------------------ https://v65rc2-master.demo.encodedcc.org// ------------------
# Average es_time: 26.42 ± 8.853 ms (n=100)
# Average queue_time: 0.894 ± 0.124 ms (n=100)
# Average render_time: 8.695 ± 3.025 ms (n=100)
# Average wsgi_time: 42.934 ± 9.864 ms (n=100)
# Average total time: 78.943 ± 19.426 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment
# ---- https://dup-v64rc0-master.demo.encodedcc.org//search/?type=Experiment -----
# Average es_time: 119.477 ± 21.681 ms (n=100)
# Average queue_time: 1.195 ± 0.585 ms (n=100)
# Average render_time: 124.438 ± 18.205 ms (n=100)
# Average wsgi_time: 268.698 ± 34.9 ms (n=100)
# Average total time: 513.808 ± 61.991 ms (n=100)
# ------ https://v65rc2-master.demo.encodedcc.org//search/?type=Experiment -------
# Average es_time: 47.719 ± 12.306 ms (n=100)
# Average queue_time: 0.991 ± 0.247 ms (n=100)
# Average render_time: 135.619 ± 16.074 ms (n=100)
# Average wsgi_time: 209.148 ± 21.095 ms (n=100)
# Average total time: 393.478 ± 41.518 ms (n=100)

# %%
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ---- https://dup-v64rc0-master.demo.encodedcc.org//search/?searchTerm=K562 -----
# Average es_time: 301.683 ± 93.886 ms (n=100)
# Average queue_time: 1.315 ± 1.063 ms (n=100)
# Average render_time: 30.089 ± 6.55 ms (n=100)
# Average wsgi_time: 351.759 ± 99.842 ms (n=100)
# Average total time: 684.847 ± 193.87 ms (n=100)
# ------ https://v65rc2-master.demo.encodedcc.org//search/?searchTerm=K562 -------
# Average es_time: 256.12 ± 148.899 ms (n=100)
# Average queue_time: 1.065 ± 0.324 ms (n=100)
# Average render_time: 30.306 ± 6.674 ms (n=100)
# Average wsgi_time: 304.04 ± 154.65 ms (n=100)
# Average total time: 591.531 ± 305.886 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# --------- https://dup-v64rc0-master.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 458.043 ± 69.274 ms (n=100)
# Average queue_time: 1.122 ± 0.458 ms (n=100)
# Average render_time: 29.181 ± 5.759 ms (n=100)
# Average wsgi_time: 507.979 ± 72.506 ms (n=100)
# Average total time: 996.325 ± 141.848 ms (n=100)
# --------- https://v65rc2-master.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 330.855 ± 85.238 ms (n=100)
# Average queue_time: 1.017 ± 0.224 ms (n=100)
# Average render_time: 33.764 ± 7.169 ms (n=100)
# Average wsgi_time: 387.869 ± 89.335 ms (n=100)
# Average total time: 753.505 ± 176.1 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=human
# --------- https://dup-v64rc0-master.demo.encodedcc.org//search/?searchTerm=human ---------
# Average es_time: 272.82 ± 26.834 ms (n=100)
# Average queue_time: 1.036 ± 0.445 ms (n=100)
# Average render_time: 29.159 ± 5.151 ms (n=100)
# Average wsgi_time: 315.196 ± 29.05 ms (n=100)
# Average total time: 618.211 ± 57.401 ms (n=100)
# ------ https://v65rc2-master.demo.encodedcc.org//search/?searchTerm=human ------
# Average es_time: 262.926 ± 31.423 ms (n=100)
# Average queue_time: 0.988 ± 0.206 ms (n=100)
# Average render_time: 40.342 ± 6.877 ms (n=100)
# Average wsgi_time: 327.933 ± 34.371 ms (n=100)
# Average total time: 632.189 ± 67.619 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# --------- https://dup-v64rc0-master.demo.encodedcc.org//search/?searchTerm=H3K36me3 ---------
# Average es_time: 496.073 ± 38.573 ms (n=100)
# Average queue_time: 1.102 ± 0.506 ms (n=100)
# Average render_time: 120.785 ± 7.094 ms (n=100)
# Average wsgi_time: 688.757 ± 49.292 ms (n=100)
# Average total time: 1306.718 ± 84.306 ms (n=100)
# ---- https://v65rc2-master.demo.encodedcc.org//search/?searchTerm=H3K36me3 -----
# Average es_time: 228.815 ± 29.789 ms (n=100)
# Average queue_time: 1.028 ± 0.245 ms (n=100)
# Average render_time: 33.517 ± 6.211 ms (n=100)
# Average wsgi_time: 279.161 ± 31.832 ms (n=100)
# Average total time: 542.522 ± 62.448 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=CTCF
# ---- https://dup-v64rc0-master.demo.encodedcc.org//search/?searchTerm=CTCF -----
# Average es_time: 296.943 ± 33.164 ms (n=100)
# Average queue_time: 1.029 ± 0.43 ms (n=100)
# Average render_time: 31.937 ± 6.816 ms (n=100)
# Average wsgi_time: 346.324 ± 34.379 ms (n=100)
# Average total time: 676.232 ± 68.51 ms (n=100)
# ------ https://v65rc2-master.demo.encodedcc.org//search/?searchTerm=CTCF -------
# Average es_time: 227.742 ± 45.067 ms (n=100)
# Average queue_time: 1.088 ± 0.478 ms (n=100)
# Average render_time: 29.554 ± 5.67 ms (n=100)
# Average wsgi_time: 272.998 ± 47.114 ms (n=100)
# Average total time: 531.382 ± 93.237 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR255XZG/ ----------
# Average es_time: 14.648 ± 2.373 ms (n=100)
# Average queue_time: 1.376 ± 0.999 ms (n=100)
# Average render_time: 126.344 ± 8.326 ms (n=100)
# Average wsgi_time: 256.961 ± 142.125 ms (n=100)
# Average total time: 399.33 ± 143.537 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR255XZG/ ------------
# Average es_time: 33.171 ± 11.148 ms (n=100)
# Average queue_time: 0.999 ± 0.433 ms (n=100)
# Average render_time: 121.811 ± 5.774 ms (n=100)
# Average wsgi_time: 256.637 ± 76.798 ms (n=100)
# Average total time: 412.617 ± 79.977 ms (n=100)
#
#
# *** item_type: /ENCSR749ILN/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR749ILN/ ----------
# Average es_time: 7.974 ± 1.358 ms (n=100)
# Average queue_time: 1.222 ± 0.723 ms (n=100)
# Average render_time: 31.621 ± 5.938 ms (n=100)
# Average wsgi_time: 73.572 ± 97.0 ms (n=100)
# Average total time: 114.389 ± 97.103 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR749ILN/ ------------
# Average es_time: 29.497 ± 8.346 ms (n=100)
# Average queue_time: 0.924 ± 0.168 ms (n=100)
# Average render_time: 31.261 ± 5.423 ms (n=100)
# Average wsgi_time: 90.086 ± 72.438 ms (n=100)
# Average total time: 151.768 ± 74.928 ms (n=100)
#
#
# *** item_type: /ENCSR688GVV/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR688GVV/ ----------
# Average es_time: 11.253 ± 1.62 ms (n=100)
# Average queue_time: 1.239 ± 0.891 ms (n=100)
# Average render_time: 61.688 ± 8.135 ms (n=100)
# Average wsgi_time: 140.692 ± 143.897 ms (n=100)
# Average total time: 214.873 ± 144.328 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR688GVV/ ------------
# Average es_time: 32.82 ± 6.238 ms (n=100)
# Average queue_time: 0.984 ± 0.282 ms (n=100)
# Average render_time: 58.351 ± 8.22 ms (n=100)
# Average wsgi_time: 144.746 ± 67.641 ms (n=100)
# Average total time: 236.901 ± 70.461 ms (n=100)
#
#
# *** item_type: /ENCSR301HAG/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR301HAG/ ----------
# Average es_time: 6.49 ± 1.217 ms (n=100)
# Average queue_time: 1.022 ± 0.362 ms (n=100)
# Average render_time: 14.051 ± 3.105 ms (n=100)
# Average wsgi_time: 33.269 ± 4.484 ms (n=100)
# Average total time: 54.832 ± 7.385 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR301HAG/ ------------
# Average es_time: 25.75 ± 4.989 ms (n=100)
# Average queue_time: 0.951 ± 0.13 ms (n=100)
# Average render_time: 14.662 ± 3.342 ms (n=100)
# Average wsgi_time: 52.013 ± 6.39 ms (n=100)
# Average total time: 93.376 ± 12.229 ms (n=100)
#
#
# *** item_type: /ENCSR315NAC/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR315NAC/ ----------
# Average es_time: 10.056 ± 1.286 ms (n=100)
# Average queue_time: 1.078 ± 0.424 ms (n=100)
# Average render_time: 52.1 ± 6.752 ms (n=100)
# Average wsgi_time: 102.005 ± 8.794 ms (n=100)
# Average total time: 165.239 ± 15.172 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR315NAC/ ------------
# Average es_time: 30.861 ± 7.053 ms (n=100)
# Average queue_time: 0.984 ± 0.247 ms (n=100)
# Average render_time: 49.007 ± 8.649 ms (n=100)
# Average wsgi_time: 124.68 ± 67.692 ms (n=100)
# Average total time: 205.532 ± 70.307 ms (n=100)
#
#
# *** item_type: /ENCSR856JJB/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR856JJB/ ----------
# Average es_time: 9.607 ± 1.236 ms (n=100)
# Average queue_time: 1.106 ± 0.508 ms (n=100)
# Average render_time: 44.361 ± 7.591 ms (n=100)
# Average wsgi_time: 107.299 ± 129.27 ms (n=100)
# Average total time: 162.374 ± 131.664 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR856JJB/ ------------
# Average es_time: 30.747 ± 6.422 ms (n=100)
# Average queue_time: 0.953 ± 0.112 ms (n=100)
# Average render_time: 43.831 ± 7.46 ms (n=100)
# Average wsgi_time: 115.162 ± 70.558 ms (n=100)
# Average total time: 190.692 ± 72.358 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR480OHP/ ----------
# Average es_time: 7.304 ± 2.031 ms (n=100)
# Average queue_time: 1.08 ± 0.514 ms (n=100)
# Average render_time: 31.084 ± 4.296 ms (n=100)
# Average wsgi_time: 74.138 ± 115.339 ms (n=100)
# Average total time: 113.607 ± 115.515 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR480OHP/ ------------
# Average es_time: 27.842 ± 6.446 ms (n=100)
# Average queue_time: 0.997 ± 0.349 ms (n=100)
# Average render_time: 32.121 ± 5.497 ms (n=100)
# Average wsgi_time: 82.668 ± 9.953 ms (n=100)
# Average total time: 143.628 ± 18.168 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR000EMB/ ----------
# Average es_time: 7.158 ± 1.058 ms (n=100)
# Average queue_time: 1.22 ± 0.645 ms (n=100)
# Average render_time: 50.345 ± 7.819 ms (n=100)
# Average wsgi_time: 102.711 ± 99.368 ms (n=100)
# Average total time: 161.434 ± 100.737 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR000EMB/ ------------
# Average es_time: 28.495 ± 6.94 ms (n=100)
# Average queue_time: 0.982 ± 0.415 ms (n=100)
# Average render_time: 49.435 ± 7.57 ms (n=100)
# Average wsgi_time: 129.358 ± 124.558 ms (n=100)
# Average total time: 208.27 ± 126.984 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR323QIP/ ----------
# Average es_time: 16.392 ± 1.51 ms (n=100)
# Average queue_time: 1.051 ± 0.438 ms (n=100)
# Average render_time: 148.511 ± 9.624 ms (n=100)
# Average wsgi_time: 305.897 ± 127.4 ms (n=100)
# Average total time: 471.851 ± 128.908 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR323QIP/ ------------
# Average es_time: 37.741 ± 12.248 ms (n=100)
# Average queue_time: 1.098 ± 0.574 ms (n=100)
# Average render_time: 149.124 ± 36.89 ms (n=100)
# Average wsgi_time: 332.071 ± 148.415 ms (n=100)
# Average total time: 520.033 ± 163.056 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR718AXQ/ ----------
# Average es_time: 6.903 ± 1.009 ms (n=100)
# Average queue_time: 0.995 ± 0.349 ms (n=100)
# Average render_time: 22.985 ± 4.128 ms (n=100)
# Average wsgi_time: 47.08 ± 5.36 ms (n=100)
# Average total time: 77.963 ± 9.215 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR718AXQ/ ------------
# Average es_time: 29.505 ± 5.286 ms (n=100)
# Average queue_time: 0.955 ± 0.109 ms (n=100)
# Average render_time: 24.266 ± 5.647 ms (n=100)
# Average wsgi_time: 70.016 ± 8.614 ms (n=100)
# Average total time: 124.742 ± 16.409 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR165BGV/ ----------
# Average es_time: 5.99 ± 2.272 ms (n=100)
# Average queue_time: 0.96 ± 0.288 ms (n=100)
# Average render_time: 24.274 ± 4.145 ms (n=100)
# Average wsgi_time: 48.674 ± 5.192 ms (n=100)
# Average total time: 79.898 ± 9.713 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR165BGV/ ------------
# Average es_time: 26.661 ± 6.474 ms (n=100)
# Average queue_time: 1.034 ± 0.581 ms (n=100)
# Average render_time: 25.901 ± 4.503 ms (n=100)
# Average wsgi_time: 77.504 ± 73.616 ms (n=100)
# Average total time: 131.1 ± 74.678 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR384KAN/ ----------
# Average es_time: 8.438 ± 1.986 ms (n=100)
# Average queue_time: 0.971 ± 0.288 ms (n=100)
# Average render_time: 44.084 ± 6.707 ms (n=100)
# Average wsgi_time: 104.252 ± 106.011 ms (n=100)
# Average total time: 157.745 ± 107.176 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR384KAN/ ------------
# Average es_time: 31.065 ± 6.541 ms (n=100)
# Average queue_time: 0.999 ± 0.239 ms (n=100)
# Average render_time: 44.971 ± 8.729 ms (n=100)
# Average wsgi_time: 110.831 ± 10.837 ms (n=100)
# Average total time: 187.865 ± 21.102 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCSR330FXL/ ----------
# Average es_time: 5.782 ± 1.063 ms (n=100)
# Average queue_time: 1.078 ± 0.577 ms (n=100)
# Average render_time: 28.53 ± 4.94 ms (n=100)
# Average wsgi_time: 56.108 ± 6.458 ms (n=100)
# Average total time: 91.498 ± 11.565 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCSR330FXL/ ------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-fe7b77c906a4> in <module>()
# ----> 1 qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
#
# ~/Applications/pyencoded-tools/qancode/qancode.py in check_response_time(self, urls, item_types, n)
#     492                 if item is not None:
#     493                     url = url + item
# --> 494                 self._average_time_for_get(url, n)
#     495             print()
#
# ~/Applications/pyencoded-tools/qancode/qancode.py in _average_time_for_get(self, url, n)
#     472     def _average_time_for_get(self, url, n):
#     473         self._print_header(url)
# --> 474         time_headers = self._get_time_headers(url, n)
#     475         parsed_headers = [self._parse_header(h) for h in time_headers]
#     476         for key in sorted(parsed_headers[0].keys()):
#
# ~/Applications/pyencoded-tools/qancode/qancode.py in _get_time_headers(url, n)
#     438         for i in range(n):
#     439             r = requests.get(url)
# --> 440             assert r.status_code == 200
#     441             time_headers.append(r.headers)
#     442         return time_headers
#
# AssertionError:

# %%
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB830JLB/ ----------
# Average es_time: 5.518 ± 1.435 ms (n=100)
# Average queue_time: 0.985 ± 0.331 ms (n=100)
# Average render_time: 26.502 ± 4.893 ms (n=100)
# Average wsgi_time: 57.102 ± 101.254 ms (n=100)
# Average total time: 90.107 ± 101.934 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB830JLB/ ------------
# Average es_time: 25.653 ± 6.088 ms (n=100)
# Average queue_time: 0.972 ± 0.237 ms (n=100)
# Average render_time: 25.761 ± 6.312 ms (n=100)
# Average wsgi_time: 66.142 ± 9.27 ms (n=100)
# Average total time: 118.527 ± 17.701 ms (n=100)
#
#
# *** item_type: /ENCAB000BKR/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB000BKR/ ----------
# Average es_time: 4.997 ± 0.79 ms (n=100)
# Average queue_time: 0.978 ± 0.272 ms (n=100)
# Average render_time: 15.453 ± 2.86 ms (n=100)
# Average wsgi_time: 29.162 ± 3.445 ms (n=100)
# Average total time: 50.59 ± 6.231 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB000BKR/ ------------
# Average es_time: 25.823 ± 6.482 ms (n=100)
# Average queue_time: 0.949 ± 0.157 ms (n=100)
# Average render_time: 13.875 ± 3.031 ms (n=100)
# Average wsgi_time: 47.79 ± 7.426 ms (n=100)
# Average total time: 88.438 ± 14.388 ms (n=100)
#
#
# *** item_type: /ENCAB284TTY/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB284TTY/ ----------
# Average es_time: 4.955 ± 0.673 ms (n=100)
# Average queue_time: 0.953 ± 0.1 ms (n=100)
# Average render_time: 18.849 ± 3.474 ms (n=100)
# Average wsgi_time: 37.085 ± 4.32 ms (n=100)
# Average total time: 61.842 ± 7.672 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB284TTY/ ------------
# Average es_time: 25.057 ± 4.058 ms (n=100)
# Average queue_time: 1.028 ± 0.38 ms (n=100)
# Average render_time: 19.319 ± 3.704 ms (n=100)
# Average wsgi_time: 56.923 ± 6.344 ms (n=100)
# Average total time: 102.327 ± 11.382 ms (n=100)
#
#
# *** item_type: /ENCAB294YUD/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB294YUD/ ----------
# Average es_time: 4.719 ± 0.68 ms (n=100)
# Average queue_time: 1.04 ± 0.564 ms (n=100)
# Average render_time: 10.287 ± 2.746 ms (n=100)
# Average wsgi_time: 22.203 ± 3.668 ms (n=100)
# Average total time: 38.248 ± 6.516 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB294YUD/ ------------
# Average es_time: 25.058 ± 5.307 ms (n=100)
# Average queue_time: 0.943 ± 0.161 ms (n=100)
# Average render_time: 10.987 ± 3.182 ms (n=100)
# Average wsgi_time: 42.545 ± 6.96 ms (n=100)
# Average total time: 79.533 ± 13.423 ms (n=100)
#
#
# *** item_type: /ENCAB000AOC/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB000AOC/ ----------
# Average es_time: 5.716 ± 1.057 ms (n=100)
# Average queue_time: 1.096 ± 0.638 ms (n=100)
# Average render_time: 23.016 ± 4.39 ms (n=100)
# Average wsgi_time: 42.324 ± 4.962 ms (n=100)
# Average total time: 72.151 ± 9.365 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB000AOC/ ------------
# Average es_time: 25.86 ± 6.801 ms (n=100)
# Average queue_time: 0.945 ± 0.208 ms (n=100)
# Average render_time: 23.912 ± 4.5 ms (n=100)
# Average wsgi_time: 62.027 ± 9.251 ms (n=100)
# Average total time: 112.744 ± 17.752 ms (n=100)
#
#
# *** item_type: /ENCAB301QZF/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB301QZF/ ----------
# Average es_time: 5.474 ± 0.732 ms (n=100)
# Average queue_time: 0.942 ± 0.282 ms (n=100)
# Average render_time: 18.293 ± 3.247 ms (n=100)
# Average wsgi_time: 33.316 ± 3.59 ms (n=100)
# Average total time: 58.025 ± 6.819 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB301QZF/ ------------
# Average es_time: 25.836 ± 6.074 ms (n=100)
# Average queue_time: 1.077 ± 0.494 ms (n=100)
# Average render_time: 18.46 ± 3.824 ms (n=100)
# Average wsgi_time: 53.416 ± 8.027 ms (n=100)
# Average total time: 98.789 ± 15.523 ms (n=100)
#
#
# *** item_type: /ENCAB000ANM/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB000ANM/ ----------
# Average es_time: 5.383 ± 1.019 ms (n=100)
# Average queue_time: 1.064 ± 0.4 ms (n=100)
# Average render_time: 19.038 ± 3.022 ms (n=100)
# Average wsgi_time: 35.923 ± 3.991 ms (n=100)
# Average total time: 61.409 ± 7.179 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB000ANM/ ------------
# Average es_time: 25.565 ± 4.693 ms (n=100)
# Average queue_time: 1.043 ± 0.35 ms (n=100)
# Average render_time: 20.917 ± 4.278 ms (n=100)
# Average wsgi_time: 57.071 ± 7.128 ms (n=100)
# Average total time: 104.595 ± 13.615 ms (n=100)
#
#
# *** item_type: /ENCAB000ANU/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB000ANU/ ----------
# Average es_time: 4.923 ± 1.152 ms (n=100)
# Average queue_time: 0.953 ± 0.402 ms (n=100)
# Average render_time: 17.483 ± 3.325 ms (n=100)
# Average wsgi_time: 31.797 ± 3.902 ms (n=100)
# Average total time: 55.156 ± 7.027 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB000ANU/ ------------
# Average es_time: 25.282 ± 5.66 ms (n=100)
# Average queue_time: 0.98 ± 0.248 ms (n=100)
# Average render_time: 16.13 ± 3.213 ms (n=100)
# Average wsgi_time: 50.428 ± 7.113 ms (n=100)
# Average total time: 92.821 ± 13.625 ms (n=100)
#
#
# *** item_type: /ENCAB445KMF/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB445KMF/ ----------
# Average es_time: 4.874 ± 0.865 ms (n=100)
# Average queue_time: 0.934 ± 0.139 ms (n=100)
# Average render_time: 17.036 ± 2.71 ms (n=100)
# Average wsgi_time: 32.599 ± 3.684 ms (n=100)
# Average total time: 55.443 ± 6.405 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB445KMF/ ------------
# Average es_time: 25.681 ± 6.152 ms (n=100)
# Average queue_time: 0.973 ± 0.272 ms (n=100)
# Average render_time: 18.545 ± 3.839 ms (n=100)
# Average wsgi_time: 54.054 ± 7.631 ms (n=100)
# Average total time: 99.253 ± 14.737 ms (n=100)
#
#
# *** item_type: /ENCAB000BAY/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCAB000BAY/ ----------
# Average es_time: 5.021 ± 0.77 ms (n=100)
# Average queue_time: 0.999 ± 0.366 ms (n=100)
# Average render_time: 25.128 ± 5.095 ms (n=100)
# Average wsgi_time: 43.376 ± 5.859 ms (n=100)
# Average total time: 74.524 ± 10.838 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCAB000BAY/ ------------
# Average es_time: 25.156 ± 4.119 ms (n=100)
# Average queue_time: 0.972 ± 0.226 ms (n=100)
# Average render_time: 26.323 ± 6.113 ms (n=100)
# Average wsgi_time: 64.303 ± 8.262 ms (n=100)
# Average total time: 116.754 ± 15.546 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS787TFV/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCBS787TFV/ ----------
# Average es_time: 4.864 ± 0.986 ms (n=100)
# Average queue_time: 1.05 ± 0.429 ms (n=100)
# Average render_time: 11.859 ± 2.766 ms (n=100)
# Average wsgi_time: 25.505 ± 4.459 ms (n=100)
# Average total time: 43.278 ± 7.378 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCBS787TFV/ ------------
# Average es_time: 25.605 ± 7.372 ms (n=100)
# Average queue_time: 0.947 ± 0.17 ms (n=100)
# Average render_time: 11.137 ± 2.486 ms (n=100)
# Average wsgi_time: 44.092 ± 8.728 ms (n=100)
# Average total time: 81.781 ± 16.718 ms (n=100)
#
#
# *** item_type: /ENCBS676QAV/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCBS676QAV/ ----------
# Average es_time: 5.545 ± 3.085 ms (n=100)
# Average queue_time: 0.969 ± 0.343 ms (n=100)
# Average render_time: 12.323 ± 1.851 ms (n=100)
# Average wsgi_time: 26.111 ± 4.673 ms (n=100)
# Average total time: 44.948 ± 8.388 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCBS676QAV/ ------------
# Average es_time: 25.96 ± 7.791 ms (n=100)
# Average queue_time: 0.94 ± 0.104 ms (n=100)
# Average render_time: 11.71 ± 2.614 ms (n=100)
# Average wsgi_time: 44.823 ± 9.475 ms (n=100)
# Average total time: 83.433 ± 18.408 ms (n=100)
#
#
# *** item_type: /ENCBS996IWU/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCBS996IWU/ ----------
# Average es_time: 4.511 ± 0.941 ms (n=100)
# Average queue_time: 0.939 ± 0.133 ms (n=100)
# Average render_time: 12.459 ± 1.849 ms (n=100)
# Average wsgi_time: 25.009 ± 3.142 ms (n=100)
# Average total time: 42.918 ± 5.299 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCBS996IWU/ ------------
# Average es_time: 25.715 ± 5.916 ms (n=100)
# Average queue_time: 0.924 ± 0.118 ms (n=100)
# Average render_time: 12.049 ± 2.615 ms (n=100)
# Average wsgi_time: 44.851 ± 7.835 ms (n=100)
# Average total time: 83.54 ± 14.83 ms (n=100)
#
#
# *** item_type: /ENCBS913XJP/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCBS913XJP/ ----------
# Average es_time: 5.367 ± 2.953 ms (n=100)
# Average queue_time: 1.037 ± 0.522 ms (n=100)
# Average render_time: 10.762 ± 1.195 ms (n=100)
# Average wsgi_time: 24.196 ± 3.288 ms (n=100)
# Average total time: 41.362 ± 6.151 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCBS913XJP/ ------------
# Average es_time: 25.199 ± 5.259 ms (n=100)
# Average queue_time: 1.007 ± 0.305 ms (n=100)
# Average render_time: 10.45 ± 2.316 ms (n=100)
# Average wsgi_time: 43.608 ± 6.361 ms (n=100)
# Average total time: 80.264 ± 12.121 ms (n=100)
#
#
# *** item_type: /ENCBS565NTN/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCBS565NTN/ ----------
# Average es_time: 4.913 ± 0.905 ms (n=100)
# Average queue_time: 1.074 ± 0.536 ms (n=100)
# Average render_time: 10.939 ± 1.591 ms (n=100)
# Average wsgi_time: 24.042 ± 3.003 ms (n=100)
# Average total time: 40.968 ± 4.724 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCBS565NTN/ ------------
# Average es_time: 25.926 ± 6.461 ms (n=100)
# Average queue_time: 1.155 ± 0.652 ms (n=100)
# Average render_time: 10.465 ± 2.831 ms (n=100)
# Average wsgi_time: 44.061 ± 7.377 ms (n=100)
# Average total time: 81.607 ± 14.343 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCBS896YZO/ ----------
# Average es_time: 5.072 ± 1.266 ms (n=100)
# Average queue_time: 1.096 ± 0.605 ms (n=100)
# Average render_time: 18.307 ± 3.067 ms (n=100)
# Average wsgi_time: 33.912 ± 4.255 ms (n=100)
# Average total time: 58.387 ± 7.405 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCBS896YZO/ ------------
# Average es_time: 25.291 ± 5.661 ms (n=100)
# Average queue_time: 1.083 ± 0.63 ms (n=100)
# Average render_time: 20.122 ± 4.292 ms (n=100)
# Average wsgi_time: 54.889 ± 7.882 ms (n=100)
# Average total time: 101.385 ± 15.205 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ---------- https://dup-v64rc0-master.demo.encodedcc.org//ENCBS280NYD/ ----------
# Average es_time: 4.485 ± 0.885 ms (n=100)
# Average queue_time: 0.845 ± 0.139 ms (n=100)
# Average render_time: 11.548 ± 2.765 ms (n=100)
# Average wsgi_time: 23.571 ± 3.607 ms (n=100)
# Average total time: 40.448 ± 6.391 ms (n=100)
# ------------ https://v65rc2-master.demo.encodedcc.org//ENCBS280NYD/ ------------
# Average es_time: 26.05 ± 6.487 ms (n=100)
# Average queue_time: 1.044 ± 0.503 ms (n=100)
# Average render_time: 11.237 ± 3.422 ms (n=100)
# Average wsgi_time: 44.961 ± 9.097 ms (n=100)
# Average total time: 83.292 ± 17.038 ms (n=100)
