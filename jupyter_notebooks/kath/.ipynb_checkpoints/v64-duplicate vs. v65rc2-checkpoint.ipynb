# %%
import sys
sys.path.append('../..')
import qancode

# %%
#comparing to v65rc2 site
qa = qancode.QANCODE(rc_url="https://series5-test-master.demo.encodedcc.org/", prod_url="https://v67rc1-master.demo.encodedcc.org/")

# %%
qa.check_response_time(item_types=["/","/search/?type=Experiment"], n=100)
# Out:
# Checking response time
#
# *** item_type: /
# ------------------ https://v67rc1-master.demo.encodedcc.org// ------------------
# Average es_time: 43.641 ± 5.736 ms (n=100)
# Average queue_time: 1.228 ± 0.46 ms (n=100)
# Average render_time: 8.924 ± 2.705 ms (n=100)
# Average wsgi_time: 63.508 ± 8.085 ms (n=100)
# Average total time: 117.3 ± 14.63 ms (n=100)
# --------------- https://series5-test-master.demo.encodedcc.org// ---------------
# Average es_time: 20.198 ± 2.972 ms (n=100)
# Average queue_time: 0.458 ± 0.026 ms (n=100)
# Average render_time: 4.348 ± 1.255 ms (n=100)
# Average wsgi_time: 28.376 ± 3.311 ms (n=100)
# Average total time: 53.381 ± 6.612 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment
# ------ https://v67rc1-master.demo.encodedcc.org//search/?type=Experiment -------
# Average es_time: 30.541 ± 9.739 ms (n=100)
# Average queue_time: 1.459 ± 0.73 ms (n=100)
# Average render_time: 153.862 ± 16.943 ms (n=100)
# Average wsgi_time: 214.367 ± 36.73 ms (n=100)
# Average total time: 400.229 ± 51.638 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//search/?type=Experiment ---------
# Average es_time: 19.734 ± 5.574 ms (n=100)
# Average queue_time: 0.478 ± 0.014 ms (n=100)
# Average render_time: 117.199 ± 13.892 ms (n=100)
# Average wsgi_time: 162.229 ± 91.072 ms (n=100)
# Average total time: 299.64 ± 94.824 ms (n=100)

# %%
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ------ https://v67rc1-master.demo.encodedcc.org//search/?searchTerm=K562 -------
# Average es_time: 247.231 ± 30.918 ms (n=100)
# Average queue_time: 1.578 ± 0.818 ms (n=100)
# Average render_time: 34.22 ± 8.142 ms (n=100)
# Average wsgi_time: 300.096 ± 34.175 ms (n=100)
# Average total time: 583.125 ± 67.757 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//search/?searchTerm=K562 ---------
# Average es_time: 120.489 ± 8.79 ms (n=100)
# Average queue_time: 0.474 ± 0.017 ms (n=100)
# Average render_time: 20.121 ± 7.004 ms (n=100)
# Average wsgi_time: 147.443 ± 12.09 ms (n=100)
# Average total time: 288.526 ± 24.21 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# --------- https://v67rc1-master.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 340.179 ± 63.128 ms (n=100)
# Average queue_time: 1.469 ± 0.64 ms (n=100)
# Average render_time: 35.093 ± 7.38 ms (n=100)
# Average wsgi_time: 398.883 ± 67.904 ms (n=100)
# Average total time: 775.624 ± 132.959 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 159.085 ± 12.011 ms (n=100)
# Average queue_time: 0.47 ± 0.011 ms (n=100)
# Average render_time: 19.867 ± 4.934 ms (n=100)
# Average wsgi_time: 187.435 ± 13.637 ms (n=100)
# Average total time: 366.857 ± 27.199 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=human
# ------ https://v67rc1-master.demo.encodedcc.org//search/?searchTerm=human ------
# Average es_time: 243.735 ± 31.568 ms (n=100)
# Average queue_time: 1.432 ± 0.65 ms (n=100)
# Average render_time: 35.856 ± 7.386 ms (n=100)
# Average wsgi_time: 297.734 ± 34.868 ms (n=100)
# Average total time: 578.757 ± 68.995 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//search/?searchTerm=human ---------
# Average es_time: 121.703 ± 7.659 ms (n=100)
# Average queue_time: 0.47 ± 0.014 ms (n=100)
# Average render_time: 18.827 ± 3.831 ms (n=100)
# Average wsgi_time: 147.28 ± 8.454 ms (n=100)
# Average total time: 288.28 ± 16.851 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# ---- https://v67rc1-master.demo.encodedcc.org//search/?searchTerm=H3K36me3 -----
# Average es_time: 247.82 ± 22.696 ms (n=100)
# Average queue_time: 1.355 ± 0.572 ms (n=100)
# Average render_time: 36.565 ± 6.737 ms (n=100)
# Average wsgi_time: 303.303 ± 24.603 ms (n=100)
# Average total time: 589.044 ± 48.642 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//search/?searchTerm=H3K36me3 ---------
# Average es_time: 121.9 ± 10.281 ms (n=100)
# Average queue_time: 0.471 ± 0.013 ms (n=100)
# Average render_time: 19.539 ± 5.396 ms (n=100)
# Average wsgi_time: 148.45 ± 12.007 ms (n=100)
# Average total time: 290.36 ± 24.005 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=CTCF
# ------ https://v67rc1-master.demo.encodedcc.org//search/?searchTerm=CTCF -------
# Average es_time: 251.685 ± 30.658 ms (n=100)
# Average queue_time: 1.401 ± 0.623 ms (n=100)
# Average render_time: 34.813 ± 6.195 ms (n=100)
# Average wsgi_time: 304.38 ± 33.823 ms (n=100)
# Average total time: 592.279 ± 67.151 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//search/?searchTerm=CTCF ---------
# Average es_time: 119.805 ± 8.078 ms (n=100)
# Average queue_time: 0.47 ± 0.014 ms (n=100)
# Average render_time: 18.566 ± 5.193 ms (n=100)
# Average wsgi_time: 144.951 ± 9.561 ms (n=100)
# Average total time: 283.792 ± 19.158 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR255XZG/ ------------
# Average es_time: 55.435 ± 8.724 ms (n=100)
# Average queue_time: 1.645 ± 0.848 ms (n=100)
# Average render_time: 127.78 ± 8.627 ms (n=100)
# Average wsgi_time: 307.997 ± 131.595 ms (n=100)
# Average total time: 492.857 ± 133.71 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR255XZG/ ---------
# Average es_time: 29.644 ± 6.814 ms (n=100)
# Average queue_time: 1.342 ± 8.583 ms (n=100)
# Average render_time: 100.909 ± 5.225 ms (n=100)
# Average wsgi_time: 219.994 ± 108.024 ms (n=100)
# Average total time: 351.888 ± 112.01 ms (n=100)
#
#
# *** item_type: /ENCSR749ILN/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR749ILN/ ------------
# Average es_time: 48.427 ± 4.362 ms (n=100)
# Average queue_time: 1.583 ± 0.674 ms (n=100)
# Average render_time: 34.947 ± 6.31 ms (n=100)
# Average wsgi_time: 111.486 ± 9.197 ms (n=100)
# Average total time: 196.443 ± 17.044 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR749ILN/ ---------
# Average es_time: 23.69 ± 3.865 ms (n=100)
# Average queue_time: 0.475 ± 0.009 ms (n=100)
# Average render_time: 20.834 ± 4.134 ms (n=100)
# Average wsgi_time: 59.105 ± 5.936 ms (n=100)
# Average total time: 104.103 ± 11.713 ms (n=100)
#
#
# *** item_type: /ENCSR688GVV/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR688GVV/ ------------
# Average es_time: 55.845 ± 5.704 ms (n=100)
# Average queue_time: 1.716 ± 0.834 ms (n=100)
# Average render_time: 70.328 ± 8.276 ms (n=100)
# Average wsgi_time: 188.543 ± 75.737 ms (n=100)
# Average total time: 316.432 ± 76.676 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR688GVV/ ---------
# Average es_time: 28.696 ± 3.626 ms (n=100)
# Average queue_time: 0.481 ± 0.011 ms (n=100)
# Average render_time: 49.869 ± 4.111 ms (n=100)
# Average wsgi_time: 113.044 ± 5.986 ms (n=100)
# Average total time: 192.09 ± 11.714 ms (n=100)
#
#
# *** item_type: /ENCSR301HAG/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR301HAG/ ------------
# Average es_time: 46.166 ± 4.401 ms (n=100)
# Average queue_time: 1.672 ± 0.801 ms (n=100)
# Average render_time: 19.887 ± 35.706 ms (n=100)
# Average wsgi_time: 82.21 ± 36.266 ms (n=100)
# Average total time: 149.935 ± 72.54 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR301HAG/ ---------
# Average es_time: 21.248 ± 2.508 ms (n=100)
# Average queue_time: 0.48 ± 0.011 ms (n=100)
# Average render_time: 7.292 ± 2.202 ms (n=100)
# Average wsgi_time: 34.026 ± 3.386 ms (n=100)
# Average total time: 63.046 ± 6.685 ms (n=100)
#
#
# *** item_type: /ENCSR315NAC/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR315NAC/ ------------
# Average es_time: 53.566 ± 6.047 ms (n=100)
# Average queue_time: 1.691 ± 1.269 ms (n=100)
# Average render_time: 58.099 ± 9.342 ms (n=100)
# Average wsgi_time: 166.66 ± 90.6 ms (n=100)
# Average total time: 280.016 ± 91.567 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR315NAC/ ---------
# Average es_time: 26.854 ± 2.471 ms (n=100)
# Average queue_time: 0.477 ± 0.011 ms (n=100)
# Average render_time: 39.787 ± 4.783 ms (n=100)
# Average wsgi_time: 101.165 ± 70.588 ms (n=100)
# Average total time: 168.283 ± 71.092 ms (n=100)
#
#
# *** item_type: /ENCSR856JJB/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR856JJB/ ------------
# Average es_time: 53.123 ± 5.009 ms (n=100)
# Average queue_time: 1.647 ± 0.911 ms (n=100)
# Average render_time: 52.026 ± 7.765 ms (n=100)
# Average wsgi_time: 146.999 ± 10.763 ms (n=100)
# Average total time: 253.796 ± 19.724 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR856JJB/ ---------
# Average es_time: 26.584 ± 3.355 ms (n=100)
# Average queue_time: 0.476 ± 0.012 ms (n=100)
# Average render_time: 34.315 ± 4.205 ms (n=100)
# Average wsgi_time: 91.577 ± 68.751 ms (n=100)
# Average total time: 152.954 ± 68.975 ms (n=100)

# %%
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR480OHP/ ------------
# Average es_time: 49.248 ± 7.209 ms (n=100)
# Average queue_time: 1.59 ± 0.959 ms (n=100)
# Average render_time: 35.152 ± 5.85 ms (n=100)
# Average wsgi_time: 113.677 ± 11.161 ms (n=100)
# Average total time: 199.667 ± 20.251 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR480OHP/ ---------
# Average es_time: 23.853 ± 4.252 ms (n=100)
# Average queue_time: 0.473 ± 0.011 ms (n=100)
# Average render_time: 20.966 ± 3.594 ms (n=100)
# Average wsgi_time: 66.685 ± 66.256 ms (n=100)
# Average total time: 111.976 ± 66.883 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR000EMB/ ------------
# Average es_time: 48.658 ± 6.125 ms (n=100)
# Average queue_time: 1.539 ± 0.753 ms (n=100)
# Average render_time: 53.329 ± 8.469 ms (n=100)
# Average wsgi_time: 148.721 ± 76.744 ms (n=100)
# Average total time: 252.247 ± 78.559 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR000EMB/ ---------
# Average es_time: 23.27 ± 2.562 ms (n=100)
# Average queue_time: 0.474 ± 0.014 ms (n=100)
# Average render_time: 36.819 ± 4.667 ms (n=100)
# Average wsgi_time: 85.352 ± 5.565 ms (n=100)
# Average total time: 145.913 ± 11.049 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR323QIP/ ------------
# Average es_time: 59.852 ± 5.207 ms (n=100)
# Average queue_time: 1.699 ± 1.042 ms (n=100)
# Average render_time: 149.958 ± 7.728 ms (n=100)
# Average wsgi_time: 378.194 ± 200.862 ms (n=100)
# Average total time: 589.703 ± 201.571 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR323QIP/ ---------
# Average es_time: 32.175 ± 3.36 ms (n=100)
# Average queue_time: 0.48 ± 0.01 ms (n=100)
# Average render_time: 122.909 ± 4.222 ms (n=100)
# Average wsgi_time: 279.625 ± 129.661 ms (n=100)
# Average total time: 435.189 ± 131.305 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR718AXQ/ ------------
# Average es_time: 49.831 ± 5.527 ms (n=100)
# Average queue_time: 1.585 ± 0.908 ms (n=100)
# Average render_time: 25.462 ± 5.129 ms (n=100)
# Average wsgi_time: 97.683 ± 8.911 ms (n=100)
# Average total time: 174.561 ± 16.623 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR718AXQ/ ---------
# Average es_time: 24.651 ± 4.37 ms (n=100)
# Average queue_time: 0.469 ± 0.015 ms (n=100)
# Average render_time: 13.743 ± 3.976 ms (n=100)
# Average wsgi_time: 47.904 ± 5.918 ms (n=100)
# Average total time: 86.766 ± 11.576 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR165BGV/ ------------
# Average es_time: 46.408 ± 5.364 ms (n=100)
# Average queue_time: 1.582 ± 0.76 ms (n=100)
# Average render_time: 28.021 ± 5.87 ms (n=100)
# Average wsgi_time: 96.965 ± 8.251 ms (n=100)
# Average total time: 172.976 ± 15.625 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR165BGV/ ---------
# Average es_time: 21.831 ± 4.543 ms (n=100)
# Average queue_time: 0.477 ± 0.012 ms (n=100)
# Average render_time: 16.355 ± 3.76 ms (n=100)
# Average wsgi_time: 48.902 ± 6.487 ms (n=100)
# Average total time: 87.565 ± 12.923 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR384KAN/ ------------
# Average es_time: 52.972 ± 5.834 ms (n=100)
# Average queue_time: 1.706 ± 0.932 ms (n=100)
# Average render_time: 49.502 ± 7.612 ms (n=100)
# Average wsgi_time: 144.096 ± 10.827 ms (n=100)
# Average total time: 248.276 ± 21.148 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR384KAN/ ---------
# Average es_time: 26.172 ± 3.102 ms (n=100)
# Average queue_time: 0.472 ± 0.01 ms (n=100)
# Average render_time: 32.696 ± 4.335 ms (n=100)
# Average wsgi_time: 89.048 ± 65.064 ms (n=100)
# Average total time: 148.388 ± 65.329 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR330FXL/ ------------
# Average es_time: 47.005 ± 10.829 ms (n=100)
# Average queue_time: 1.339 ± 0.644 ms (n=100)
# Average render_time: 31.984 ± 5.899 ms (n=100)
# Average wsgi_time: 104.802 ± 14.101 ms (n=100)
# Average total time: 185.131 ± 25.715 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR330FXL/ ---------
# Average es_time: 21.27 ± 3.32 ms (n=100)
# Average queue_time: 0.46 ± 0.01 ms (n=100)
# Average render_time: 19.611 ± 3.139 ms (n=100)
# Average wsgi_time: 57.237 ± 32.377 ms (n=100)
# Average total time: 98.577 ± 33.33 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR825UNV/ ------------
# Average es_time: 60.881 ± 6.646 ms (n=100)
# Average queue_time: 1.917 ± 0.956 ms (n=100)
# Average render_time: 176.879 ± 8.834 ms (n=100)
# Average wsgi_time: 412.39 ± 165.104 ms (n=100)
# Average total time: 652.068 ± 167.389 ms (n=100)
# --------- https://series5-test-master.demo.encodedcc.org//ENCSR825UNV/ ---------
# Average es_time: 32.656 ± 4.562 ms (n=100)
# Average queue_time: 0.485 ± 0.012 ms (n=100)
# Average render_time: 148.88 ± 3.654 ms (n=100)
# Average wsgi_time: 362.182 ± 207.96 ms (n=100)
# Average total time: 544.202 ± 208.411 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------ https://v67rc1-master.demo.encodedcc.org//ENCSR089EOA/ ------------

# %%
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=100)

# %%
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=100)
