# %%
import qancode

# %%
qa = qancode.QANCODE(prod_url="https://encd-3132-delete.demo.encodedcc.org/", rc_url="https://delete-test.demo.encodedcc.org/")

# %%
#comparison as public user
qa.compare_facets(users=['Public'], browsers=['Safari'], browser_comparison=False)
# Out:
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Library
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=AntibodyLot
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Biosample
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Donor
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: search/?type=GeneticModification
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=FileSet
# ...

# %%
#comparison as admin user
qa.compare_facets(users=['encoded.test4@gmail.com'], browsers=['Safari'], browser_comparison=False)
# Out:
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Library
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=AntibodyLot
# Search page detected
# Opening https://encd-3132-delete.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Biosample
# ...
