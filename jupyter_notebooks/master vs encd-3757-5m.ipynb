# %%
import qancode

# %%
qa = qancode.QANCODE(prod_url="https://master-3757-compare-idan.demo.encodedcc.org/", rc_url="https://encd-3757-5m-idan.demo.encodedcc.org/")

# %%
#public view of site master vs encd-3757-5m
qa.compare_facets(users=['Public'], browsers=['Safari'], item_types=['/search/?type=Experiment', '/search/?type=File', '/search/?type=Annotation'], browser_comparison=False)
# Out:
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=File
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Annotation
# Search page detected
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Item type: /search/?type=Experiment
# Assay
#      MATCH
# Assay category
#      MATCH
# AUDIT CATEGORY
#      control extremely low read depth: 68 (prod), 82 (rc)
#      extremely low read depth: 124 (prod), 213 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 1362 (prod), 1353 (rc)
#      insufficient read depth: 1864 (prod), 1811 (rc)
# AUDIT CATEGORY3
#      control low read depth: 758 (prod), 763 (rc)
# Available data
#      MATCH
# Biosample treatment
#      MATCH
# Biosample type
#      MATCH
# Date Submitted
#      MATCH
# Date released
#      MATCH
# Experiment status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Library depleted in
#      MATCH
# Library insert size (nt)
#      MATCH
# Library made from
#      MATCH
# Library treatment
#      MATCH
# Life stage
#      MATCH
# Mapped read length (nt)
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Replication type
#      MATCH
# Run type
#      MATCH
# Target of assay
#      MATCH
#
# ------------------------------------- File -------------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Item type: /search/?type=File
# AUDIT CATEGORY
#      control extremely low read depth: 160 (prod), 213 (rc)
#      extremely low read depth: 319 (prod), 632 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 3996 (prod), 3965 (rc)
#      insufficient read depth: 5654 (prod), 5473 (rc)
# AUDIT CATEGORY3
#      control low read depth: 2443 (prod), 2476 (rc)
# Content category
#      MATCH
# Content type
#      MATCH
# File format
#      MATCH
# File status
#      MATCH
# Lab
#      MATCH
# Mapping assembly
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# Specific file format type
#      MATCH
#
# ---------------------------------- Annotation ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Item type: /search/?type=Annotation
# Annotation type
#      MATCH
# Assay
#      MATCH
# Audit category
#      MATCH
# Available data
#      MATCH
# Biosample type
#      MATCH
# Date released
#      MATCH
# Encyclopedia version
#      MATCH
# File set status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Life stage
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Run type
#      MATCH
# Software used
#      MATCH
# Target(s) of assay
#      MATCH
# Target(s) of assay2
#      MATCH

# %%
#admin view of site master vs encd-3757-5m
qa.compare_facets(users=['encoded.test4@gmail.com'], browsers=['Safari'], item_types=['/search/?type=Experiment', '/search/?type=File', '/search/?type=Annotation'], browser_comparison=False)
# Out:
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Annotation
# Search page detected
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Item type: /search/?type=Experiment
# Assay
#      MATCH
# Assay category
#      MATCH
# AUDIT CATEGORY
#      control extremely low read depth: 68 (prod), 82 (rc)
#      extremely low read depth: 124 (prod), 214 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 1362 (prod), 1353 (rc)
#      insufficient read depth: 1876 (prod), 1822 (rc)
# AUDIT CATEGORY3
#      control low read depth: 765 (prod), 770 (rc)
# AUDIT CATEGORY4
#      prod: [('low read depth', '667')]
#      rc: [('insufficient read depth for broad peaks control', '667')]
# Available data
#      MATCH
# Biosample treatment
#      MATCH
# Biosample type
#      MATCH
# Date Submitted
#      MATCH
# Date released
#      MATCH
# Experiment status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Library depleted in
#      MATCH
# Library insert size (nt)
#      MATCH
# Library made from
#      MATCH
# Library treatment
#      MATCH
# Life stage
#      MATCH
# Mapped read length (nt)
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Replication type
#      MATCH
# Run type
#      MATCH
# Target of assay
#      MATCH
#
# ------------------------------------- File -------------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Item type: /search/?type=File
# AUDIT CATEGORY
#      control extremely low read depth: 172 (prod), 225 (rc)
#      extremely low read depth: 336 (prod), 668 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 4314 (prod), 4297 (rc)
#      insufficient read depth: 6388 (prod), 6198 (rc)
# AUDIT CATEGORY3
#      control low read depth: 2588 (prod), 2631 (rc)
# AUDIT CATEGORY4
#      prod: [('low read depth', '1761')]
#      rc: [('insufficient read depth for broad peaks control', '1761')]
# Content category
#      MATCH
# Content type
#      MATCH
# File format
#      MATCH
# File status
#      MATCH
# Lab
#      MATCH
# Mapping assembly
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# Specific file format type
#      MATCH
#
# ---------------------------------- Annotation ----------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Item type: /search/?type=Annotation
# Annotation type
#      MATCH
# Assay
#      MATCH
# Audit category
#      MATCH
# Audit category2
#      MATCH
# Available data
#      MATCH
# Biosample type
#      MATCH
# Date released
#      MATCH
# Encyclopedia version
#      MATCH
# File set status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Life stage
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Run type
#      MATCH
# Software used
#      MATCH
# Target(s) of assay
#      MATCH
# Target(s) of assay2
#      MATCH

# %%
qa = qancode.QANCODE(prod_url="https://master-3757-compare-idan.demo.encodedcc.org/", rc_url="https://encd-3757-5m-35m-idan.demo.encodedcc.org/")

# %%
#public view of site master vs encd-3757-5m-35m
qa.compare_facets(users=['Public'], browsers=['Safari'], item_types=['/search/?type=Experiment', '/search/?type=File', '/search/?type=Annotation'], browser_comparison=False)
# Out:
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=File
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Getting type: /search/?type=Annotation
# Search page detected
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=Experiment
# Assay
#      MATCH
# Assay category
#      MATCH
# AUDIT CATEGORY
#      control extremely low read depth: 68 (prod), 82 (rc)
#      extremely low read depth: 124 (prod), 213 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 1362 (prod), 1266 (rc)
#      insufficient read depth: 1864 (prod), 1746 (rc)
# AUDIT CATEGORY3
#      control low read depth: 758 (prod), 875 (rc)
#      low read depth: 2421 (prod), 2512 (rc)
# Available data
#      MATCH
# Biosample treatment
#      MATCH
# Biosample type
#      MATCH
# Date Submitted
#      MATCH
# Date released
#      MATCH
# Experiment status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Library depleted in
#      MATCH
# Library insert size (nt)
#      MATCH
# Library made from
#      MATCH
# Library treatment
#      MATCH
# Life stage
#      MATCH
# Mapped read length (nt)
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Replication type
#      MATCH
# Run type
#      MATCH
# Target of assay
#      MATCH
#
# ------------------------------------- File -------------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=File
# AUDIT CATEGORY
#      control extremely low read depth: 160 (prod), 213 (rc)
#      extremely low read depth: 319 (prod), 632 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 3996 (prod), 3692 (rc)
#      insufficient read depth: 5654 (prod), 5276 (rc)
# AUDIT CATEGORY3
#      control low read depth: 2443 (prod), 2840 (rc)
#      low read depth: 8487 (prod), 8747 (rc)
# Content category
#      MATCH
# Content type
#      MATCH
# File format
#      MATCH
# File status
#      MATCH
# Lab
#      MATCH
# Mapping assembly
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# Specific file format type
#      MATCH
#
# ---------------------------------- Annotation ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=Annotation
# Annotation type
#      MATCH
# Assay
#      MATCH
# Audit category
#      MATCH
# Available data
#      MATCH
# Biosample type
#      MATCH
# Date released
#      MATCH
# Encyclopedia version
#      MATCH
# File set status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Life stage
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Run type
#      MATCH
# Software used
#      MATCH
# Target(s) of assay
#      MATCH
# Target(s) of assay2
#      MATCH

# %%
#admin view of site master vs encd-3757-5m-35m
qa.compare_facets(users=['encoded.test4@gmail.com'], browsers=['Safari'], item_types=['/search/?type=Experiment', '/search/?type=File', '/search/?type=Annotation'], browser_comparison=False)
# Out:
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://master-3757-compare-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Annotation
# Search page detected
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=Experiment
# Assay
#      MATCH
# Assay category
#      MATCH
# AUDIT CATEGORY
#      control extremely low read depth: 68 (prod), 82 (rc)
#      extremely low read depth: 124 (prod), 214 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 1362 (prod), 1266 (rc)
#      insufficient read depth: 1876 (prod), 1757 (rc)
# AUDIT CATEGORY3
#      control low read depth: 765 (prod), 882 (rc)
#      low read depth: 2468 (prod), 2559 (rc)
# AUDIT CATEGORY4
#      prod: [('low read depth', '667')]
#      rc: [('insufficient read depth for broad peaks control', '667')]
# Available data
#      MATCH
# Biosample treatment
#      MATCH
# Biosample type
#      MATCH
# Date Submitted
#      MATCH
# Date released
#      MATCH
# Experiment status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Library depleted in
#      MATCH
# Library insert size (nt)
#      MATCH
# Library made from
#      MATCH
# Library treatment
#      MATCH
# Life stage
#      MATCH
# Mapped read length (nt)
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Replication type
#      MATCH
# Run type
#      MATCH
# Target of assay
#      MATCH
#
# ------------------------------------- File -------------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=File
# AUDIT CATEGORY
#      control extremely low read depth: 172 (prod), 225 (rc)
#      extremely low read depth: 336 (prod), 668 (rc)
# AUDIT CATEGORY2
#      control insufficient read depth: 4314 (prod), 3935 (rc)
#      insufficient read depth: 6388 (prod), 5955 (rc)
# AUDIT CATEGORY3
#      control low read depth: 2588 (prod), 3074 (rc)
#      low read depth: 9420 (prod), 9734 (rc)
# AUDIT CATEGORY4
#      prod: [('low read depth', '1761')]
#      rc: [('insufficient read depth for broad peaks control', '1761')]
# Content category
#      MATCH
# Content type
#      MATCH
# File format
#      MATCH
# File status
#      MATCH
# Lab
#      MATCH
# Mapping assembly
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# Specific file format type
#      MATCH
#
# ---------------------------------- Annotation ----------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://master-3757-compare-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=Annotation
# Annotation type
#      MATCH
# Assay
#      MATCH
# Audit category
#      MATCH
# Audit category2
#      MATCH
# Available data
#      MATCH
# Biosample type
#      MATCH
# Date released
#      MATCH
# Encyclopedia version
#      MATCH
# File set status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Life stage
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Run type
#      MATCH
# Software used
#      MATCH
# Target(s) of assay
#      MATCH
# Target(s) of assay2
#      MATCH

# %%
qa = qancode.QANCODE(prod_url="https://encd-3757-5m-idan.demo.encodedcc.org/", rc_url="https://encd-3757-5m-35m-idan.demo.encodedcc.org/")

# %%
#admin view of site encd-3757-5m vs encd-3757-5m-35m
qa.compare_facets(users=['encoded.test4@gmail.com'], browsers=['Safari'], item_types=['/search/?type=Experiment', '/search/?type=File', '/search/?type=Annotation'], browser_comparison=False)
# Out:
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3757-5m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=File
# Search page detected
# Opening https://encd-3757-5m-35m-idan.demo.encodedcc.org/ in Safari
# Logging in as encoded.test4@gmail.com
# Login successful
# Refreshing.
# Getting type: /search/?type=Annotation
# Search page detected
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=Experiment
# Assay
#      MATCH
# Assay category
#      MATCH
# Audit category
#      MATCH
# AUDIT CATEGORY2
#      control insufficient read depth: 1353 (prod), 1266 (rc)
#      insufficient read depth: 1822 (prod), 1757 (rc)
# AUDIT CATEGORY3
#      control low read depth: 770 (prod), 882 (rc)
#      low read depth: 2468 (prod), 2559 (rc)
# Audit category4
#      MATCH
# Available data
#      MATCH
# Biosample treatment
#      MATCH
# Biosample type
#      MATCH
# Date Submitted
#      MATCH
# Date released
#      MATCH
# Experiment status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Library depleted in
#      MATCH
# Library insert size (nt)
#      MATCH
# Library made from
#      MATCH
# Library treatment
#      MATCH
# Life stage
#      MATCH
# Mapped read length (nt)
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Replication type
#      MATCH
# Run type
#      MATCH
# Target of assay
#      MATCH
#
# ------------------------------------- File -------------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=File
# Audit category
#      MATCH
# AUDIT CATEGORY2
#      control insufficient read depth: 4297 (prod), 3935 (rc)
#      insufficient read depth: 6198 (prod), 5955 (rc)
# AUDIT CATEGORY3
#      control low read depth: 2631 (prod), 3074 (rc)
#      low read depth: 9420 (prod), 9734 (rc)
# Audit category4
#      MATCH
# Content category
#      MATCH
# Content type
#      MATCH
# File format
#      MATCH
# File status
#      MATCH
# Lab
#      MATCH
# Mapping assembly
#      MATCH
# Platform
#      MATCH
# Project
#      MATCH
# Specific file format type
#      MATCH
#
# ---------------------------------- Annotation ----------------------------------
# Comparing data between URLs.
# As user: encoded.test4@gmail.com
# Browser: Safari
# First URL: https://encd-3757-5m-idan.demo.encodedcc.org/
# Second URL: https://encd-3757-5m-35m-idan.demo.encodedcc.org/
# Item type: /search/?type=Annotation
# Annotation type
#      MATCH
# Assay
#      MATCH
# Audit category
#      MATCH
# Audit category2
#      MATCH
# Available data
#      MATCH
# Biosample type
#      MATCH
# Date released
#      MATCH
# Encyclopedia version
#      MATCH
# File set status
#      MATCH
# Genome assembly (visualization)
#      MATCH
# Lab
#      MATCH
# Life stage
#      MATCH
# Organ
#      MATCH
# Organism
#      MATCH
# Project
#      MATCH
# RFA
#      MATCH
# Read length (nt)
#      MATCH
# Run type
#      MATCH
# Software used
#      MATCH
# Target(s) of assay
#      MATCH
# Target(s) of assay2
#      MATCH
