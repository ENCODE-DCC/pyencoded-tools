# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('..')
import qancode
import numpy as np
import pandas as pd

# %%
#compare any two encoded instances here
qa = qancode.QANCODE(rc_url="https://test.encodedcc.org", prod_url='https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org/')

# %%
res = qa.check_response_time(item_types=["/","/search/?type=Experiment"], n=50)
# Out:
# Checking response time
#
# *** item_type: /
# ---------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org// ----------
# Average es_time: 0.733 ± 0.051 ms (n=50)
# Average queue_time: 0.37 ± 0.032 ms (n=50)
# Average render_time: 3.005 ± 0.283 ms (n=50)
# Average wsgi_time: 7.108 ± 0.454 ms (n=50)
# Average total time: 11.216 ± 0.764 ms (n=50)
# ------------------------- https://test.encodedcc.org/ --------------------------
# Average es_time: 13.38 ± 3.615 ms (n=50)
# Average queue_time: 0.421 ± 0.017 ms (n=50)
# Average render_time: 3.946 ± 1.37 ms (n=50)
# Average wsgi_time: 21.032 ± 4.176 ms (n=50)
# Average total time: 38.779 ± 8.338 ms (n=50)
#
#
# *** item_type: /search/?type=Experiment
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?type=Experiment ---------
# Average es_time: 14.774 ± 1.608 ms (n=50)
# Average queue_time: 0.473 ± 0.013 ms (n=50)
# Average render_time: 110.853 ± 10.258 ms (n=50)
# Average wsgi_time: 140.347 ± 11.087 ms (n=50)
# Average total time: 266.447 ± 21.867 ms (n=50)
# -------------- https://test.encodedcc.org/search/?type=Experiment --------------
# Average es_time: 22.591 ± 6.109 ms (n=50)
# Average queue_time: 0.473 ± 0.014 ms (n=50)
# Average render_time: 110.62 ± 15.968 ms (n=50)
# Average wsgi_time: 148.084 ± 18.568 ms (n=50)
# Average total time: 281.768 ± 37.016 ms (n=50)

# %%
res
# Out:
#                   https://es-frontend2.demo.encodedcc.org/  \
# es_time_mean                                        16.256
# es_time_std                                          2.587
# es_time_N                                           50.000
# queue_time_mean                                      1.119
# queue_time_std                                       0.274
# queue_time_N                                        50.000
# render_time_mean                                    10.741
# render_time_std                                      3.374
# render_time_N                                       50.000
# wsgi_time_mean                                      37.187
# wsgi_time_std                                        5.298
# wsgi_time_N                                         50.000
# total_mean                                          65.303
# total_std                                            9.447
# total_N                                             50.000
#
#                   https://es-frontend2.demo.encodedcc.org/search/?type=Experiment  \
# es_time_mean                                                 25.668
# es_time_std                                                   6.929
# es_time_N                                                    50.000
# queue_time_mean                                               1.068
# queue_time_std                                                0.428
# queue_time_N                                                 50.000
# render_time_mean                                            150.630
# render_time_std                                              14.479
# render_time_N                                                50.000
# wsgi_time_mean                                              202.899
# wsgi_time_std                                                17.418
# wsgi_time_N                                                  50.000
# total_mean                                                  380.264
# total_std                                                    34.508
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/  \
# es_time_mean                           13.313
# es_time_std                             3.475
# es_time_N                              50.000
# queue_time_mean                         0.435
# queue_time_std                          0.032
# queue_time_N                           50.000
# render_time_mean                        4.018
# render_time_std                         1.527
# render_time_N                          50.000
# wsgi_time_mean                         20.967
# wsgi_time_std                           4.047
# wsgi_time_N                            50.000
# total_mean                             38.734
# total_std                               8.126
# total_N                                50.000
#
#                   https://test.encodedcc.org/search/?type=Experiment
# es_time_mean                                                 24.365
# es_time_std                                                   7.398
# es_time_N                                                    50.000
# queue_time_mean                                               0.478
# queue_time_std                                                0.013
# queue_time_N                                                 50.000
# render_time_mean                                            108.651
# render_time_std                                              14.653
# render_time_N                                                50.000
# wsgi_time_mean                                              147.731
# wsgi_time_std                                                16.097
# wsgi_time_N                                                  50.000
# total_mean                                                  281.225
# total_std                                                    32.119
# total_N                                                      50.000

# %%
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=50)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=K562 ---------
# Average es_time: 157.582 ± 3.94 ms (n=50)
# Average queue_time: 0.482 ± 0.009 ms (n=50)
# Average render_time: 19.609 ± 7.719 ms (n=50)
# Average wsgi_time: 183.631 ± 9.635 ms (n=50)
# Average total time: 361.305 ± 19.223 ms (n=50)
# -------------- https://test.encodedcc.org/search/?searchTerm=K562 --------------
# Average es_time: 190.879 ± 12.549 ms (n=50)
# Average queue_time: 0.466 ± 0.011 ms (n=50)
# Average render_time: 19.467 ± 7.491 ms (n=50)
# Average wsgi_time: 216.898 ± 14.289 ms (n=50)
# Average total time: 427.71 ± 28.647 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 263.99 ± 4.486 ms (n=50)
# Average queue_time: 0.483 ± 0.009 ms (n=50)
# Average render_time: 21.016 ± 5.636 ms (n=50)
# Average wsgi_time: 293.514 ± 7.857 ms (n=50)
# Average total time: 579.003 ± 15.653 ms (n=50)
# ---------- https://test.encodedcc.org/search/?searchTerm=DNA+binding -----------
# Average es_time: 281.067 ± 12.781 ms (n=50)
# Average queue_time: 0.474 ± 0.023 ms (n=50)
# Average render_time: 20.123 ± 5.02 ms (n=50)
# Average wsgi_time: 309.671 ± 14.141 ms (n=50)
# Average total time: 611.335 ± 28.274 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=human
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=human ---------
# Average es_time: 156.92 ± 3.856 ms (n=50)
# Average queue_time: 0.48 ± 0.008 ms (n=50)
# Average render_time: 19.892 ± 4.162 ms (n=50)
# Average wsgi_time: 183.057 ± 5.94 ms (n=50)
# Average total time: 360.349 ± 11.868 ms (n=50)
# ------------- https://test.encodedcc.org/search/?searchTerm=human --------------
# Average es_time: 192.853 ± 9.624 ms (n=50)
# Average queue_time: 0.466 ± 0.009 ms (n=50)
# Average render_time: 22.357 ± 6.606 ms (n=50)
# Average wsgi_time: 221.441 ± 11.136 ms (n=50)
# Average total time: 437.116 ± 22.276 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=H3K36me3 ---------
# Average es_time: 159.429 ± 3.633 ms (n=50)
# Average queue_time: 0.483 ± 0.007 ms (n=50)
# Average render_time: 22.086 ± 6.045 ms (n=50)
# Average wsgi_time: 188.201 ± 7.418 ms (n=50)
# Average total time: 370.199 ± 14.642 ms (n=50)
# ------------ https://test.encodedcc.org/search/?searchTerm=H3K36me3 ------------
# Average es_time: 190.384 ± 9.842 ms (n=50)
# Average queue_time: 0.466 ± 0.015 ms (n=50)
# Average render_time: 20.169 ± 4.732 ms (n=50)
# Average wsgi_time: 217.075 ± 11.681 ms (n=50)
# Average total time: 428.094 ± 23.346 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=CTCF
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=CTCF ---------
# Average es_time: 158.013 ± 3.384 ms (n=50)
# Average queue_time: 0.487 ± 0.011 ms (n=50)
# Average render_time: 17.455 ± 3.967 ms (n=50)
# Average wsgi_time: 181.733 ± 4.878 ms (n=50)
# Average total time: 357.688 ± 9.764 ms (n=50)
# -------------- https://test.encodedcc.org/search/?searchTerm=CTCF --------------
# Average es_time: 190.518 ± 10.276 ms (n=50)
# Average queue_time: 0.48 ± 0.021 ms (n=50)
# Average render_time: 18.016 ± 4.338 ms (n=50)
# Average wsgi_time: 214.748 ± 10.204 ms (n=50)
# Average total time: 423.763 ± 20.429 ms (n=50)
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=CTCF  \
# es_time_mean                                                158.013
# es_time_std                                                   3.384
# es_time_N                                                    50.000
# queue_time_mean                                               0.487
# queue_time_std                                                0.011
# queue_time_N                                                 50.000
# render_time_mean                                             17.455
# render_time_std                                               3.967
# render_time_N                                                50.000
# wsgi_time_mean                                              181.733
# wsgi_time_std                                                 4.878
# wsgi_time_N                                                  50.000
# total_mean                                                  357.688
# total_std                                                     9.764
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=DNA+binding  \
# es_time_mean                                                263.990
# es_time_std                                                   4.486
# es_time_N                                                    50.000
# queue_time_mean                                               0.483
# queue_time_std                                                0.009
# queue_time_N                                                 50.000
# render_time_mean                                             21.016
# render_time_std                                               5.636
# render_time_N                                                50.000
# wsgi_time_mean                                              293.514
# wsgi_time_std                                                 7.857
# wsgi_time_N                                                  50.000
# total_mean                                                  579.003
# total_std                                                    15.653
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=H3K36me3  \
# es_time_mean                                                159.429
# es_time_std                                                   3.633
# es_time_N                                                    50.000
# queue_time_mean                                               0.483
# queue_time_std                                                0.007
# queue_time_N                                                 50.000
# render_time_mean                                             22.086
# render_time_std                                               6.045
# render_time_N                                                50.000
# wsgi_time_mean                                              188.201
# wsgi_time_std                                                 7.418
# wsgi_time_N                                                  50.000
# total_mean                                                  370.199
# total_std                                                    14.642
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=K562  \
# es_time_mean                                                157.582
# es_time_std                                                   3.940
# es_time_N                                                    50.000
# queue_time_mean                                               0.482
# queue_time_std                                                0.009
# queue_time_N                                                 50.000
# render_time_mean                                             19.609
# render_time_std                                               7.719
# render_time_N                                                50.000
# wsgi_time_mean                                              183.631
# wsgi_time_std                                                 9.635
# wsgi_time_N                                                  50.000
# total_mean                                                  361.305
# total_std                                                    19.223
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//search/?searchTerm=human  \
# es_time_mean                                                156.920
# es_time_std                                                   3.856
# es_time_N                                                    50.000
# queue_time_mean                                               0.480
# queue_time_std                                                0.008
# queue_time_N                                                 50.000
# render_time_mean                                             19.892
# render_time_std                                               4.162
# render_time_N                                                50.000
# wsgi_time_mean                                              183.057
# wsgi_time_std                                                 5.940
# wsgi_time_N                                                  50.000
# total_mean                                                  360.349
# total_std                                                    11.868
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/search/?searchTerm=CTCF  \
# es_time_mean                                                190.518
# es_time_std                                                  10.276
# es_time_N                                                    50.000
# queue_time_mean                                               0.480
# queue_time_std                                                0.021
# queue_time_N                                                 50.000
# render_time_mean                                             18.016
# render_time_std                                               4.338
# render_time_N                                                50.000
# wsgi_time_mean                                              214.748
# wsgi_time_std                                                10.204
# wsgi_time_N                                                  50.000
# total_mean                                                  423.763
# total_std                                                    20.429
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/search/?searchTerm=DNA+binding  \
# es_time_mean                                                281.067
# es_time_std                                                  12.781
# es_time_N                                                    50.000
# queue_time_mean                                               0.474
# queue_time_std                                                0.023
# queue_time_N                                                 50.000
# render_time_mean                                             20.123
# render_time_std                                               5.020
# render_time_N                                                50.000
# wsgi_time_mean                                              309.671
# wsgi_time_std                                                14.141
# wsgi_time_N                                                  50.000
# total_mean                                                  611.335
# total_std                                                    28.274
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/search/?searchTerm=H3K36me3  \
# es_time_mean                                                190.384
# es_time_std                                                   9.842
# es_time_N                                                    50.000
# queue_time_mean                                               0.466
# queue_time_std                                                0.015
# queue_time_N                                                 50.000
# render_time_mean                                             20.169
# render_time_std                                               4.732
# render_time_N                                                50.000
# wsgi_time_mean                                              217.075
# wsgi_time_std                                                11.681
# wsgi_time_N                                                  50.000
# total_mean                                                  428.094
# total_std                                                    23.346
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/search/?searchTerm=K562  \
# es_time_mean                                                190.879
# es_time_std                                                  12.549
# es_time_N                                                    50.000
# queue_time_mean                                               0.466
# queue_time_std                                                0.011
# queue_time_N                                                 50.000
# render_time_mean                                             19.467
# render_time_std                                               7.491
# render_time_N                                                50.000
# wsgi_time_mean                                              216.898
# wsgi_time_std                                                14.289
# wsgi_time_N                                                  50.000
# total_mean                                                  427.710
# total_std                                                    28.647
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/search/?searchTerm=human
# es_time_mean                                                192.853
# es_time_std                                                   9.624
# es_time_N                                                    50.000
# queue_time_mean                                               0.466
# queue_time_std                                                0.009
# queue_time_N                                                 50.000
# render_time_mean                                             22.357
# render_time_std                                               6.606
# render_time_N                                                50.000
# wsgi_time_mean                                              221.441
# wsgi_time_std                                                11.136
# wsgi_time_N                                                  50.000
# total_mean                                                  437.116
# total_std                                                    22.276
# total_N                                                      50.000

# %%
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR255XZG/ ---------
# Average es_time: 3.427 ± 0.14 ms (n=50)
# Average queue_time: 0.473 ± 0.011 ms (n=50)
# Average render_time: 102.627 ± 6.713 ms (n=50)
# Average wsgi_time: 229.562 ± 170.299 ms (n=50)
# Average total time: 336.089 ± 169.153 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR255XZG/ --------------------
# Average es_time: 22.524 ± 5.369 ms (n=50)
# Average queue_time: 0.484 ± 0.012 ms (n=50)
# Average render_time: 101.847 ± 4.433 ms (n=50)
# Average wsgi_time: 222.274 ± 123.298 ms (n=50)
# Average total time: 347.13 ± 123.42 ms (n=50)
#
#
# *** item_type: /ENCSR749ILN/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR749ILN/ ---------
# Average es_time: 1.969 ± 0.707 ms (n=50)
# Average queue_time: 0.458 ± 0.012 ms (n=50)
# Average render_time: 21.579 ± 4.237 ms (n=50)
# Average wsgi_time: 37.883 ± 4.18 ms (n=50)
# Average total time: 61.889 ± 8.476 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR749ILN/ --------------------
# Average es_time: 16.634 ± 2.976 ms (n=50)
# Average queue_time: 0.482 ± 0.017 ms (n=50)
# Average render_time: 21.232 ± 4.268 ms (n=50)
# Average wsgi_time: 52.689 ± 4.831 ms (n=50)
# Average total time: 91.036 ± 9.701 ms (n=50)
#
#
# *** item_type: /ENCSR688GVV/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR688GVV/ ---------
# Average es_time: 3.353 ± 0.049 ms (n=50)
# Average queue_time: 0.472 ± 0.008 ms (n=50)
# Average render_time: 50.326 ± 4.796 ms (n=50)
# Average wsgi_time: 87.704 ± 4.724 ms (n=50)
# Average total time: 141.855 ± 9.481 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR688GVV/ --------------------
# Average es_time: 20.651 ± 4.494 ms (n=50)
# Average queue_time: 0.481 ± 0.014 ms (n=50)
# Average render_time: 50.141 ± 5.997 ms (n=50)
# Average wsgi_time: 104.909 ± 7.084 ms (n=50)
# Average total time: 176.182 ± 14.266 ms (n=50)
#
#
# *** item_type: /ENCSR301HAG/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR301HAG/ ---------
# Average es_time: 1.188 ± 0.037 ms (n=50)
# Average queue_time: 0.472 ± 0.011 ms (n=50)
# Average render_time: 9.058 ± 4.089 ms (n=50)
# Average wsgi_time: 15.581 ± 4.08 ms (n=50)
# Average total time: 26.298 ± 8.169 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR301HAG/ --------------------
# Average es_time: 15.776 ± 4.047 ms (n=50)
# Average queue_time: 0.476 ± 0.011 ms (n=50)
# Average render_time: 7.52 ± 1.928 ms (n=50)
# Average wsgi_time: 28.649 ± 4.635 ms (n=50)
# Average total time: 52.42 ± 9.221 ms (n=50)
#
#
# *** item_type: /ENCSR315NAC/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR315NAC/ ---------
# Average es_time: 2.861 ± 0.073 ms (n=50)
# Average queue_time: 0.469 ± 0.012 ms (n=50)
# Average render_time: 40.14 ± 5.249 ms (n=50)
# Average wsgi_time: 98.165 ± 138.118 ms (n=50)
# Average total time: 141.635 ± 138.012 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR315NAC/ --------------------
# Average es_time: 20.143 ± 4.434 ms (n=50)
# Average queue_time: 0.479 ± 0.014 ms (n=50)
# Average render_time: 40.894 ± 5.696 ms (n=50)
# Average wsgi_time: 88.257 ± 6.484 ms (n=50)
# Average total time: 149.773 ± 13.098 ms (n=50)
#
#
# *** item_type: /ENCSR856JJB/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR856JJB/ ---------
# Average es_time: 2.748 ± 0.057 ms (n=50)
# Average queue_time: 0.469 ± 0.01 ms (n=50)
# Average render_time: 35.655 ± 4.13 ms (n=50)
# Average wsgi_time: 62.074 ± 4.346 ms (n=50)
# Average total time: 100.947 ± 8.435 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR856JJB/ --------------------
# Average es_time: 19.421 ± 3.729 ms (n=50)
# Average queue_time: 0.481 ± 0.01 ms (n=50)
# Average render_time: 34.81 ± 4.648 ms (n=50)
# Average wsgi_time: 77.726 ± 5.414 ms (n=50)
# Average total time: 132.439 ± 10.807 ms (n=50)
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR255XZG/  \
# es_time_mean                                                  3.427
# es_time_std                                                   0.140
# es_time_N                                                    50.000
# queue_time_mean                                               0.473
# queue_time_std                                                0.011
# queue_time_N                                                 50.000
# render_time_mean                                            102.627
# render_time_std                                               6.713
# render_time_N                                                50.000
# wsgi_time_mean                                              229.562
# wsgi_time_std                                               170.299
# wsgi_time_N                                                  50.000
# total_mean                                                  336.089
# total_std                                                   169.153
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR301HAG/  \
# es_time_mean                                                  1.188
# es_time_std                                                   0.037
# es_time_N                                                    50.000
# queue_time_mean                                               0.472
# queue_time_std                                                0.011
# queue_time_N                                                 50.000
# render_time_mean                                              9.058
# render_time_std                                               4.089
# render_time_N                                                50.000
# wsgi_time_mean                                               15.581
# wsgi_time_std                                                 4.080
# wsgi_time_N                                                  50.000
# total_mean                                                   26.298
# total_std                                                     8.169
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR315NAC/  \
# es_time_mean                                                  2.861
# es_time_std                                                   0.073
# es_time_N                                                    50.000
# queue_time_mean                                               0.469
# queue_time_std                                                0.012
# queue_time_N                                                 50.000
# render_time_mean                                             40.140
# render_time_std                                               5.249
# render_time_N                                                50.000
# wsgi_time_mean                                               98.165
# wsgi_time_std                                               138.118
# wsgi_time_N                                                  50.000
# total_mean                                                  141.635
# total_std                                                   138.012
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR688GVV/  \
# es_time_mean                                                  3.353
# es_time_std                                                   0.049
# es_time_N                                                    50.000
# queue_time_mean                                               0.472
# queue_time_std                                                0.008
# queue_time_N                                                 50.000
# render_time_mean                                             50.326
# render_time_std                                               4.796
# render_time_N                                                50.000
# wsgi_time_mean                                               87.704
# wsgi_time_std                                                 4.724
# wsgi_time_N                                                  50.000
# total_mean                                                  141.855
# total_std                                                     9.481
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR749ILN/  \
# es_time_mean                                                  1.969
# es_time_std                                                   0.707
# es_time_N                                                    50.000
# queue_time_mean                                               0.458
# queue_time_std                                                0.012
# queue_time_N                                                 50.000
# render_time_mean                                             21.579
# render_time_std                                               4.237
# render_time_N                                                50.000
# wsgi_time_mean                                               37.883
# wsgi_time_std                                                 4.180
# wsgi_time_N                                                  50.000
# total_mean                                                   61.889
# total_std                                                     8.476
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR856JJB/  \
# es_time_mean                                                  2.748
# es_time_std                                                   0.057
# es_time_N                                                    50.000
# queue_time_mean                                               0.469
# queue_time_std                                                0.010
# queue_time_N                                                 50.000
# render_time_mean                                             35.655
# render_time_std                                               4.130
# render_time_N                                                50.000
# wsgi_time_mean                                               62.074
# wsgi_time_std                                                 4.346
# wsgi_time_N                                                  50.000
# total_mean                                                  100.947
# total_std                                                     8.435
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/ENCSR255XZG/  \
# es_time_mean                                       22.524
# es_time_std                                         5.369
# es_time_N                                          50.000
# queue_time_mean                                     0.484
# queue_time_std                                      0.012
# queue_time_N                                       50.000
# render_time_mean                                  101.847
# render_time_std                                     4.433
# render_time_N                                      50.000
# wsgi_time_mean                                    222.274
# wsgi_time_std                                     123.298
# wsgi_time_N                                        50.000
# total_mean                                        347.130
# total_std                                         123.420
# total_N                                            50.000
#
#                   https://test.encodedcc.org/ENCSR301HAG/  \
# es_time_mean                                       15.776
# es_time_std                                         4.047
# es_time_N                                          50.000
# queue_time_mean                                     0.476
# queue_time_std                                      0.011
# queue_time_N                                       50.000
# render_time_mean                                    7.520
# render_time_std                                     1.928
# render_time_N                                      50.000
# wsgi_time_mean                                     28.649
# wsgi_time_std                                       4.635
# wsgi_time_N                                        50.000
# total_mean                                         52.420
# total_std                                           9.221
# total_N                                            50.000
#
#                   https://test.encodedcc.org/ENCSR315NAC/  \
# es_time_mean                                       20.143
# es_time_std                                         4.434
# es_time_N                                          50.000
# queue_time_mean                                     0.479
# queue_time_std                                      0.014
# queue_time_N                                       50.000
# render_time_mean                                   40.894
# render_time_std                                     5.696
# render_time_N                                      50.000
# wsgi_time_mean                                     88.257
# wsgi_time_std                                       6.484
# wsgi_time_N                                        50.000
# total_mean                                        149.773
# total_std                                          13.098
# total_N                                            50.000
#
#                   https://test.encodedcc.org/ENCSR688GVV/  \
# es_time_mean                                       20.651
# es_time_std                                         4.494
# es_time_N                                          50.000
# queue_time_mean                                     0.481
# queue_time_std                                      0.014
# queue_time_N                                       50.000
# render_time_mean                                   50.141
# render_time_std                                     5.997
# render_time_N                                      50.000
# wsgi_time_mean                                    104.909
# wsgi_time_std                                       7.084
# wsgi_time_N                                        50.000
# total_mean                                        176.182
# total_std                                          14.266
# total_N                                            50.000
#
#                   https://test.encodedcc.org/ENCSR749ILN/  \
# es_time_mean                                       16.634
# es_time_std                                         2.976
# es_time_N                                          50.000
# queue_time_mean                                     0.482
# queue_time_std                                      0.017
# queue_time_N                                       50.000
# render_time_mean                                   21.232
# render_time_std                                     4.268
# render_time_N                                      50.000
# wsgi_time_mean                                     52.689
# wsgi_time_std                                       4.831
# wsgi_time_N                                        50.000
# total_mean                                         91.036
# total_std                                           9.701
# total_N                                            50.000
#
#                   https://test.encodedcc.org/ENCSR856JJB/
# es_time_mean                                       19.421
# es_time_std                                         3.729
# es_time_N                                          50.000
# queue_time_mean                                     0.481
# queue_time_std                                      0.010
# queue_time_N                                       50.000
# render_time_mean                                   34.810
# render_time_std                                     4.648
# render_time_N                                      50.000
# wsgi_time_mean                                     77.726
# wsgi_time_std                                       5.414
# wsgi_time_N                                        50.000
# total_mean                                        132.439
# total_std                                          10.807
# total_N                                            50.000

# %%
qa.check_response_time(item_types=['/experiments/ENCSR255XZG/', '/experiments/ENCSR749ILN/', '/experiments/ENCSR688GVV/', '/experiments/ENCSR301HAG/','/experiments/ENCSR315NAC/', '/experiments/ENCSR856JJB/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /experiments/ENCSR255XZG/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR255XZG/ ---------
# Average es_time: 3.465 ± 0.14 ms (n=50)
# Average queue_time: 0.469 ± 0.012 ms (n=50)
# Average render_time: 102.812 ± 2.761 ms (n=50)
# Average wsgi_time: 204.397 ± 119.778 ms (n=50)
# Average total time: 311.142 ± 120.439 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR255XZG/ --------------
# Average es_time: 21.519 ± 2.996 ms (n=50)
# Average queue_time: 0.49 ± 0.02 ms (n=50)
# Average render_time: 104.027 ± 2.903 ms (n=50)
# Average wsgi_time: 227.953 ± 136.849 ms (n=50)
# Average total time: 353.989 ± 137.183 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR749ILN/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR749ILN/ ---------
# Average es_time: 1.812 ± 0.057 ms (n=50)
# Average queue_time: 0.428 ± 0.014 ms (n=50)
# Average render_time: 20.299 ± 4.004 ms (n=50)
# Average wsgi_time: 36.672 ± 4.513 ms (n=50)
# Average total time: 59.211 ± 8.474 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR749ILN/ --------------
# Average es_time: 16.351 ± 3.407 ms (n=50)
# Average queue_time: 0.492 ± 0.026 ms (n=50)
# Average render_time: 20.522 ± 3.501 ms (n=50)
# Average wsgi_time: 51.948 ± 5.347 ms (n=50)
# Average total time: 89.314 ± 9.98 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR688GVV/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR688GVV/ ---------
# Average es_time: 3.392 ± 0.15 ms (n=50)
# Average queue_time: 0.458 ± 0.011 ms (n=50)
# Average render_time: 44.491 ± 4.214 ms (n=50)
# Average wsgi_time: 95.576 ± 95.782 ms (n=50)
# Average total time: 143.916 ± 97.697 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR688GVV/ --------------
# Average es_time: 20.404 ± 3.93 ms (n=50)
# Average queue_time: 0.499 ± 0.021 ms (n=50)
# Average render_time: 46.417 ± 4.955 ms (n=50)
# Average wsgi_time: 101.581 ± 6.566 ms (n=50)
# Average total time: 168.9 ± 12.805 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR301HAG/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR301HAG/ ---------
# Average es_time: 1.191 ± 0.033 ms (n=50)
# Average queue_time: 0.46 ± 0.015 ms (n=50)
# Average render_time: 9.183 ± 4.054 ms (n=50)
# Average wsgi_time: 15.75 ± 4.066 ms (n=50)
# Average total time: 26.584 ± 8.117 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR301HAG/ --------------
# Average es_time: 15.04 ± 6.581 ms (n=50)
# Average queue_time: 0.411 ± 0.027 ms (n=50)
# Average render_time: 6.68 ± 1.519 ms (n=50)
# Average wsgi_time: 27.058 ± 6.549 ms (n=50)
# Average total time: 49.189 ± 13.122 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR315NAC/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR315NAC/ ---------
# Average es_time: 2.872 ± 0.088 ms (n=50)
# Average queue_time: 0.448 ± 0.012 ms (n=50)
# Average render_time: 35.799 ± 4.084 ms (n=50)
# Average wsgi_time: 80.271 ± 101.842 ms (n=50)
# Average total time: 119.391 ± 101.667 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR315NAC/ --------------
# Average es_time: 19.0 ± 4.062 ms (n=50)
# Average queue_time: 0.464 ± 0.017 ms (n=50)
# Average render_time: 36.909 ± 4.456 ms (n=50)
# Average wsgi_time: 83.347 ± 6.864 ms (n=50)
# Average total time: 139.721 ± 12.583 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR856JJB/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR856JJB/ ---------
# Average es_time: 2.744 ± 0.066 ms (n=50)
# Average queue_time: 0.439 ± 0.022 ms (n=50)
# Average render_time: 31.81 ± 5.409 ms (n=50)
# Average wsgi_time: 58.038 ± 5.628 ms (n=50)
# Average total time: 93.031 ± 11.021 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR856JJB/ --------------
# Average es_time: 19.184 ± 5.515 ms (n=50)
# Average queue_time: 0.465 ± 0.025 ms (n=50)
# Average render_time: 30.939 ± 4.881 ms (n=50)
# Average wsgi_time: 73.26 ± 7.695 ms (n=50)
# Average total time: 123.848 ± 15.186 ms (n=50)
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR255XZG/  \
# es_time_mean                                                  3.465
# es_time_std                                                   0.140
# es_time_N                                                    50.000
# queue_time_mean                                               0.469
# queue_time_std                                                0.012
# queue_time_N                                                 50.000
# render_time_mean                                            102.812
# render_time_std                                               2.761
# render_time_N                                                50.000
# wsgi_time_mean                                              204.397
# wsgi_time_std                                               119.778
# wsgi_time_N                                                  50.000
# total_mean                                                  311.142
# total_std                                                   120.439
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR301HAG/  \
# es_time_mean                                                  1.191
# es_time_std                                                   0.033
# es_time_N                                                    50.000
# queue_time_mean                                               0.460
# queue_time_std                                                0.015
# queue_time_N                                                 50.000
# render_time_mean                                              9.183
# render_time_std                                               4.054
# render_time_N                                                50.000
# wsgi_time_mean                                               15.750
# wsgi_time_std                                                 4.066
# wsgi_time_N                                                  50.000
# total_mean                                                   26.584
# total_std                                                     8.117
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR315NAC/  \
# es_time_mean                                                  2.872
# es_time_std                                                   0.088
# es_time_N                                                    50.000
# queue_time_mean                                               0.448
# queue_time_std                                                0.012
# queue_time_N                                                 50.000
# render_time_mean                                             35.799
# render_time_std                                               4.084
# render_time_N                                                50.000
# wsgi_time_mean                                               80.271
# wsgi_time_std                                               101.842
# wsgi_time_N                                                  50.000
# total_mean                                                  119.391
# total_std                                                   101.667
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR688GVV/  \
# es_time_mean                                                  3.392
# es_time_std                                                   0.150
# es_time_N                                                    50.000
# queue_time_mean                                               0.458
# queue_time_std                                                0.011
# queue_time_N                                                 50.000
# render_time_mean                                             44.491
# render_time_std                                               4.214
# render_time_N                                                50.000
# wsgi_time_mean                                               95.576
# wsgi_time_std                                                95.782
# wsgi_time_N                                                  50.000
# total_mean                                                  143.916
# total_std                                                    97.697
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR749ILN/  \
# es_time_mean                                                  1.812
# es_time_std                                                   0.057
# es_time_N                                                    50.000
# queue_time_mean                                               0.428
# queue_time_std                                                0.014
# queue_time_N                                                 50.000
# render_time_mean                                             20.299
# render_time_std                                               4.004
# render_time_N                                                50.000
# wsgi_time_mean                                               36.672
# wsgi_time_std                                                 4.513
# wsgi_time_N                                                  50.000
# total_mean                                                   59.211
# total_std                                                     8.474
# total_N                                                      50.000
#
#                   https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//experiments/ENCSR856JJB/  \
# es_time_mean                                                  2.744
# es_time_std                                                   0.066
# es_time_N                                                    50.000
# queue_time_mean                                               0.439
# queue_time_std                                                0.022
# queue_time_N                                                 50.000
# render_time_mean                                             31.810
# render_time_std                                               5.409
# render_time_N                                                50.000
# wsgi_time_mean                                               58.038
# wsgi_time_std                                                 5.628
# wsgi_time_N                                                  50.000
# total_mean                                                   93.031
# total_std                                                    11.021
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/experiments/ENCSR255XZG/  \
# es_time_mean                                                 21.519
# es_time_std                                                   2.996
# es_time_N                                                    50.000
# queue_time_mean                                               0.490
# queue_time_std                                                0.020
# queue_time_N                                                 50.000
# render_time_mean                                            104.027
# render_time_std                                               2.903
# render_time_N                                                50.000
# wsgi_time_mean                                              227.953
# wsgi_time_std                                               136.849
# wsgi_time_N                                                  50.000
# total_mean                                                  353.989
# total_std                                                   137.183
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/experiments/ENCSR301HAG/  \
# es_time_mean                                                 15.040
# es_time_std                                                   6.581
# es_time_N                                                    50.000
# queue_time_mean                                               0.411
# queue_time_std                                                0.027
# queue_time_N                                                 50.000
# render_time_mean                                              6.680
# render_time_std                                               1.519
# render_time_N                                                50.000
# wsgi_time_mean                                               27.058
# wsgi_time_std                                                 6.549
# wsgi_time_N                                                  50.000
# total_mean                                                   49.189
# total_std                                                    13.122
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/experiments/ENCSR315NAC/  \
# es_time_mean                                                 19.000
# es_time_std                                                   4.062
# es_time_N                                                    50.000
# queue_time_mean                                               0.464
# queue_time_std                                                0.017
# queue_time_N                                                 50.000
# render_time_mean                                             36.909
# render_time_std                                               4.456
# render_time_N                                                50.000
# wsgi_time_mean                                               83.347
# wsgi_time_std                                                 6.864
# wsgi_time_N                                                  50.000
# total_mean                                                  139.721
# total_std                                                    12.583
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/experiments/ENCSR688GVV/  \
# es_time_mean                                                 20.404
# es_time_std                                                   3.930
# es_time_N                                                    50.000
# queue_time_mean                                               0.499
# queue_time_std                                                0.021
# queue_time_N                                                 50.000
# render_time_mean                                             46.417
# render_time_std                                               4.955
# render_time_N                                                50.000
# wsgi_time_mean                                              101.581
# wsgi_time_std                                                 6.566
# wsgi_time_N                                                  50.000
# total_mean                                                  168.900
# total_std                                                    12.805
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/experiments/ENCSR749ILN/  \
# es_time_mean                                                 16.351
# es_time_std                                                   3.407
# es_time_N                                                    50.000
# queue_time_mean                                               0.492
# queue_time_std                                                0.026
# queue_time_N                                                 50.000
# render_time_mean                                             20.522
# render_time_std                                               3.501
# render_time_N                                                50.000
# wsgi_time_mean                                               51.948
# wsgi_time_std                                                 5.347
# wsgi_time_N                                                  50.000
# total_mean                                                   89.314
# total_std                                                     9.980
# total_N                                                      50.000
#
#                   https://test.encodedcc.org/experiments/ENCSR856JJB/
# es_time_mean                                                 19.184
# es_time_std                                                   5.515
# es_time_N                                                    50.000
# queue_time_mean                                               0.465
# queue_time_std                                                0.025
# queue_time_N                                                 50.000
# render_time_mean                                             30.939
# render_time_std                                               4.881
# render_time_N                                                50.000
# wsgi_time_mean                                               73.260
# wsgi_time_std                                                 7.695
# wsgi_time_N                                                  50.000
# total_mean                                                  123.848
# total_std                                                    15.186
# total_N                                                      50.000

# %%
qa.check_response_time(json=True, item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR255XZG/ ---------
# Average es_time: 3.548 ± 0.306 ms (n=50)
# Average queue_time: 0.468 ± 0.013 ms (n=50)
# Average wsgi_time: 102.824 ± 127.339 ms (n=50)
# Average total time: 106.841 ± 127.372 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR255XZG/ --------------------
# Average es_time: 22.733 ± 5.298 ms (n=50)
# Average queue_time: 0.473 ± 0.017 ms (n=50)
# Average wsgi_time: 96.062 ± 5.493 ms (n=50)
# Average total time: 119.268 ± 10.715 ms (n=50)
#
#
# *** item_type: /ENCSR749ILN/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR749ILN/ ---------
# Average es_time: 1.893 ± 0.242 ms (n=50)
# Average queue_time: 0.46 ± 0.014 ms (n=50)
# Average wsgi_time: 16.17 ± 0.901 ms (n=50)
# Average total time: 18.523 ± 0.986 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR749ILN/ --------------------
# Average es_time: 17.565 ± 5.914 ms (n=50)
# Average queue_time: 0.481 ± 0.031 ms (n=50)
# Average wsgi_time: 46.521 ± 98.772 ms (n=50)
# Average total time: 64.567 ± 98.946 ms (n=50)
#
#
# *** item_type: /ENCSR688GVV/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR688GVV/ ---------
# Average es_time: 3.36 ± 0.08 ms (n=50)
# Average queue_time: 0.471 ± 0.011 ms (n=50)
# Average wsgi_time: 62.86 ± 124.371 ms (n=50)
# Average total time: 66.69 ± 124.415 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR688GVV/ --------------------
# Average es_time: 20.534 ± 3.046 ms (n=50)
# Average queue_time: 0.481 ± 0.012 ms (n=50)
# Average wsgi_time: 54.658 ± 3.246 ms (n=50)
# Average total time: 75.673 ± 6.239 ms (n=50)
#
#
# *** item_type: /ENCSR301HAG/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR301HAG/ ---------
# Average es_time: 1.185 ± 0.039 ms (n=50)
# Average queue_time: 0.467 ± 0.009 ms (n=50)
# Average wsgi_time: 6.503 ± 0.385 ms (n=50)
# Average total time: 8.155 ± 0.401 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR301HAG/ --------------------
# Average es_time: 15.949 ± 3.715 ms (n=50)
# Average queue_time: 0.48 ± 0.011 ms (n=50)
# Average wsgi_time: 21.453 ± 3.775 ms (n=50)
# Average total time: 37.882 ± 7.485 ms (n=50)
#
#
# *** item_type: /ENCSR315NAC/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR315NAC/ ---------
# Average es_time: 2.85 ± 0.062 ms (n=50)
# Average queue_time: 0.465 ± 0.01 ms (n=50)
# Average wsgi_time: 43.198 ± 93.904 ms (n=50)
# Average total time: 46.513 ± 93.931 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR315NAC/ --------------------
# Average es_time: 34.573 ± 103.978 ms (n=50)
# Average queue_time: 0.48 ± 0.011 ms (n=50)
# Average wsgi_time: 61.732 ± 104.098 ms (n=50)
# Average total time: 96.785 ± 208.075 ms (n=50)
#
#
# *** item_type: /ENCSR856JJB/
# --------- https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR856JJB/ ---------
# Average es_time: 2.758 ± 0.045 ms (n=50)
# Average queue_time: 0.466 ± 0.01 ms (n=50)
# Average wsgi_time: 26.436 ± 1.023 ms (n=50)
# Average total time: 29.66 ± 1.036 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR856JJB/ --------------------
# Average es_time: 19.524 ± 4.852 ms (n=50)
# Average queue_time: 0.47 ± 0.029 ms (n=50)
# Average wsgi_time: 42.871 ± 5.054 ms (n=50)
# Average total time: 62.865 ± 9.874 ms (n=50)
#                  https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR255XZG/  \
# es_time_mean                                                 3.548
# es_time_std                                                  0.306
# es_time_N                                                   50.000
# queue_time_mean                                              0.468
# queue_time_std                                               0.013
# queue_time_N                                                50.000
# wsgi_time_mean                                             102.824
# wsgi_time_std                                              127.339
# wsgi_time_N                                                 50.000
# total_mean                                                 106.841
# total_std                                                  127.372
# total_N                                                     50.000
#
#                  https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR301HAG/  \
# es_time_mean                                                 1.185
# es_time_std                                                  0.039
# es_time_N                                                   50.000
# queue_time_mean                                              0.467
# queue_time_std                                               0.009
# queue_time_N                                                50.000
# wsgi_time_mean                                               6.503
# wsgi_time_std                                                0.385
# wsgi_time_N                                                 50.000
# total_mean                                                   8.155
# total_std                                                    0.401
# total_N                                                     50.000
#
#                  https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR315NAC/  \
# es_time_mean                                                 2.850
# es_time_std                                                  0.062
# es_time_N                                                   50.000
# queue_time_mean                                              0.465
# queue_time_std                                               0.010
# queue_time_N                                                50.000
# wsgi_time_mean                                              43.198
# wsgi_time_std                                               93.904
# wsgi_time_N                                                 50.000
# total_mean                                                  46.513
# total_std                                                   93.931
# total_N                                                     50.000
#
#                  https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR688GVV/  \
# es_time_mean                                                 3.360
# es_time_std                                                  0.080
# es_time_N                                                   50.000
# queue_time_mean                                              0.471
# queue_time_std                                               0.011
# queue_time_N                                                50.000
# wsgi_time_mean                                              62.860
# wsgi_time_std                                              124.371
# wsgi_time_N                                                 50.000
# total_mean                                                  66.690
# total_std                                                  124.415
# total_N                                                     50.000
#
#                  https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR749ILN/  \
# es_time_mean                                                 1.893
# es_time_std                                                  0.242
# es_time_N                                                   50.000
# queue_time_mean                                              0.460
# queue_time_std                                               0.014
# queue_time_N                                                50.000
# wsgi_time_mean                                              16.170
# wsgi_time_std                                                0.901
# wsgi_time_N                                                 50.000
# total_mean                                                  18.523
# total_std                                                    0.986
# total_N                                                     50.000
#
#                  https://sno-33-wrapper-f838d93b7-hitz.demo.encodedcc.org//ENCSR856JJB/  \
# es_time_mean                                                 2.758
# es_time_std                                                  0.045
# es_time_N                                                   50.000
# queue_time_mean                                              0.466
# queue_time_std                                               0.010
# queue_time_N                                                50.000
# wsgi_time_mean                                              26.436
# wsgi_time_std                                                1.023
# wsgi_time_N                                                 50.000
# total_mean                                                  29.660
# total_std                                                    1.036
# total_N                                                     50.000
#
#                  https://test.encodedcc.org/ENCSR255XZG/  \
# es_time_mean                                      22.733
# es_time_std                                        5.298
# es_time_N                                         50.000
# queue_time_mean                                    0.473
# queue_time_std                                     0.017
# queue_time_N                                      50.000
# wsgi_time_mean                                    96.062
# wsgi_time_std                                      5.493
# wsgi_time_N                                       50.000
# total_mean                                       119.268
# total_std                                         10.715
# total_N                                           50.000
#
#                  https://test.encodedcc.org/ENCSR301HAG/  \
# es_time_mean                                      15.949
# es_time_std                                        3.715
# es_time_N                                         50.000
# queue_time_mean                                    0.480
# queue_time_std                                     0.011
# queue_time_N                                      50.000
# wsgi_time_mean                                    21.453
# wsgi_time_std                                      3.775
# wsgi_time_N                                       50.000
# total_mean                                        37.882
# total_std                                          7.485
# total_N                                           50.000
#
#                  https://test.encodedcc.org/ENCSR315NAC/  \
# es_time_mean                                      34.573
# es_time_std                                      103.978
# es_time_N                                         50.000
# queue_time_mean                                    0.480
# queue_time_std                                     0.011
# queue_time_N                                      50.000
# wsgi_time_mean                                    61.732
# wsgi_time_std                                    104.098
# wsgi_time_N                                       50.000
# total_mean                                        96.785
# total_std                                        208.075
# total_N                                           50.000
#
#                  https://test.encodedcc.org/ENCSR688GVV/  \
# es_time_mean                                      20.534
# es_time_std                                        3.046
# es_time_N                                         50.000
# queue_time_mean                                    0.481
# queue_time_std                                     0.012
# queue_time_N                                      50.000
# wsgi_time_mean                                    54.658
# wsgi_time_std                                      3.246
# wsgi_time_N                                       50.000
# total_mean                                        75.673
# total_std                                          6.239
# total_N                                           50.000
#
#                  https://test.encodedcc.org/ENCSR749ILN/  \
# es_time_mean                                      17.565
# es_time_std                                        5.914
# es_time_N                                         50.000
# queue_time_mean                                    0.481
# queue_time_std                                     0.031
# queue_time_N                                      50.000
# wsgi_time_mean                                    46.521
# wsgi_time_std                                     98.772
# wsgi_time_N                                       50.000
# total_mean                                        64.567
# total_std                                         98.946
# total_N                                           50.000
#
#                  https://test.encodedcc.org/ENCSR856JJB/
# es_time_mean                                      19.524
# es_time_std                                        4.852
# es_time_N                                         50.000
# queue_time_mean                                    0.470
# queue_time_std                                     0.029
# queue_time_N                                      50.000
# wsgi_time_mean                                    42.871
# wsgi_time_std                                      5.054
# wsgi_time_N                                       50.000
# total_mean                                        62.865
# total_std                                          9.874
# total_N                                           50.000

# %%
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/'], n=50)

# %%
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=50)

# %%
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=50)

# %% [markdown]
# ##
