# %%
# %load_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('..')
import qancode
import numpy as np
import pandas as pd

# %%
#compare any two encoded instances here
qa = qancode.QANCODE(rc_url="https://test.encodedcc.org", prod_url='https://sno68-on-dev.demo.encodedcc.org/')

# %%
res = qa.check_response_time(item_types=["/","/search/?type=Experiment"], n=50)
# Out:
# Checking response time
#
# *** item_type: /
# ------------------ https://sno68-on-dev.demo.encodedcc.org// -------------------
# Average es_time: 1.437 ± 0.354 ms (n=50)
# Average queue_time: 0.448 ± 0.041 ms (n=50)
# Average render_time: 25.741 ± 89.396 ms (n=50)
# Average wsgi_time: 30.986 ± 89.729 ms (n=50)
# Average total time: 58.612 ± 179.157 ms (n=50)
# ------------------------- https://test.encodedcc.org/ --------------------------
# Average es_time: 2.303 ± 0.099 ms (n=50)
# Average queue_time: 0.458 ± 0.041 ms (n=50)
# Average render_time: 5.768 ± 3.2 ms (n=50)
# Average wsgi_time: 11.952 ± 3.236 ms (n=50)
# Average total time: 20.48 ± 6.469 ms (n=50)
#
#
# *** item_type: /search/?type=Experiment
# ------- https://sno68-on-dev.demo.encodedcc.org//search/?type=Experiment -------
# Average es_time: 14.541 ± 5.102 ms (n=50)
# Average queue_time: 0.502 ± 0.017 ms (n=50)
# Average render_time: 128.394 ± 23.567 ms (n=50)
# Average wsgi_time: 159.202 ± 25.75 ms (n=50)
# Average total time: 302.639 ± 51.557 ms (n=50)
# -------------- https://test.encodedcc.org/search/?type=Experiment --------------
# Average es_time: 27.5 ± 14.652 ms (n=50)
# Average queue_time: 0.557 ± 0.036 ms (n=50)
# Average render_time: 125.738 ± 14.438 ms (n=50)
# Average wsgi_time: 170.586 ± 23.562 ms (n=50)
# Average total time: 324.382 ± 47.143 ms (n=50)

# %%
res

# %%
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=50)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ------- https://sno68-on-dev.demo.encodedcc.org//search/?searchTerm=K562 -------
# Average es_time: 155.442 ± 74.564 ms (n=50)
# Average queue_time: 0.524 ± 0.028 ms (n=50)
# Average render_time: 22.779 ± 7.123 ms (n=50)
# Average wsgi_time: 186.839 ± 80.049 ms (n=50)
# Average total time: 365.584 ± 158.176 ms (n=50)
# -------------- https://test.encodedcc.org/search/?searchTerm=K562 --------------
# Average es_time: 255.756 ± 77.864 ms (n=50)
# Average queue_time: 0.513 ± 0.026 ms (n=50)
# Average render_time: 26.322 ± 8.186 ms (n=50)
# Average wsgi_time: 290.326 ± 80.959 ms (n=50)
# Average total time: 572.917 ± 161.66 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# --------- https://sno68-on-dev.demo.encodedcc.org//search/?searchTerm=DNA+binding ---------
# Average es_time: 254.752 ± 75.15 ms (n=50)
# Average queue_time: 0.526 ± 0.028 ms (n=50)
# Average render_time: 26.921 ± 7.768 ms (n=50)
# Average wsgi_time: 294.292 ± 78.654 ms (n=50)
# Average total time: 576.491 ± 156.045 ms (n=50)
# ---------- https://test.encodedcc.org/search/?searchTerm=DNA+binding -----------
# Average es_time: 367.404 ± 76.163 ms (n=50)
# Average queue_time: 0.527 ± 0.021 ms (n=50)
# Average render_time: 29.935 ± 9.041 ms (n=50)
# Average wsgi_time: 410.561 ± 79.709 ms (n=50)
# Average total time: 808.427 ± 158.638 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=human
# ------ https://sno68-on-dev.demo.encodedcc.org//search/?searchTerm=human -------
# Average es_time: 148.868 ± 45.529 ms (n=50)
# Average queue_time: 0.533 ± 0.032 ms (n=50)
# Average render_time: 23.33 ± 6.177 ms (n=50)
# Average wsgi_time: 179.455 ± 46.863 ms (n=50)
# Average total time: 352.186 ± 93.566 ms (n=50)
# ------------- https://test.encodedcc.org/search/?searchTerm=human --------------
# Average es_time: 257.445 ± 38.647 ms (n=50)
# Average queue_time: 0.518 ± 0.022 ms (n=50)
# Average render_time: 27.964 ± 7.933 ms (n=50)
# Average wsgi_time: 292.925 ± 39.979 ms (n=50)
# Average total time: 578.852 ± 79.926 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# ----- https://sno68-on-dev.demo.encodedcc.org//search/?searchTerm=H3K36me3 -----
# Average es_time: 146.904 ± 24.684 ms (n=50)
# Average queue_time: 0.523 ± 0.023 ms (n=50)
# Average render_time: 30.099 ± 7.767 ms (n=50)
# Average wsgi_time: 185.015 ± 26.124 ms (n=50)
# Average total time: 362.541 ± 52.151 ms (n=50)
# ------------ https://test.encodedcc.org/search/?searchTerm=H3K36me3 ------------
# Average es_time: 246.258 ± 32.593 ms (n=50)
# Average queue_time: 0.525 ± 0.028 ms (n=50)
# Average render_time: 30.388 ± 8.277 ms (n=50)
# Average wsgi_time: 285.043 ± 34.345 ms (n=50)
# Average total time: 562.213 ± 68.457 ms (n=50)
#
#
# *** item_type: /search/?searchTerm=CTCF
# ------- https://sno68-on-dev.demo.encodedcc.org//search/?searchTerm=CTCF -------
# Average es_time: 144.103 ± 19.595 ms (n=50)
# Average queue_time: 0.512 ± 0.007 ms (n=50)
# Average render_time: 20.148 ± 4.698 ms (n=50)
# Average wsgi_time: 171.377 ± 19.931 ms (n=50)
# Average total time: 336.14 ± 39.722 ms (n=50)
# -------------- https://test.encodedcc.org/search/?searchTerm=CTCF --------------
# Average es_time: 252.529 ± 36.873 ms (n=50)
# Average queue_time: 0.509 ± 0.023 ms (n=50)
# Average render_time: 23.091 ± 5.945 ms (n=50)
# Average wsgi_time: 283.187 ± 37.499 ms (n=50)
# Average total time: 559.317 ± 74.672 ms (n=50)

# %%
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR255XZG/ -------------
# Average es_time: 4.903 ± 2.332 ms (n=50)
# Average queue_time: 0.48 ± 0.01 ms (n=50)
# Average render_time: 110.471 ± 7.062 ms (n=50)
# Average wsgi_time: 221.761 ± 137.386 ms (n=50)
# Average total time: 337.615 ± 137.271 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR255XZG/ --------------------
# Average es_time: 13.03 ± 0.324 ms (n=50)
# Average queue_time: 0.514 ± 0.042 ms (n=50)
# Average render_time: 112.099 ± 7.44 ms (n=50)
# Average wsgi_time: 210.327 ± 58.171 ms (n=50)
# Average total time: 335.971 ± 60.629 ms (n=50)
#
#
# *** item_type: /ENCSR749ILN/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR749ILN/ -------------
# Average es_time: 2.916 ± 1.82 ms (n=50)
# Average queue_time: 0.471 ± 0.013 ms (n=50)
# Average render_time: 32.94 ± 5.569 ms (n=50)
# Average wsgi_time: 54.267 ± 6.194 ms (n=50)
# Average total time: 90.593 ± 12.348 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR749ILN/ --------------------
# Average es_time: 6.436 ± 1.997 ms (n=50)
# Average queue_time: 0.494 ± 0.043 ms (n=50)
# Average render_time: 33.159 ± 5.633 ms (n=50)
# Average wsgi_time: 58.507 ± 6.561 ms (n=50)
# Average total time: 98.595 ± 12.807 ms (n=50)
#
#
# *** item_type: /ENCSR688GVV/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR688GVV/ -------------
# Average es_time: 4.76 ± 1.849 ms (n=50)
# Average queue_time: 0.485 ± 0.012 ms (n=50)
# Average render_time: 67.924 ± 4.594 ms (n=50)
# Average wsgi_time: 116.541 ± 5.01 ms (n=50)
# Average total time: 189.71 ± 9.724 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR688GVV/ --------------------
# Average es_time: 11.618 ± 2.389 ms (n=50)
# Average queue_time: 0.478 ± 0.036 ms (n=50)
# Average render_time: 65.276 ± 5.28 ms (n=50)
# Average wsgi_time: 133.771 ± 92.157 ms (n=50)
# Average total time: 211.144 ± 91.676 ms (n=50)
#
#
# *** item_type: /ENCSR301HAG/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR301HAG/ -------------
# Average es_time: 1.511 ± 0.058 ms (n=50)
# Average queue_time: 0.482 ± 0.015 ms (n=50)
# Average render_time: 10.035 ± 3.754 ms (n=50)
# Average wsgi_time: 17.406 ± 3.978 ms (n=50)
# Average total time: 29.435 ± 7.687 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR301HAG/ --------------------
# Average es_time: 3.328 ± 0.766 ms (n=50)
# Average queue_time: 0.514 ± 0.042 ms (n=50)
# Average render_time: 11.034 ± 5.567 ms (n=50)
# Average wsgi_time: 20.235 ± 6.023 ms (n=50)
# Average total time: 35.111 ± 11.654 ms (n=50)
#
#
# *** item_type: /ENCSR315NAC/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR315NAC/ -------------
# Average es_time: 3.931 ± 1.808 ms (n=50)
# Average queue_time: 0.478 ± 0.011 ms (n=50)
# Average render_time: 51.032 ± 6.394 ms (n=50)
# Average wsgi_time: 87.364 ± 5.965 ms (n=50)
# Average total time: 142.805 ± 12.115 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR315NAC/ --------------------
# Average es_time: 8.632 ± 0.267 ms (n=50)
# Average queue_time: 0.507 ± 0.034 ms (n=50)
# Average render_time: 49.58 ± 5.741 ms (n=50)
# Average wsgi_time: 90.762 ± 5.885 ms (n=50)
# Average total time: 149.48 ± 11.654 ms (n=50)
#
#
# *** item_type: /ENCSR856JJB/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR856JJB/ -------------
# Average es_time: 3.332 ± 0.298 ms (n=50)
# Average queue_time: 0.48 ± 0.013 ms (n=50)
# Average render_time: 46.093 ± 6.48 ms (n=50)
# Average wsgi_time: 77.116 ± 6.515 ms (n=50)
# Average total time: 127.02 ± 12.932 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR856JJB/ --------------------
# Average es_time: 7.342 ± 0.777 ms (n=50)
# Average queue_time: 0.49 ± 0.036 ms (n=50)
# Average render_time: 44.245 ± 6.929 ms (n=50)
# Average wsgi_time: 79.198 ± 7.208 ms (n=50)
# Average total time: 131.275 ± 14.219 ms (n=50)

# %%
qa.check_response_time(item_types=['/experiments/ENCSR255XZG/', '/experiments/ENCSR749ILN/', '/experiments/ENCSR688GVV/', '/experiments/ENCSR301HAG/','/experiments/ENCSR315NAC/', '/experiments/ENCSR856JJB/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /experiments/ENCSR255XZG/
# ------ https://sno68-on-dev.demo.encodedcc.org//experiments/ENCSR255XZG/ -------
# Average es_time: 4.022 ± 0.267 ms (n=50)
# Average queue_time: 0.51 ± 0.02 ms (n=50)
# Average render_time: 109.33 ± 5.735 ms (n=50)
# Average wsgi_time: 192.425 ± 5.473 ms (n=50)
# Average total time: 306.286 ± 11.048 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR255XZG/ --------------
# Average es_time: 13.514 ± 3.218 ms (n=50)
# Average queue_time: 0.562 ± 0.021 ms (n=50)
# Average render_time: 109.987 ± 5.737 ms (n=50)
# Average wsgi_time: 220.592 ± 88.486 ms (n=50)
# Average total time: 344.655 ± 91.32 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR749ILN/
# ------ https://sno68-on-dev.demo.encodedcc.org//experiments/ENCSR749ILN/ -------
# Average es_time: 2.493 ± 0.072 ms (n=50)
# Average queue_time: 0.472 ± 0.021 ms (n=50)
# Average render_time: 29.516 ± 6.184 ms (n=50)
# Average wsgi_time: 51.005 ± 6.574 ms (n=50)
# Average total time: 83.487 ± 12.711 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR749ILN/ --------------
# Average es_time: 6.395 ± 2.8 ms (n=50)
# Average queue_time: 0.516 ± 0.029 ms (n=50)
# Average render_time: 28.675 ± 6.21 ms (n=50)
# Average wsgi_time: 55.222 ± 6.933 ms (n=50)
# Average total time: 90.809 ± 13.484 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR688GVV/
# ------ https://sno68-on-dev.demo.encodedcc.org//experiments/ENCSR688GVV/ -------
# Average es_time: 4.425 ± 0.103 ms (n=50)
# Average queue_time: 0.491 ± 0.02 ms (n=50)
# Average render_time: 61.885 ± 5.524 ms (n=50)
# Average wsgi_time: 119.652 ± 61.652 ms (n=50)
# Average total time: 186.454 ± 62.837 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR688GVV/ --------------
# Average es_time: 11.513 ± 0.2 ms (n=50)
# Average queue_time: 0.553 ± 0.021 ms (n=50)
# Average render_time: 62.544 ± 5.625 ms (n=50)
# Average wsgi_time: 128.16 ± 60.801 ms (n=50)
# Average total time: 202.77 ± 62.738 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR301HAG/
# ------ https://sno68-on-dev.demo.encodedcc.org//experiments/ENCSR301HAG/ -------
# Average es_time: 1.459 ± 0.052 ms (n=50)
# Average queue_time: 0.471 ± 0.02 ms (n=50)
# Average render_time: 11.334 ± 5.182 ms (n=50)
# Average wsgi_time: 18.492 ± 5.26 ms (n=50)
# Average total time: 31.756 ± 10.421 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR301HAG/ --------------
# Average es_time: 3.046 ± 0.104 ms (n=50)
# Average queue_time: 0.47 ± 0.028 ms (n=50)
# Average render_time: 10.735 ± 4.49 ms (n=50)
# Average wsgi_time: 19.373 ± 4.532 ms (n=50)
# Average total time: 33.625 ± 9.036 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR315NAC/
# ------ https://sno68-on-dev.demo.encodedcc.org//experiments/ENCSR315NAC/ -------
# Average es_time: 3.677 ± 0.1 ms (n=50)
# Average queue_time: 0.487 ± 0.015 ms (n=50)
# Average render_time: 46.814 ± 5.759 ms (n=50)
# Average wsgi_time: 93.227 ± 69.586 ms (n=50)
# Average total time: 144.206 ± 69.243 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR315NAC/ --------------
# Average es_time: 8.833 ± 0.248 ms (n=50)
# Average queue_time: 0.528 ± 0.029 ms (n=50)
# Average render_time: 47.254 ± 5.473 ms (n=50)
# Average wsgi_time: 89.393 ± 5.686 ms (n=50)
# Average total time: 146.008 ± 11.104 ms (n=50)
#
#
# *** item_type: /experiments/ENCSR856JJB/
# ------ https://sno68-on-dev.demo.encodedcc.org//experiments/ENCSR856JJB/ -------
# Average es_time: 3.378 ± 0.077 ms (n=50)
# Average queue_time: 0.483 ± 0.022 ms (n=50)
# Average render_time: 39.693 ± 5.439 ms (n=50)
# Average wsgi_time: 71.004 ± 5.595 ms (n=50)
# Average total time: 114.558 ± 11.007 ms (n=50)
# ------------- https://test.encodedcc.org/experiments/ENCSR856JJB/ --------------
# Average es_time: 7.527 ± 0.787 ms (n=50)
# Average queue_time: 0.528 ± 0.021 ms (n=50)
# Average render_time: 41.415 ± 6.093 ms (n=50)
# Average wsgi_time: 77.284 ± 6.558 ms (n=50)
# Average total time: 126.754 ± 12.804 ms (n=50)

# %%
qa.check_response_time(json=True, item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-45caf8576b05> in <module>()
# ----> 1 qa.check_response_time(json=True, item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=50)
#
# TypeError: check_response_time() got an unexpected keyword argument 'json'

# %%
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR480OHP/ -------------
# Average es_time: 3.024 ± 1.973 ms (n=50)
# Average queue_time: 0.476 ± 0.014 ms (n=50)
# Average render_time: 42.567 ± 4.129 ms (n=50)
# Average wsgi_time: 92.21 ± 106.447 ms (n=50)
# Average total time: 138.277 ± 107.694 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR480OHP/ --------------------
# Average es_time: 6.934 ± 4.134 ms (n=50)
# Average queue_time: 0.486 ± 0.043 ms (n=50)
# Average render_time: 43.671 ± 4.564 ms (n=50)
# Average wsgi_time: 82.283 ± 5.793 ms (n=50)
# Average total time: 133.373 ± 11.43 ms (n=50)
#
#
# *** item_type: /ENCSR000EMB/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR000EMB/ -------------
# Average es_time: 3.539 ± 1.585 ms (n=50)
# Average queue_time: 0.478 ± 0.011 ms (n=50)
# Average render_time: 46.913 ± 6.625 ms (n=50)
# Average wsgi_time: 91.812 ± 97.01 ms (n=50)
# Average total time: 142.743 ± 98.367 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR000EMB/ --------------------
# Average es_time: 7.46 ± 0.897 ms (n=50)
# Average queue_time: 0.495 ± 0.039 ms (n=50)
# Average render_time: 46.362 ± 7.316 ms (n=50)
# Average wsgi_time: 104.983 ± 118.496 ms (n=50)
# Average total time: 159.3 ± 120.608 ms (n=50)
#
#
# *** item_type: /ENCSR323QIP/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR323QIP/ -------------
# Average es_time: 5.408 ± 0.751 ms (n=50)
# Average queue_time: 0.483 ± 0.012 ms (n=50)
# Average render_time: 133.507 ± 5.343 ms (n=50)
# Average wsgi_time: 256.008 ± 119.64 ms (n=50)
# Average total time: 395.406 ± 119.941 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR323QIP/ --------------------
# Average es_time: 17.838 ± 0.255 ms (n=50)
# Average queue_time: 0.509 ± 0.039 ms (n=50)
# Average render_time: 133.907 ± 5.734 ms (n=50)
# Average wsgi_time: 275.48 ± 126.165 ms (n=50)
# Average total time: 427.734 ± 126.717 ms (n=50)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR718AXQ/ -------------
# Average es_time: 2.845 ± 1.286 ms (n=50)
# Average queue_time: 0.482 ± 0.012 ms (n=50)
# Average render_time: 19.758 ± 7.758 ms (n=50)
# Average wsgi_time: 33.103 ± 7.805 ms (n=50)
# Average total time: 56.188 ± 15.612 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR718AXQ/ --------------------
# Average es_time: 5.281 ± 0.422 ms (n=50)
# Average queue_time: 0.469 ± 0.025 ms (n=50)
# Average render_time: 17.789 ± 6.706 ms (n=50)
# Average wsgi_time: 33.317 ± 6.879 ms (n=50)
# Average total time: 56.855 ± 13.486 ms (n=50)
#
#
# *** item_type: /ENCSR165BGV/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR165BGV/ -------------
# Average es_time: 1.523 ± 0.183 ms (n=50)
# Average queue_time: 0.478 ± 0.014 ms (n=50)
# Average render_time: 19.061 ± 4.842 ms (n=50)
# Average wsgi_time: 31.754 ± 4.894 ms (n=50)
# Average total time: 52.817 ± 9.686 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR165BGV/ --------------------
# Average es_time: 3.204 ± 0.412 ms (n=50)
# Average queue_time: 0.497 ± 0.043 ms (n=50)
# Average render_time: 19.4 ± 5.446 ms (n=50)
# Average wsgi_time: 33.894 ± 5.551 ms (n=50)
# Average total time: 56.994 ± 11.006 ms (n=50)
#
#
# *** item_type: /ENCSR384KAN/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR384KAN/ -------------
# Average es_time: 3.217 ± 0.336 ms (n=50)
# Average queue_time: 0.475 ± 0.012 ms (n=50)
# Average render_time: 48.631 ± 6.211 ms (n=50)
# Average wsgi_time: 86.01 ± 6.301 ms (n=50)
# Average total time: 138.333 ± 12.447 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR384KAN/ --------------------
# Average es_time: 7.753 ± 0.258 ms (n=50)
# Average queue_time: 0.466 ± 0.019 ms (n=50)
# Average render_time: 48.559 ± 6.189 ms (n=50)
# Average wsgi_time: 90.366 ± 6.371 ms (n=50)
# Average total time: 147.143 ± 12.556 ms (n=50)
#
#
# *** item_type: /ENCSR330FXL/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR330FXL/ -------------
# Average es_time: 1.833 ± 1.882 ms (n=50)
# Average queue_time: 0.461 ± 0.017 ms (n=50)
# Average render_time: 23.601 ± 5.635 ms (n=50)
# Average wsgi_time: 39.282 ± 6.39 ms (n=50)
# Average total time: 65.177 ± 12.654 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR330FXL/ --------------------
# Average es_time: 4.176 ± 4.315 ms (n=50)
# Average queue_time: 0.447 ± 0.02 ms (n=50)
# Average render_time: 23.821 ± 6.008 ms (n=50)
# Average wsgi_time: 41.621 ± 7.911 ms (n=50)
# Average total time: 70.065 ± 15.61 ms (n=50)
#
#
# *** item_type: /ENCSR825UNV/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCSR825UNV/ -------------
# Average es_time: 7.651 ± 0.795 ms (n=50)
# Average queue_time: 0.496 ± 0.017 ms (n=50)
# Average render_time: 214.359 ± 7.611 ms (n=50)
# Average wsgi_time: 450.827 ± 223.591 ms (n=50)
# Average total time: 673.333 ± 222.807 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCSR825UNV/ --------------------
# Average es_time: 22.394 ± 5.35 ms (n=50)
# Average queue_time: 0.489 ± 0.021 ms (n=50)
# Average render_time: 212.983 ± 7.953 ms (n=50)
# Average wsgi_time: 514.785 ± 280.001 ms (n=50)
# Average total time: 750.652 ± 281.499 ms (n=50)

# %%
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=50)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCAB830JLB/ -------------
# Average es_time: 1.478 ± 0.355 ms (n=50)
# Average queue_time: 0.456 ± 0.017 ms (n=50)
# Average render_time: 39.482 ± 6.56 ms (n=50)
# Average wsgi_time: 66.734 ± 7.516 ms (n=50)
# Average total time: 108.15 ± 14.101 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCAB830JLB/ --------------------
# Average es_time: 3.655 ± 0.701 ms (n=50)
# Average queue_time: 0.436 ± 0.026 ms (n=50)
# Average render_time: 38.509 ± 6.206 ms (n=50)
# Average wsgi_time: 67.066 ± 6.822 ms (n=50)
# Average total time: 109.667 ± 13.242 ms (n=50)
#
#
# *** item_type: /ENCAB000BKR/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCAB000BKR/ -------------
# Average es_time: 1.272 ± 0.191 ms (n=50)
# Average queue_time: 0.453 ± 0.017 ms (n=50)
# Average render_time: 19.947 ± 6.523 ms (n=50)
# Average wsgi_time: 32.458 ± 6.693 ms (n=50)
# Average total time: 54.13 ± 13.239 ms (n=50)
# ------------------- https://test.encodedcc.org/ENCAB000BKR/ --------------------
# Average es_time: 2.95 ± 0.839 ms (n=50)
# Average queue_time: 0.46 ± 0.039 ms (n=50)
# Average render_time: 19.6 ± 6.643 ms (n=50)
# Average wsgi_time: 34.022 ± 6.833 ms (n=50)
# Average total time: 57.031 ± 13.672 ms (n=50)
#
#
# *** item_type: /ENCAB284TTY/
# ------------ https://sno68-on-dev.demo.encodedcc.org//ENCAB284TTY/ -------------

# %%
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=50)

# %% [markdown]
# ##
