# %%
import qancode as q

# %%
qa = q.QANCODE(rc_url="https://v71rc1-master.demo.encodedcc.org/")

# %%
qa.compare_facets(users=['Public'], browsers=['Chrome'], browser_comparison=False)
# Out:
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=File
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Library
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=AntibodyLot
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Biosample
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Donor
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: search/?type=GeneticModification
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=FileSet
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Series
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=OrganismDevelopmentSeries
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=UcscBrowserComposite
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=ReferenceEpigenome
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Project
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=ReplicationTimingSeries
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=PublicationData
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=MatchedSet
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=TreatmentConcentrationSeries
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=TreatmentTimeSeries
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Target
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Pipeline
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Publication
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /search/?type=Software
# Search page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /matrix/?type=Experiment
# Matrix page detected
# Opening https://www.encodeproject.org in Chrome
# Getting type: /matrix/?type=Annotation
# Matrix page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Experiment
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=File
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Library
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=AntibodyLot
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Biosample
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Donor
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: search/?type=GeneticModification
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=FileSet
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Annotation
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Series
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=OrganismDevelopmentSeries
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=UcscBrowserComposite
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=ReferenceEpigenome
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Project
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=ReplicationTimingSeries
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=PublicationData
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=MatchedSet
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=TreatmentConcentrationSeries
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=TreatmentTimeSeries
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Target
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Pipeline
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Publication
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /search/?type=Software
# Search page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /matrix/?type=Experiment
# Matrix page detected
# Opening https://v71rc1-master.demo.encodedcc.org/ in Chrome
# Getting type: /matrix/?type=Annotation
# Matrix page detected
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /search/?type=Experiment
# ASSAY
#      prod: [("5' RLM RACE", '2'), ('5C', '13'), ('ATAC-seq', '180'), ('CAGE', '121'), ('CRISPR RNA-seq', '50'), ('CRISPRi RNA-seq', '77'), ('ChIA-PET', '62'), ('ChIP-seq', '8911'), ('Circulome-seq', '1'), ('DNA-PET', '6'), ('DNAme array', '259'), ('DNase-seq', '873'), ('FAIRE-seq', '37'), ('Hi-C', '36'), ('MNase-seq', '2'), ('MRE-seq', '68'), ('MS-MS', '14'), ('MeDIP-seq', '55'), ('PAS-seq', '47'), ('RAMPAGE', '168'), ('RIP-chip', '32'), ('RIP-seq', '73'), ('RNA Bind-n-Seq', '161'), ('RNA microarray', '291'), ('RNA-PET', '31'), ('RRBS', '218'), ('Repli-chip', '63'), ('Repli-seq', '119'), ('Switchgear', '2'), ('TAB-seq', '8'), ('WGBS', '258'), ('eCLIP', '359'), ('genetic modification DNase-seq', '40'), ('genotyping HTS', '16'), ('genotyping array', '142'), ('iCLIP', '7'), ('microRNA counts', '115'), ('microRNA-seq', '185'), ('polyA RNA-seq', '817'), ('polyA depleted RNA-seq', '32'), ('shRNA RNA-seq', '533'), ('siRNA RNA-seq', '113'), ('single cell RNA-seq', '120'), ('small RNA-seq', '216'), ('total RNA-seq', '413'), ('whole genome sequencing assay', '21')]
# ASSAY CATEGORY
#      prod: [('3D chromatin structure', '111'), ('DNA accessibility', '1132'), ('DNA binding', '8911'), ('DNA methylation', '866'), ('DNA sequencing', '22'), ('Genotyping', '164'), ('Proteomics', '14'), ('RNA binding', '634'), ('Replication timing', '182'), ('Transcription', '3331')]
# AUDIT CATEGORY
#      prod: [('control extremely low read depth', '24'), ('extremely low coverage', '7'), ('extremely low read depth', '221'), ('extremely low read length', '10'), ('extremely low spot score', '49'), ('inconsistent control', '3'), ('inconsistent library biosample', '1'), ('inconsistent read count', '2'), ('missing antibody', '75'), ('missing control alignments', '418'), ('missing donor', '1'), ('missing nih_institutional_certification', '33'), ('missing possible_controls', '2')]
# AUDIT CATEGORY2
#      prod: [('antibody not characterized to standard', '25'), ('control insufficient read depth', '952'), ('insufficient coverage', '4'), ('insufficient read depth', '1757'), ('insufficient read length', '511'), ('insufficient replicate concordance', '48'), ('missing RNA fragment size', '2'), ('missing controlled_by', '596'), ('missing documents', '30'), ('missing input control', '2'), ('missing possible_controls', '27'), ('missing spikeins', '173'), ('partially characterized antibody', '139'), ('poor library complexity', '283'), ('severe bottlenecking', '271'), ('uncharacterized antibody', '11'), ('unreplicated experiment', '341')]
# AUDIT CATEGORY3
#      prod: [('antibody characterized with exemption', '676'), ('borderline replicate concordance', '455'), ('control low read depth', '659'), ('file validation error', '40'), ('high lambda C methylation ratio', '3'), ('inconsistent assembly', '18'), ('inconsistent control read length', '907'), ('inconsistent control run_type', '158'), ('inconsistent platforms', '1032'), ('inconsistent target of control experiment', '217'), ('low coverage', '4'), ('low read depth', '2545'), ('low read length', '3292'), ('low replicate concordance', '89'), ('low spot score', '321'), ('mild to moderate bottlenecking', '2873'), ('missing external identifiers', '330'), ('missing genetic modification characterization', '2307'), ('missing genotype', '116'), ('missing spikeins', '28'), ('mixed read lengths', '482'), ('mixed run types', '101'), ('moderate library complexity', '1280')]
# AVAILABLE DATA
#      prod: [('CEL', '4'), ('bam', '12757'), ('bed bed12', '43'), ('bed bed3', '7'), ('bed bed3+', '869'), ('bed bed6+', '115'), ('bed bed9', '18'), ('bed bedExonScore', '27'), ('bed bedGraph', '30'), ('bed bedLogR', '64'), ('bed bedMethyl', '278'), ('bed bedRnaElements', '288'), ('bed broadPeak', '2451'), ('bed idr_peak', '134'), ('bed modPepMap', '6'), ('bed narrowPeak', '7324'), ('bed pepMap', '6'), ('bed peptideMapping', '8'), ('bed tss_peak', '235'), ('bedpe', '5'), ('bigBed bed12', '43'), ('bigBed bed3', '7'), ('bigBed bed3+', '13'), ('bigBed bed6+', '115'), ('bigBed bed9', '18'), ('bigBed bedExonScore', '27'), ('bigBed bedLogR', '63'), ('bigBed bedMethyl', '278'), ('bigBed bedRnaElements', '288'), ('bigBed broadPeak', '1992'), ('bigBed idr_peak', '134'), ('bigBed modPepMap', '6'), ('bigBed narrowPeak', '7313'), ('bigBed pepMap', '6'), ('bigBed peptideMapping', '8'), ('bigBed tss_peak', '235'), ('bigWig', '11714'), ('csfasta', '25'), ('csqual', '13'), ('fasta', '3'), ('fastq', '13745'), ('gff gff3', '235'), ('gtf', '269'), ('hdf5', '20'), ('hic', '5'), ('idat', '277'), ('rcc', '115'), ('sam', '59'), ('sra', '672'), ('tagAlign', '1368'), ('tar', '110'), ('tsv', '2470'), ('vcf', '13'), ('wig', '59')]
# BIOSAMPLE TREATMENT
#      prod: [('17β-estradiol', '38'), ('17β-hydroxy-17-methylestra-4,9,11-trien-3-one', '4'), ('17β-hydroxy-5α-androstan-3-one', '3'), ('20-hydroxyecdysone', '16'), ('Lipopolysaccharide', '66'), ('Sendai virus', '1'), ('Sindbis virus', '4'), ('Transforming growth factor beta-1', '1'), ('UT189', '3'), ('afimoxifene', '16'), ('all-trans-retinoic acid', '21'), ('bisphenol A', '4'), ('cadmium dichloride', '4'), ('caffeine', '3'), ('calcium', '52'), ('cisplatin', '1'), ('cold shock treatment', '2'), ('copper(II) sulfate', '32'), ('dexamethasone', '293'), ('differentiation', '1'), ('dimethyl sulfoxide', '39'), ('doxycycline', '1'), ('doxycycline hyclate', '33'), ('erythropoietin', '9'), ('estradiol', '8'), ('ethanol', '57'), ('forskolin and pyruvate', '8'), ('genistein', '4'), ('heat shock treatment', '1'), ('hydrocortisone succinate', '9'), ('hydroxyurea', '1'), ('insulin and 22-hydroxycholesterol', '2'), ('interferon alpha', '19'), ('interferon gamma', '18'), ('interleukin-3', '9'), ('ionomycin', '14'), ('kit ligand', '9'), ('lactate', '3'), ('methyltrienolone', '1'), ('paraquat', '2'), ('phorbol 13-acetate 12-myristate', '14'), ('pravastatin', '4'), ('resveratrol', '1'), ('retinoic acid', '2'), ('rotenone', '3'), ('serum free', '2'), ('sodium butyrate', '3'), ('tamoxifen', '2'), ('tumor necrosis factor', '20'), ('vorinostat', '1'), ('zinc dichloride', '3')]
# BIOSAMPLE TYPE
#      prod: [('cell line', '5779'), ('cell-free sample', '161'), ('in vitro differentiated cells', '679'), ('induced pluripotent stem cell line', '137'), ('primary cell', '1678'), ('stem cell', '506'), ('tissue', '4375'), ('whole organisms', '2052')]
# DATE SUBMITTED
#      prod: [('2010-11-16', '12'), ('2011-01-11', '18'), ('2011-06-25', '14'), ('2011-07-13', '12'), ('2011-10-27', '10'), ('2011-12-23', '14'), ('2012-01-23', '29'), ('2013-05-09', '16'), ('2013-07-16', '15'), ('2013-07-18', '10'), ('2014-01-30', '23'), ('2014-02-25', '53'), ('2014-03-13', '24'), ('2014-03-15', '161'), ('2014-03-19', '69'), ('2014-03-20', '23'), ('2014-04-04', '15'), ('2014-04-29', '11'), ('2014-05-13', '39'), ('2014-05-14', '16'), ('2014-05-29', '36'), ('2014-06-10', '18'), ('2014-06-17', '20'), ('2014-06-30', '22'), ('2014-07-01', '22'), ('2014-07-03', '12'), ('2014-07-04', '71'), ('2014-07-06', '25'), ('2014-07-26', '35'), ('2014-07-30', '30'), ('2014-09-15', '26'), ('2014-09-17', '24'), ('2014-09-27', '32'), ('2014-09-29', '41'), ('2014-10-07', '21'), ('2014-10-24', '41'), ('2014-10-26', '25'), ('2014-10-29', '33'), ('2014-11-04', '31'), ('2014-11-21', '12'), ('2014-12-05', '13'), ('2014-12-08', '23'), ('2014-12-11', '53'), ('2014-12-13', '48'), ('2014-12-16', '21'), ('2014-12-17', '51'), ('2015-02-19', '24'), ('2015-02-21', '10'), ('2015-03-11', '13'), ('2015-03-13', '10'), ('2015-03-27', '29'), ('2015-03-31', '55'), ('2015-04-02', '19'), ('2015-05-22', '10'), ('2015-05-29', '16'), ('2015-06-18', '57'), ('2015-06-25', '19'), ('2015-06-28', '17'), ('2015-06-30', '30'), ('2015-07-16', '36'), ('2015-07-19', '96'), ('2015-07-23', '166'), ('2015-07-24', '123'), ('2015-07-29', '184'), ('2015-07-30', '54'), ('2015-08-05', '14'), ('2015-08-12', '18'), ('2015-08-13', '36'), ('2015-08-14', '43'), ('2015-08-24', '14'), ('2015-09-23', '12'), ('2015-09-24', '22'), ('2015-09-29', '27'), ('2015-09-30', '59'), ('2015-10-03', '27'), ('2015-10-21', '16'), ('2015-10-22', '12'), ('2015-10-30', '32'), ('2015-10-31', '27'), ('2015-12-07', '11'), ('2015-12-08', '13'), ('2015-12-10', '36'), ('2015-12-11', '38'), ('2015-12-14', '20'), ('2015-12-15', '20'), ('2015-12-16', '25'), ('2015-12-17', '16'), ('2015-12-22', '12'), ('2016-01-13', '20'), ('2016-01-22', '23'), ('2016-01-27', '22'), ('2016-02-01', '10'), ('2016-02-06', '20'), ('2016-02-10', '31'), ('2016-02-11', '25'), ('2016-02-16', '10'), ('2016-02-17', '10'), ('2016-02-26', '39'), ('2016-03-02', '17'), ('2016-03-03', '16'), ('2016-03-04', '45'), ('2016-03-07', '17'), ('2016-03-08', '11'), ('2016-03-09', '16'), ('2016-03-11', '62'), ('2016-03-13', '23'), ('2016-03-14', '35'), ('2016-03-15', '20'), ('2016-03-16', '56'), ('2016-03-17', '70'), ('2016-03-21', '155'), ('2016-03-22', '109'), ('2016-03-23', '29'), ('2016-03-25', '16'), ('2016-03-26', '21'), ('2016-03-30', '10'), ('2016-03-31', '98'), ('2016-04-09', '40'), ('2016-04-10', '16'), ('2016-04-11', '111'), ('2016-04-12', '14'), ('2016-04-13', '12'), ('2016-04-18', '11'), ('2016-04-19', '16'), ('2016-04-23', '43'), ('2016-04-24', '29'), ('2016-04-26', '20'), ('2016-04-27', '89'), ('2016-04-28', '51'), ('2016-04-29', '15'), ('2016-05-03', '17'), ('2016-05-09', '20'), ('2016-05-12', '19'), ('2016-05-13', '27'), ('2016-05-20', '20'), ('2016-05-26', '31'), ('2016-05-30', '83'), ('2016-06-22', '24'), ('2016-06-28', '45'), ('2016-06-29', '29'), ('2016-07-07', '19'), ('2016-07-20', '32'), ('2016-07-27', '12'), ('2016-07-29', '131'), ('2016-07-30', '156'), ('2016-07-31', '13'), ('2016-08-01', '57'), ('2016-08-02', '15'), ('2016-08-03', '66'), ('2016-08-04', '26'), ('2016-08-05', '18'), ('2016-08-23', '12'), ('2016-08-24', '40'), ('2016-09-16', '16'), ('2016-09-24', '14'), ('2016-09-25', '18'), ('2016-10-04', '26'), ('2016-10-11', '20'), ('2016-10-12', '21'), ('2016-10-14', '13'), ('2016-10-18', '13'), ('2016-10-19', '94'), ('2016-10-20', '68'), ('2016-10-21', '18'), ('2016-10-22', '27'), ('2016-10-24', '12'), ('2016-10-28', '23'), ('2016-10-31', '56'), ('2016-11-18', '39'), ('2016-12-05', '13'), ('2016-12-08', '14'), ('2016-12-09', '44'), ('2016-12-12', '25'), ('2016-12-15', '49'), ('2016-12-16', '12'), ('2016-12-20', '45'), ('2016-12-21', '48'), ('2016-12-31', '13'), ('2017-01-01', '11'), ('2017-01-12', '15'), ('2017-01-18', '25' ...
# DATE RELEASED
#      prod: [('April, 2011', '149'), ('April, 2012', '77'), ('April, 2013', '6'), ('April, 2014', '2'), ('April, 2015', '28'), ('April, 2016', '170'), ('April, 2017', '52'), ('April, 2018', '48'), ('August, 2011', '88'), ('August, 2012', '257'), ('August, 2015', '180'), ('August, 2016', '265'), ('August, 2017', '71'), ('December, 2010', '68'), ('December, 2011', '87'), ('December, 2014', '247'), ('December, 2015', '40'), ('December, 2016', '174'), ('December, 2017', '139'), ('February, 2011', '255'), ('February, 2012', '264'), ('February, 2013', '1'), ('February, 2014', '7'), ('February, 2015', '3'), ('February, 2016', '183'), ('February, 2017', '138'), ('February, 2018', '177'), ('January, 2011', '6'), ('January, 2012', '59'), ('January, 2015', '8'), ('January, 2016', '110'), ('January, 2017', '399'), ('January, 2018', '156'), ('July, 2009', '22'), ('July, 2011', '263'), ('July, 2012', '128'), ('July, 2013', '2761'), ('July, 2014', '300'), ('July, 2015', '103'), ('July, 2016', '614'), ('July, 2017', '39'), ('June, 2011', '83'), ('June, 2012', '75'), ('June, 2014', '432'), ('June, 2015', '106'), ('June, 2016', '221'), ('June, 2017', '272'), ('March, 2011', '160'), ('March, 2012', '170'), ('March, 2013', '1'), ('March, 2014', '887'), ('March, 2015', '2'), ('March, 2016', '291'), ('March, 2017', '96'), ('March, 2018', '134'), ('May, 2011', '35'), ('May, 2012', '138'), ('May, 2013', '2'), ('May, 2014', '8'), ('May, 2015', '12'), ('May, 2016', '569'), ('May, 2017', '66'), ('May, 2018', '15'), ('November, 2010', '9'), ('November, 2011', '76'), ('November, 2012', '7'), ('November, 2014', '98'), ('November, 2015', '225'), ('November, 2016', '400'), ('November, 2017', '428'), ('October, 2009', '4'), ('October, 2010', '1'), ('October, 2011', '456'), ('October, 2014', '86'), ('October, 2015', '106'), ('October, 2016', '485'), ('October, 2017', '200'), ('September, 2011', '134'), ('September, 2012', '190'), ('September, 2014', '41'), ('September, 2015', '17'), ('September, 2016', '209'), ('September, 2017', '115')]
# EXPERIMENT STATUS
#      prod: [('archived', '1012'), ('released', '14124'), ('revoked', '231')]
# GENOME ASSEMBLY (VISUALIZATION)
#      prod: [('GRCh38', '7315'), ('ce10', '838'), ('ce11', '897'), ('dm3', '835'), ('dm6', '811'), ('hg19', '7492'), ('mm10', '1508'), ('mm9', '338')]
# LAB
#      prod: [('Alexander Urban, Stanford', '3'), ('Ali Mortazavi, UCI', '231'), ('Andrew Z. Fire, Stanford', '4'), ('Barbara Wold, Caltech', '287'), ('Bing Ren, UCSD', '1379'), ('Bradley Bernstein, Broad', '1957'), ('Brenton Graveley, UConn', '789'), ('Brian Oliver, NIH', '27'), ('Chris Burge, MIT', '161'), ('Christina Leslie, MSKCC', '32'), ('David Gilbert, FSU', '77'), ('David MacAlpine, Duke', '39'), ('Eric Lécuyer, IRCM', '30'), ('Gene Yeo, UCSD', '366'), ('Gregory Crawford, Duke', '162'), ('Jason Lieb, UNC', '37'), ('Job Dekker, UMass', '26'), ('Joe Ecker, Salk', '193'), ('John Rinn, Broad', '35'), ('John Stamatoyannopoulos, UW', '1594'), ('Joseph Costello, UCSF', '595'), ('Kevin Struhl, HMS', '43'), ('Kevin White, UChicago', '1064'), ('Manuel Garber, UMass', '68'), ('Michael Snyder, Stanford', '2401'), ('Morgan Giddings, UNC', '14'), ('Paul Khavari, Stanford', '13'), ('Peggy Farnham, USC', '125'), ('Piero Carninci, RIKEN', '78'), ('Richard Myers, HAIB', '1423'), ('Ross Hardison, PennState', '128'), ('Scott Tenenbaum, SUNY-Albany', '42'), ('Sherman Weissman, Yale', '65'), ('Susan Celniker, LBNL', '239'), ('Terry Orr-Weaver, MIT', '2'), ('Thomas Gingeras, CSHL', '736'), ('Tim Reddy, Duke', '298'), ('Valerie Reinke, Yale', '361'), ('Vishwanath Iyer, UTA', '85'), ('Will Greenleaf, Stanford', '13'), ('Xiang-Dong Fu, UCSD', '97'), ('Yijun Ruan, JAX', '48')]
# LIBRARY DEPLETED IN
#      prod: [('polyadenylated mRNA', '57'), ('rRNA', '870')]
# LIBRARY INSERT SIZE (NT)
#      prod: [('10-50', '2'), ('100-100', '3'), ('100-300', '24'), ('100-350', '17'), ('100-500', '17'), ('120-200', '128'), ('120-280', '1'), ('125-278', '1'), ('138-1000', '1'), ('149-512', '1'), ('150-1000', '13'), ('150-150', '35'), ('150-250', '47'), ('150-300', '4'), ('150-350', '537'), ('150-400', '15'), ('151-347', '1'), ('151-379', '1'), ('151-499', '1'), ('153-309', '1'), ('153-499', '1'), ('156-312', '1'), ('157-497', '1'), ('159-196', '1'), ('165-203', '1'), ('168-367', '1'), ('169-225', '1'), ('170-202', '1'), ('171-201', '1'), ('172-1452', '1'), ('172-200', '1'), ('175-196', '1'), ('175-250', '3'), ('175-275', '2'), ('175-300', '359'), ('175-500', '35'), ('177-207', '1'), ('180-500', '84'), ('184-224', '1'), ('185-234', '1'), ('186-747', '1'), ('187-1606', '1'), ('19-25', '66'), ('20-20', '132'), ('200-1000', '9'), ('200-1500', '6'), ('200-200', '6'), ('200-250', '48'), ('200-300', '3'), ('200-325', '1'), ('200-400', '97'), ('200-491', '1'), ('200-500', '183'), ('200-594', '1'), ('200-600', '734'), ('200-650', '2'), ('200-712', '1'), ('200-750', '74'), ('200-764', '1'), ('200-800', '802'), ('200-900', '1'), ('208-442', '1'), ('209-891', '1'), ('210-480', '1'), ('213-451', '1'), ('215-1000', '1'), ('217-475', '1'), ('221-1000', '1'), ('222-318', '1'), ('225-350', '1'), ('232-1000', '1'), ('240-420', '13'), ('250-430', '4'), ('250-470', '2'), ('266-470', '1'), ('267-400', '2'), ('268-478', '1'), ('270-500', '1'), ('275-470', '1'), ('280-509', '1'), ('285-477', '1'), ('287-478', '1'), ('289-481', '1'), ('2963-2963', '1'), ('299-300', '28'), ('300-1000', '43'), ('300-350', '4'), ('300-400', '1'), ('300-500', '644'), ('300-600', '79'), ('300-700', '1'), ('300-800', '19'), ('312-506', '1'), ('312-531', '1'), ('325-425', '1'), ('325-450', '1'), ('350-450', '26'), ('373-373', '1'), ('40-40', '27'), ('400-400', '3'), ('450-650', '1085'), ('50-300', '11'), ('<200', '216'), ('<30', '231'), ('>175', '17'), ('>200', '2660')]
# LIBRARY MADE FROM
#      prod: [('DNA', '11433'), ('RNA', '2112'), ('miRNA', '300'), ('polyadenylated mRNA', '1509')]
# LIBRARY TREATMENT
#      prod: [('Antarctic Phosphatase', '26'), ('Tobacco Acid Pyrophosphatase', '179'), ('duplex-specific nuclease (DSN) normalization', '29')]
# LIFE STAGE
#      prod: [('L1 larva', '187'), ('L2 larva', '106'), ('L3 larva', '119'), ('L4 larva', '153'), ('L4/young adult', '6'), ('adult', '6601'), ('child', '1305'), ('dauer', '2'), ('early embryonic', '20'), ('embryonic', '3978'), ('first instar larva', '5'), ('larva', '3'), ('late embryonic', '137'), ('midembryonic', '4'), ('mixed stage (embryonic)', '70'), ('newborn', '333'), ('postnatal', '250'), ('prepupa', '129'), ('pupa', '21'), ('second instar larva', '4'), ('third instar larva', '78'), ('unknown', '1446'), ('wandering third instar larva', '109'), ('young adult', '162')]
# MAPPED READ LENGTH (NT)
#      prod: [('100', '832'), ('101', '262'), ('25', '16'), ('27', '42'), ('28', '83'), ('30', '57'), ('32', '55'), ('33', '5'), ('35', '9'), ('36', '3162'), ('37', '10'), ('38', '3'), ('40', '98'), ('41', '25'), ('45', '10'), ('47', '1'), ('48', '7'), ('50', '652'), ('51', '32'), ('72', '3'), ('74', '21'), ('75', '143'), ('76', '821'), ('83', '7')]
# ORGAN
#      prod: [('adipose tissue', '137'), ('adrenal gland', '105'), ('artery', '42'), ('blood', '2614'), ('blood vessel', '208'), ('bodily fluid', '2614'), ('bone element', '117'), ('bone marrow', '38'), ('brain', '937'), ('breast', '49'), ('bronchus', '20'), ('connective tissue', '571'), ('embryo', '984'), ('epithelium', '723'), ('esophagus', '117'), ('extraembryonic component', '203'), ('eye', '36'), ('gonad', '130'), ('heart', '340'), ('intestine', '559'), ('kidney', '571'), ('large intestine', '359'), ('limb', '356'), ('liver', '1184'), ('lung', '927'), ('lymph node', '169'), ('lymphatic vessel', '6'), ('lymphoid tissue', '41'), ('mammary gland', '427'), ('mouth', '25'), ('musculature of body', '553'), ('nerve', '39'), ('nose', '2'), ('ovary', '55'), ('pancreas', '146'), ('penis', '212'), ('pericardium', '4'), ('placenta', '65'), ('prostate gland', '118'), ('skeleton', '5'), ('skin of body', '565'), ('small intestine', '107'), ('spinal cord', '28'), ('spleen', '195'), ('stomach', '250'), ('testis', '69'), ('thymus', '53'), ('thyroid gland', '60'), ('tongue', '5'), ('trachea', '3'), ('ureter', '31'), ('urinary bladder', '21'), ('uterus', '230'), ('vagina', '29'), ('vasculature', '231'), ('vein', '69')]
# ORGANISM
#      prod: [('Caenorhabditis elegans', '975'), ('Drosophila ananassae', '1'), ('Drosophila melanogaster', '1435'), ('Drosophila mojavensis', '4'), ('Drosophila pseudoobscura', '12'), ('Drosophila simulans', '8'), ('Drosophila virilis', '1'), ('Drosophila yakuba', '1'), ('Homo sapiens', '10891'), ('Mus musculus', '1864')]
# PLATFORM
#      prod: [('Affymetrix - Human Exon 1.0 ST V2 tilling array', '4'), ('Applied Biosystems SOLiD System 3 Plus', '50'), ('Illumina - Methylation 450K BeadChip', '62'), ('Illumina Genome Analyzer', '976'), ('Illumina Genome Analyzer I', '138'), ('Illumina Genome Analyzer II', '765'), ('Illumina Genome Analyzer IIe', '97'), ('Illumina Genome Analyzer IIx', '2417'), ('Illumina HiSeq 1000', '8'), ('Illumina HiSeq 2000', '6401'), ('Illumina HiSeq 2500', '2495'), ('Illumina HiSeq 4000', '1509'), ('Illumina HiSeq X Ten', '37'), ('Illumina Infinium Methylation EPIC BeadChip', '156'), ('Illumina Infinium Omni5Exome-4 Kit', '59'), ('Illumina MiSeq', '4'), ('Illumina NextSeq 500', '246'), ('Mouse 385K Whole Genome CGH Tiling Array', '16'), ('Mouse 3x720K Whole Genome CGH Tiling Array', '2'), ('Nimbelgen - Human 3x720K Whole Genome CGH Tiling Array', '34'), ('Nimblegen - Human 2.1M Whole-Genome CGH Tiling Array v2.0', '8'), ('Nimblegen - Human 6x630K CGH Whole Genome tiling array', '12'), ('Roche 454 Genome Sequencer FLX', '2'), ('nCounter Human V2 miRNA Expression array', '38'), ('nCounter Mouse V1.2 miRNA Expression array', '5'), ('nCounter Mouse V1.3 miRNA Expression array', '58'), ('nCounter Mouse V1.5 miRNA Expression array', '14')]
# PROJECT
#      prod: [('ENCODE', '9701'), ('GGR', '461'), ('Roadmap', '2761'), ('community', '7'), ('modENCODE', '1330'), ('modERN', '1107')]
# RFA
#      prod: [('ENCODE2', '2805'), ('ENCODE2-Mouse', '564'), ('ENCODE3', '6291'), ('ENCODE4', '41'), ('GGR', '461'), ('Roadmap', '2761'), ('community', '7'), ('modENCODE', '1330'), ('modERN', '1107')]
# READ LENGTH (NT)
#      prod: [('100', '2090'), ('101', '1132'), ('108', '11'), ('113', '1'), ('117', '2'), ('125', '11'), ('130', '40'), ('132', '3'), ('133', '3'), ('136', '2'), ('139', '3'), ('150', '10'), ('151', '44'), ('152', '6'), ('176', '1'), ('18', '5'), ('191', '1'), ('20', '153'), ('202', '17'), ('25', '84'), ('250', '1'), ('27', '90'), ('28', '59'), ('29', '9'), ('30', '119'), ('300', '2'), ('31', '73'), ('32', '526'), ('33', '44'), ('34', '78'), ('35', '42'), ('36', '4574'), ('37', '44'), ('38', '7'), ('39', '33'), ('40', '191'), ('41', '23'), ('42', '15'), ('43', '66'), ('44', '87'), ('45', '249'), ('458', '1'), ('46', '46'), ('47', '2'), ('48', '35'), ('49', '15'), ('50', '2739'), ('51', '394'), ('52', '2'), ('53', '1'), ('55', '125'), ('56', '3'), ('58', '1'), ('59', '1'), ('61', '1'), ('62', '1'), ('70', '2'), ('71', '1'), ('72', '10'), ('73', '30'), ('74', '22'), ('75', '256'), ('76', '1471'), ('78', '42'), ('80', '27'), ('82', '2'), ('83', '10'), ('84', '1'), ('85', '6'), ('86', '2'), ('87', '4'), ('88', '1'), ('90', '1'), ('94', '1'), ('98', '1'), ('99', '9')]
# REPLICATION TYPE
#      prod: [('anisogenic', '430'), ('isogenic', '8730'), ('unreplicated', '6205')]
# RUN TYPE
#      prod: [('paired-ended', '4504'), ('single-ended', '9669')]
# TARGET OF ASSAY
#      prod: [('RNA binding protein', '1466'), ('broad histone mark', '1727'), ('chromatin remodeller', '254'), ('control', '2568'), ('histone', '3102'), ('narrow histone mark', '1265'), ('nucleotide modification', '70'), ('other context', '58'), ('other post-translational modification', '76'), ('recombinant protein', '1271'), ('tag', '1'), ('transcription factor', '3971')]
#
# ------------------------------------- File -------------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /search/?type=File
# AUDIT CATEGORY
#      prod: [('control extremely low read depth', '67'), ('extremely low coverage', '551'), ('extremely low read depth', '653'), ('extremely low read length', '54'), ('extremely low spot score', '360'), ('inconsistent control', '7'), ('inconsistent library biosample', '4'), ('inconsistent read count', '4'), ('missing antibody', '208'), ('missing control alignments', '1470'), ('missing nih_institutional_certification', '88'), ('missing possible_controls', '24')]
# AUDIT CATEGORY2
#      prod: [('antibody not characterized to standard', '81'), ('control insufficient read depth', '2546'), ('insufficient coverage', '54'), ('insufficient read depth', '5319'), ('insufficient read length', '2109'), ('insufficient replicate concordance', '267'), ('missing controlled_by', '1283'), ('missing documents', '110'), ('missing input control', '4'), ('missing possible_controls', '61'), ('missing spikeins', '780'), ('partially characterized antibody', '577'), ('poor library complexity', '1078'), ('severe bottlenecking', '1114'), ('uncharacterized antibody', '82'), ('unreplicated experiment', '948')]
# AUDIT CATEGORY3
#      prod: [('antibody characterized with exemption', '3199'), ('borderline replicate concordance', '1792'), ('control low read depth', '1853'), ('file validation error', '148'), ('high lambda C methylation ratio', '238'), ('inconsistent assembly', '93'), ('inconsistent control read length', '1586'), ('inconsistent control run_type', '320'), ('inconsistent platforms', '4179'), ('inconsistent target of control experiment', '880'), ('low coverage', '20'), ('low read depth', '8967'), ('low read length', '10417'), ('low replicate concordance', '657'), ('low spot score', '2075'), ('mild to moderate bottlenecking', '10435'), ('missing spikeins', '212'), ('mixed read lengths', '1973'), ('mixed run types', '573'), ('moderate library complexity', '4717')]
# CONTENT CATEGORY
#      prod: [('alignment', '83296'), ('annotation', '139643'), ('quantification', '22336'), ('raw data', '48346'), ('reference', '145'), ('signal', '130574'), ('validation', '56')]
# CONTENT TYPE
#      prod: [('HMM predicted chromatin state', '54'), ('RNA-binding protein associated mRNAs', '92'), ('alignments', '52579'), ('base overlap signal', '194'), ('blacklisted regions', '14'), ('candidate enhancers', '873'), ('candidate promoters', '570'), ('candidate regulatory elements', '2903'), ('chromatin interactions', '300'), ('clusters', '68'), ('conservative idr thresholded peaks', '7235'), ('contigs', '422'), ('control normalized signal', '5405'), ('copy number variation', '179'), ('distal peaks', '8'), ('enhancer validation', '21'), ('enrichment', '4081'), ('exon quantifications', '901'), ('female genome index', '14'), ('female genome reference', '3'), ('filtered SNPs', '5'), ('filtered indels', '6'), ('filtered modified peptide quantification', '12'), ('filtered peaks', '346'), ('filtered peptide quantification', '28'), ('filtered regions', '20'), ('filtered transcribed fragments', '52'), ('fold change over control', '25044'), ('gene quantifications', '8091'), ('genome compartments', '52'), ('genome index', '30'), ('genome reference', '39'), ('hotspots', '12519'), ('idat green channel', '279'), ('idat red channel', '275'), ('intensity values', '127'), ('library fraction', '301'), ('long range chromatin interactions', '93'), ('male genome index', '16'), ('male genome reference', '11'), ('methylation state at CHG', '544'), ('methylation state at CHH', '544'), ('methylation state at CpG', '979'), ('microRNA quantifications', '454'), ('minus strand signal', '515'), ('minus strand signal of all reads', '10343'), ('minus strand signal of unique reads', '11441'), ('nested topologically associated domains', '24'), ('normalized signal of all reads', '70'), ('open chromatin regions', '20'), ('optimal idr thresholded peaks', '14297'), ('peaks', '82553'), ('percentage normalized signal', '96'), ('plus strand signal', '515'), ('plus strand signal of all reads', '10344'), ('plus strand signal of unique reads', '11439'), ('predicted enhancers', '7'), ('predicted forebrain enhancers', '93'), ('predicted heart enhancers', '97'), ('predicted transcription start sites', '160'), ('predicted whole brain enhancers', '5'), ('primer sequence', '2'), ('proximal peaks', '8'), ('pseudoreplicated idr thresholded peaks', '1194'), ('rRNA reference', '2'), ('raw signal', '1507'), ('read-depth normalized signal', '9011'), ('reads', '47007'), ('redacted alignments', '1701'), ('redacted unfiltered alignments', '1702'), ('rejected reads', '431'), ('relative replication signal', '7'), ('replicated peaks', '7070'), ('replication timing profile', '70'), ('reporter code counts', '227'), ('representative dnase hypersensitivity sites', '4'), ('semi-automated genome annotation', '360'), ('sequence alignability', '20'), ('sequence uniqueness', '2'), ('signal', '2239'), ('signal of all reads', '2286'), ('signal of unique reads', '11871'), ('signal p-value', '28089'), ('spike-in alignments', '94'), ('spike-in sequence', '5'), ('splice junctions', '367'), ('stable peaks', '4700'), ('summed densities signal', '16'), ('topologically associated domains', '37'), ('transcribed fragments', '62'), ('transcript quantifications', '6291'), ('transcription start sites', '2729'), ('transcriptome alignments', '5824'), ('transcriptome reference', '1'), ('unfiltered alignments', '21396'), ('unfiltered modified peptide quantification', '12'), ('unfiltered peptide quantification', '28'), ('validation', '35'), ('valleys', '32'), ('variant calls', '13'), ('wavelet-smoothed signal', '142')]
# FILE FORMAT
#      prod: [('CEL', '8'), ('bam', '80877'), ('bed', '75479'), ('bedpe', '5'), ('bigBed', '69860'), ('bigWig', '130365'), ('csfasta', '49'), ('csqual', '38'), ('fasta', '26'), ('fastq', '46115'), ('gff', '720'), ('gtf', '1172'), ('hdf5', '280'), ('hic', '20'), ('idat', '554'), ('rcc', '227'), ('sam', '188'), ('sra', '1233'), ('tagAlign', '2278'), ('tar', '244'), ('tsv', '14446'), ('vcf', '24'), ('wig', '188')]
# FILE STATUS
#      prod: [('archived', '62785'), ('released', '337559'), ('revoked', '24052')]
# LAB
#      prod: [('Alexander Urban, Stanford', '11'), ('Ali Mortazavi, UCI', '2262'), ('Andrew Z. Fire, Stanford', '8'), ('Anshul Kundaje, Stanford', '7802'), ('Barbara Wold, Caltech', '2781'), ('Bill Noble, UW', '3056'), ('Bing Ren, UCSD', '3434'), ('Bradley Bernstein, Broad', '6873'), ('Brenton Graveley, UConn', '10391'), ('Brian Oliver, NIH', '116'), ('Chris Burge, MIT', '1098'), ('Christina Leslie, MSKCC', '249'), ('David Gilbert, FSU', '350'), ('David MacAlpine, Duke', '10'), ('ENCODE Consortium', '1456'), ('ENCODE Consortium Analysis Working Group', '689'), ('ENCODE Processing Pipeline', '274085'), ('Erez Lieberman-Aiden, Baylor', '1'), ('Eric Lécuyer, IRCM', '120'), ('Ewan Birney, EBI', '2'), ('Gene Yeo, UCSD', '7322'), ('Gregory Crawford, Duke', '1106'), ('Guo-Cheng Yuan, Harvard', '23'), ('J. Michael Cherry, Stanford', '218'), ('Jason Lieb, UNC', '301'), ('Jennifer Harrow, Sanger', '12'), ('Job Dekker, UMass', '1655'), ('Joe Ecker, Salk', '1053'), ('John Rinn, Broad', '144'), ('John Stamatoyannopoulos, UW', '11157'), ('Joseph Costello, UCSF', '2101'), ('Kevin Struhl, HMS', '320'), ('Kevin White, UChicago', '43498'), ('Len Pennacchio, LBNL', '6'), ('Manolis Kellis, Broad', '10'), ('Manuel Garber, UMass', '283'), ('Mark Gerstein, Yale', '73'), ('Michael Beer, JHU', '26'), ('Michael Brent, WUSTL', '30'), ('Michael Snyder, Stanford', '10768'), ('Morgan Giddings, UNC', '40'), ('Peggy Farnham, USC', '758'), ('Piero Carninci, RIKEN', '663'), ('Richard Myers, HAIB', '6141'), ('Robert Waterston, UW', '11'), ('Roderic Guigo, CRG', '52'), ('Ross Hardison, PennState', '1283'), ('Scott Tenenbaum, SUNY-Albany', '152'), ('Sherman Weissman, Yale', '391'), ('Sunduz Keles, UW-M', '29'), ('Susan Celniker, LBNL', '534'), ('Thomas Gingeras, CSHL', '5635'), ('Thomas Tullius, BU', '2'), ('Tim Reddy, Duke', '4034'), ('Vishwanath Iyer, UTA', '535'), ('W. James Kent, UCSC', '34'), ('Wei Wang, UCSD', '7'), ('Will Greenleaf, Stanford', '2'), ('Xiang-Dong Fu, UCSD', '224'), ('Yijun Ruan, JAX', '436'), ('Zhiping Weng, UMass', '8533')]
# MAPPING ASSEMBLY
#      prod: [('GRCh38', '123627'), ('GRCh38-minimal', '7'), ('J02459.1', '2'), ('ce10', '10218'), ('ce11', '10881'), ('dm3', '10307'), ('dm6', '10652'), ('hg19', '162080'), ('mm10', '29449'), ('mm10-minimal', '14257'), ('mm9', '4137')]
# PLATFORM
#      prod: [('Affymetrix - Human Exon 1.0 ST V2 tilling array', '8'), ('Applied Biosystems SOLiD System 3 Plus', '292'), ('Illumina - Methylation 450K BeadChip', '126'), ('Illumina Genome Analyzer', '2388'), ('Illumina Genome Analyzer I', '329'), ('Illumina Genome Analyzer II', '2777'), ('Illumina Genome Analyzer IIe', '139'), ('Illumina Genome Analyzer IIx', '5477'), ('Illumina HiSeq 1000', '8'), ('Illumina HiSeq 2000', '22324'), ('Illumina HiSeq 2500', '8912'), ('Illumina HiSeq 4000', '4589'), ('Illumina HiSeq X Ten', '100'), ('Illumina Infinium Methylation EPIC BeadChip', '314'), ('Illumina Infinium Omni5Exome-4 Kit', '114'), ('Illumina MiSeq', '8'), ('Illumina NextSeq 500', '787'), ('Mouse 385K Whole Genome CGH Tiling Array', '29'), ('Mouse 3x720K Whole Genome CGH Tiling Array', '4'), ('Nimbelgen - Human 3x720K Whole Genome CGH Tiling Array', '136'), ('Nimblegen - Human 2.1M Whole-Genome CGH Tiling Array v2.0', '21'), ('Nimblegen - Human 6x630K CGH Whole Genome tiling array', '69'), ('Roche 454 Genome Sequencer FLX', '18'), ('nCounter Human V2 miRNA Expression array', '73'), ('nCounter Mouse V1.2 miRNA Expression array', '10'), ('nCounter Mouse V1.3 miRNA Expression array', '116'), ('nCounter Mouse V1.5 miRNA Expression array', '28')]
# PROJECT
#      prod: [('ENCODE', '357965'), ('GGR', '5010'), ('Roadmap', '14548'), ('community', '12'), ('modENCODE', '18385'), ('modERN', '28476')]
# SPECIFIC FILE FORMAT TYPE
#      prod: [('bed12', '106'), ('bed3', '52'), ('bed3+', '8377'), ('bed6', '6'), ('bed6+', '454'), ('bed9', '543'), ('bedExonScore', '120'), ('bedGraph', '78'), ('bedLogR', '176'), ('bedMethyl', '2067'), ('bedRnaElements', '834'), ('broadPeak', '16503'), ('candidate enhancer predictions', '90'), ('enhancer predictions', '77'), ('enhancerAssay', '4'), ('gappedPeak', '162'), ('gff3', '720'), ('idr_peak', '512'), ('modPepMap', '24'), ('narrowPeak', '113602'), ('openChromCombinedPeaks', '34'), ('pepMap', '24'), ('peptideMapping', '32'), ('shortFrags', '10'), ('tss_peak', '1428'), ('unknown', '25')]
#
# ----------------------------------- Library ------------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /search/?type=Library
# AUDIT CATEGORY
#      prod: [('missing donor', '3')]
# AUDIT CATEGORY2
#      prod: [('missing external identifiers', '484'), ('missing genotype', '173')]
# LIBRARY STATUS
#      prod: [('released', '27070'), ('revoked', '182')]
#
# --------------------------------- AntibodyLot ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /search/?type=AntibodyLot
# AUDIT CATEGORY
#      prod: [('inconsistent ontology term', '5')]
# AUDIT CATEGORY2
#      prod: [('need compliant primaries', '1465'), ('need compliant secondary', '87'), ('no characterizations submitted', '534'), ('no primary characterizations', '80'), ('no secondary characterizations', '1290')]
# CHARACTERIZATION METHOD
#      prod: [('ChIP-seq comparison', '166'), ('ChIP-string comparison', '26'), ('dot blot assay', '97'), ('immunoblot', '726'), ('immunofluorescence', '4'), ('immunoprecipitation', '1793'), ('immunoprecipitation followed by mass spectrometry', '335'), ('knockdown or knockout', '303'), ('motif enrichment', '79'), ('peptide ELISA assay', '3'), ('peptide competition assay', '1')]
# CLONALITY
#      prod: [('monoclonal', '653'), ('polyclonal', '2642')]
# ELIGIBILITY STATUS
#      prod: [('awaiting characterization', '1235'), ('characterized to standards', '562'), ('characterized to standards with exemption', '180'), ('not characterized to standards', '236'), ('not pursued', '1091'), ('partially characterized', '605')]
# HOST ORGANISM
#      prod: [('chicken', '1'), ('goat', '81'), ('guineapig', '9'), ('mouse', '556'), ('rabbit', '2677'), ('rat', '14'), ('savidinii', '1'), ('sheep', '1')]
# LAB
#      prod: [('Abby Dernburg, Berkeley', '1'), ('Bing Ren, UCSD', '24'), ('Bradley Bernstein, Broad', '179'), ('Brenton Graveley, UConn', '261'), ('Gary Karpen, LBNL', '5'), ('Gene Yeo, UCSD', '717'), ('Gregory Crawford, Duke', '1'), ('J. Michael Cherry, Stanford', '4'), ('Jason Lieb, UNC', '6'), ('John Stamatoyannopoulos, UW', '1'), ('Julie Ahringer, Cambridge', '9'), ('Kevin White, UChicago', '4'), ('Michael Snyder, Stanford', '1044'), ('Peggy Farnham, USC', '4'), ('Richard Myers, HAIB', '219'), ('Ross Hardison, PennState', '16'), ('Sarah Elgin, WashU', '4'), ('Scott Tenenbaum, SUNY-Albany', '7'), ('Susan Strome, UCSC', '18'), ('Vincenzo Pirrotta, Rutgers', '1'), ('Xiang-Dong Fu, UCSD', '102'), ('Yijun Ruan, JAX', '3')]
# SOURCE
#      prod: [('ABclonal', '5'), ('Abcam', '255'), ('Abnova', '3'), ('Active Motif', '195'), ('Andrew Dingwall', '3'), ('Anthony Hyman', '1'), ('Anthony Schwacha', '1'), ('Arno Greenleaf', '1'), ('Arshad Desai', '2'), ('Assay Biotech', '28'), ('Aviva', '68'), ('Axxora', '1'), ('BD Biosciences', '6'), ('Bethyl Labs', '725'), ('BioLegend', '3'), ('Bioss', '30'), ('CDI', '112'), ('Callaini Guiliano', '1'), ('Carl Wu', '1'), ('Cayman', '1'), ('Cell Signaling', '75'), ('Claude Desplan', '2'), ('Covance', '14'), ('David Anderson', '1'), ('Diagenode', '23'), ('Dmitry Fyodorov', '1'), ('Donna Arndt-Jovin', '1'), ('Emery Bresnick', '2'), ('Epitomics', '1'), ('Eric Lai', '1'), ('Erika Bach', '2'), ('Eurogentec', '4'), ('Everest Biotech', '25'), ('Florence Maschat', '2'), ('Francesca Palladino', '1'), ('Francis Stewart', '2'), ('GeneTex', '419'), ('Giacomo Cavalli', '1'), ('Harald Saumweber', '2'), ('Haruhiko Siomi', '1'), ('Hiroshi Kimura', '6'), ('Huabing Li and Vincenzo Pirrotta', '1'), ('Hugo Bellen', '1'), ('Invitrogen', '1'), ('James Engel', '1'), ('James Kadonaga', '2'), ('Jan Larsson', '1'), ('Jean-Antoine Lepseant', '1'), ('Jianhong Wu and Tao Shi Hsieh', '1'), ('John Reinitz', '1'), ('Julie Ahringer', '2'), ('Karen Schulze and Hugo Bellen', '1'), ('Ken Cadigan', '1'), ('Kenneth Irvine', '1'), ('Kevin White', '35'), ('Kirsten Hagstrom', '1'), ('Kyoko Yokomori', '1'), ('LSBio', '4'), ('Lake Placid Biologicals', '8'), ('Laszlo Tora', '3'), ('MBLI', '113'), ('Marek Bartkuhn', '1'), ('Mattias Mannervik', '3'), ('Max Reuter', '1'), ('Medimabs', '1'), ('Millipore', '113'), ('Novus', '22'), ('Nuria Paricio', '1'), ('Origene', '29'), ('Pacific Immunology', '2'), ('Pamela Geyer', '1'), ('Paul Schedl, Jason Blanton and Greg Shanowe', '1'), ('Paul Yaswen', '1'), ('Peggy Farnham', '1'), ('Proteintech', '6'), ('RAN', '1'), ('RD Systems', '1'), ('Rainer Renkawitz', '2'), ('ReproCELL', '1'), ('Richard Mann', '1'), ('Robert Horvitz', '5'), ('Robert White', '5'), ('Roberto Mantovani', '2'), ('Roche', '1'), ('Rockland', '16'), ('SDIX, LLC', '109'), ('Santa Cruz Biotech', '281'), ('Sarah Elgin', '4'), ('Scott Hawley', '1'), ('Sigma', '426'), ('Stephen Bell', '1'), ('Stephen Crews', '2'), ('Stephen Smale', '1'), ('Steven Henikoff', '2'), ('Susan Strome', '1'), ('Thermo Fisher', '41'), ('Thomas Jenuwein', '2'), ('Tirtha Das and Ross Cagan', '1'), ('Tom Williams and Sean Carroll', '2'), ('Ulrich Laemmli', '1'), ('Unknown Source', '3'), ('Victor Corces', '6'), ('Victor Lobanenkov', '1'), ('Vincenzo Pirrotta', '8'), ('Wako Chemicals', '7'), ('William Kelly', '1'), ('Yang Shi', '2'), ('Zen Bioscience', '11')]
# TARGET ORGANISM
#      prod: [('Aequorea victoria', '8'), ('Caenorhabditis elegans', '143'), ('Drosophila melanogaster', '231'), ('Homo sapiens', '2920'), ('Mus musculus', '123'), ('influenzavirus', '3'), ('synthetic', '3')]
# TARGET OF ANTIBODY
#      prod: [('RNA binding protein', '1039'), ('broad histone mark', '144'), ('chromatin remodeller', '136'), ('control', '13'), ('histone', '334'), ('narrow histone mark', '105'), ('nucleotide modification', '6'), ('other context', '5'), ('other post-translational modification', '6'), ('recombinant protein', '1'), ('tag', '14'), ('transcription factor', '2190')]
#
# ---------------------------------- Biosample -----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /search/?type=Biosample
# AUDIT CATEGORY
#      prod: [('missing donor', '4')]
# AUDIT CATEGORY2
#      prod: [('missing external identifiers', '424'), ('missing genetic modification characterization', '3637'), ('missing genotype', '186')]
# BIOSAMPLE STATUS
#      prod: [('released', '12913'), ('revoked', '24')]
# BIOSAMPLE TREATMENT
#      prod: [('17β-estradiol', '17'), ('17β-hydroxy-17-methylestra-4,9,11-trien-3-one', '1'), ('17β-hydroxy-5α-androstan-3-one', '4'), ('20-hydroxyecdysone', '16'), ('Diphtheria Toxin', '10'), ('LCMV', '4'), ('Lipopolysaccharide', '56'), ('Sendai virus', '2'), ('Sindbis virus', '8'), ('Tamoxifen', '15'), ('Transforming growth factor beta-1', '1'), ('UT189', '1'), ('activated CD4-positive, alpha-beta T cell', '1'), ('activated regulatory T-cells', '2'), ('afimoxifene', '10'), ('all-trans-retinoic acid', '8'), ('bisphenol A', '5'), ('bone marrow hematopoietic cell', '2'), ('cadmium dichloride', '8'), ('caffeine', '6'), ('calcium', '24'), ('cisplatin', '1'), ('cold shock treatment', '4'), ('copper(II) sulfate', '72'), ('dexamethasone', '786'), ('differentiation', '1'), ('dimethyl sulfoxide', '14'), ('doxycycline', '1'), ('doxycycline hyclate', '6'), ('effector memory CD4-positive, alpha-beta T cell', '1'), ('erythropoietin', '18'), ('estradiol', '13'), ('ethanol', '16'), ('forskolin and pyruvate', '1'), ('genistein', '5'), ('heat shock treatment', '2'), ('hydrocortisone succinate', '18'), ('hydroxyurea', '1'), ('inflammation-experienced regulatory T-cells', '1'), ('insulin and 22-hydroxycholesterol', '1'), ('interferon alpha', '3'), ('interferon gamma', '4'), ('interleukin-3', '18'), ('ionomycin', '4'), ('irradiation', '2'), ('kit ligand', '18'), ('lactate', '2'), ('methyltrienolone', '2'), ('paraquat', '4'), ('phorbol 13-acetate 12-myristate', '4'), ('pravastatin', '1'), ('regulatory T cell', '1'), ('resveratrol', '2'), ('retinoic acid', '2'), ('rotenone', '6'), ('serum free', '1'), ('sodium butyrate', '1'), ('tamoxifen', '2'), ('tumor necrosis factor', '10'), ('vorinostat', '1'), ('zinc dichloride', '6')]
# BIOSAMPLE TYPE
#      prod: [('cell line', '5449'), ('in vitro differentiated cells', '311'), ('induced pluripotent stem cell line', '55'), ('primary cell', '1045'), ('stem cell', '301'), ('tissue', '2757'), ('whole organisms', '3019')]
# CELL CYCLE PHASE
#      prod: [('G1', '6'), ('G1b', '21'), ('G2', '20'), ('S1', '18'), ('S2', '16'), ('S3', '16'), ('S4', '16'), ('early S', '7'), ('late S', '7')]
# HAS NIH INSTITUTIONAL CERTIFICATION
#      prod: [('no', '12937')]
# LAB
# ...
# PUBLISHED BY
#      prod: [('ENCODE', '971'), ('community', '1949'), ('historical reference', '101'), ('modENCODE', '176'), ('mouseENCODE', '42')]
#
# ----------------------------------- Software -----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /search/?type=Software
# CREATED BY
#      prod: [('ENCODE', '39'), ('community', '21'), ('historical reference', '4'), ('modENCODE', '3'), ('mouseENCODE', '1')]
# PURPOSE IN PROJECT
#      prod: [('ChIP-seq', '14'), ('DNase-seq', '23'), ('HiC', '1'), ('RNA-seq', '37'), ('community resource', '16'), ('data QC', '8'), ('integrative analysis', '7'), ('variant analysis', '8')]
# SOFTWARE TYPE
#      prod: [('aligner', '14'), ('database', '7'), ('file format conversion', '14'), ('filtering', '9'), ('genome segmentation', '4'), ('other', '19'), ('peak caller', '13'), ('quality metric', '17'), ('transcript identification', '5'), ('transcriptome assembly', '1'), ('variant annotation', '8')]
#
# ---------------------------------- Experiment ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /matrix/?type=Experiment
# ASSAY
#      prod: [("5' RLM RACE", '2'), ('5C', '13'), ('ATAC-seq', '180'), ('CAGE', '121'), ('CRISPR RNA-seq', '50'), ('CRISPRi RNA-seq', '77'), ('ChIA-PET', '62'), ('ChIP-seq', '8911'), ('Circulome-seq', '1'), ('DNA-PET', '6'), ('DNAme array', '259'), ('DNase-seq', '873'), ('FAIRE-seq', '37'), ('Hi-C', '36'), ('MNase-seq', '2'), ('MRE-seq', '68'), ('MS-MS', '14'), ('MeDIP-seq', '55'), ('PAS-seq', '47'), ('RAMPAGE', '168'), ('RIP-chip', '32'), ('RIP-seq', '73'), ('RNA Bind-n-Seq', '161'), ('RNA microarray', '291'), ('RNA-PET', '31'), ('RRBS', '218'), ('Repli-chip', '63'), ('Repli-seq', '119'), ('Switchgear', '2'), ('TAB-seq', '8'), ('WGBS', '258'), ('eCLIP', '359'), ('genetic modification DNase-seq', '40'), ('genotyping HTS', '16'), ('genotyping array', '142'), ('iCLIP', '7'), ('microRNA counts', '115'), ('microRNA-seq', '185'), ('polyA RNA-seq', '817'), ('polyA depleted RNA-seq', '32'), ('shRNA RNA-seq', '533'), ('siRNA RNA-seq', '113'), ('single cell RNA-seq', '120'), ('small RNA-seq', '216'), ('total RNA-seq', '413'), ('whole genome sequencing assay', '21')]
# ASSAY CATEGORY
#      prod: [('3D chromatin structure', '111'), ('DNA accessibility', '1132'), ('DNA binding', '8911'), ('DNA methylation', '866'), ('DNA sequencing', '22'), ('Genotyping', '164'), ('Proteomics', '14'), ('RNA binding', '634'), ('Replication timing', '182'), ('Transcription', '3331')]
# AUDIT CATEGORY
#      prod: [('control extremely low read depth', '24'), ('extremely low coverage', '7'), ('extremely low read depth', '221'), ('extremely low read length', '10'), ('extremely low spot score', '49'), ('inconsistent control', '3'), ('inconsistent library biosample', '1'), ('inconsistent read count', '2'), ('missing antibody', '75'), ('missing control alignments', '418'), ('missing donor', '1'), ('missing nih_institutional_certification', '33'), ('missing possible_controls', '2')]
# AUDIT CATEGORY2
#      prod: [('antibody not characterized to standard', '25'), ('control insufficient read depth', '952'), ('insufficient coverage', '4'), ('insufficient read depth', '1757'), ('insufficient read length', '511'), ('insufficient replicate concordance', '48'), ('missing RNA fragment size', '2'), ('missing controlled_by', '596'), ('missing documents', '30'), ('missing input control', '2'), ('missing possible_controls', '27'), ('missing spikeins', '173'), ('partially characterized antibody', '139'), ('poor library complexity', '283'), ('severe bottlenecking', '271'), ('uncharacterized antibody', '11'), ('unreplicated experiment', '341')]
# AUDIT CATEGORY3
#      prod: [('antibody characterized with exemption', '676'), ('borderline replicate concordance', '455'), ('control low read depth', '659'), ('file validation error', '40'), ('high lambda C methylation ratio', '3'), ('inconsistent assembly', '18'), ('inconsistent control read length', '907'), ('inconsistent control run_type', '158'), ('inconsistent platforms', '1032'), ('inconsistent target of control experiment', '217'), ('low coverage', '4'), ('low read depth', '2545'), ('low read length', '3292'), ('low replicate concordance', '89'), ('low spot score', '321'), ('mild to moderate bottlenecking', '2873'), ('missing external identifiers', '330'), ('missing genetic modification characterization', '2307'), ('missing genotype', '116'), ('missing spikeins', '28'), ('mixed read lengths', '482'), ('mixed run types', '101'), ('moderate library complexity', '1280')]
# AVAILABLE DATA
#      prod: [('CEL', '4'), ('bam', '12757'), ('bed bed12', '43'), ('bed bed3', '7'), ('bed bed3+', '869'), ('bed bed6+', '115'), ('bed bed9', '18'), ('bed bedExonScore', '27'), ('bed bedGraph', '30'), ('bed bedLogR', '64'), ('bed bedMethyl', '278'), ('bed bedRnaElements', '288'), ('bed broadPeak', '2451'), ('bed idr_peak', '134'), ('bed modPepMap', '6'), ('bed narrowPeak', '7324'), ('bed pepMap', '6'), ('bed peptideMapping', '8'), ('bed tss_peak', '235'), ('bedpe', '5'), ('bigBed bed12', '43'), ('bigBed bed3', '7'), ('bigBed bed3+', '13'), ('bigBed bed6+', '115'), ('bigBed bed9', '18'), ('bigBed bedExonScore', '27'), ('bigBed bedLogR', '63'), ('bigBed bedMethyl', '278'), ('bigBed bedRnaElements', '288'), ('bigBed broadPeak', '1992'), ('bigBed idr_peak', '134'), ('bigBed modPepMap', '6'), ('bigBed narrowPeak', '7313'), ('bigBed pepMap', '6'), ('bigBed peptideMapping', '8'), ('bigBed tss_peak', '235'), ('bigWig', '11714'), ('csfasta', '25'), ('csqual', '13'), ('fasta', '3'), ('fastq', '13745'), ('gff gff3', '235'), ('gtf', '269'), ('hdf5', '20'), ('hic', '5'), ('idat', '277'), ('rcc', '115'), ('sam', '59'), ('sra', '672'), ('tagAlign', '1368'), ('tar', '110'), ('tsv', '2470'), ('vcf', '13'), ('wig', '59')]
# BIOSAMPLE TYPE
#      prod: [('cell line', '5779'), ('cell-free sample', '161'), ('in vitro differentiated cells', '679'), ('induced pluripotent stem cell line', '137'), ('primary cell', '1678'), ('stem cell', '506'), ('tissue', '4375'), ('whole organisms', '2052')]
# DATE RELEASED
#      prod: [('April, 2011', '149'), ('April, 2012', '77'), ('April, 2013', '6'), ('April, 2014', '2'), ('April, 2015', '28'), ('April, 2016', '170'), ('April, 2017', '52'), ('April, 2018', '48'), ('August, 2011', '88'), ('August, 2012', '257'), ('August, 2015', '180'), ('August, 2016', '265'), ('August, 2017', '71'), ('December, 2010', '68'), ('December, 2011', '87'), ('December, 2014', '247'), ('December, 2015', '40'), ('December, 2016', '174'), ('December, 2017', '139'), ('February, 2011', '255'), ('February, 2012', '264'), ('February, 2013', '1'), ('February, 2014', '7'), ('February, 2015', '3'), ('February, 2016', '183'), ('February, 2017', '138'), ('February, 2018', '177'), ('January, 2011', '6'), ('January, 2012', '59'), ('January, 2015', '8'), ('January, 2016', '110'), ('January, 2017', '399'), ('January, 2018', '156'), ('July, 2009', '22'), ('July, 2011', '263'), ('July, 2012', '128'), ('July, 2013', '2761'), ('July, 2014', '300'), ('July, 2015', '103'), ('July, 2016', '614'), ('July, 2017', '39'), ('June, 2011', '83'), ('June, 2012', '75'), ('June, 2014', '432'), ('June, 2015', '106'), ('June, 2016', '221'), ('June, 2017', '272'), ('March, 2011', '160'), ('March, 2012', '170'), ('March, 2013', '1'), ('March, 2014', '887'), ('March, 2015', '2'), ('March, 2016', '291'), ('March, 2017', '96'), ('March, 2018', '134'), ('May, 2011', '35'), ('May, 2012', '138'), ('May, 2013', '2'), ('May, 2014', '8'), ('May, 2015', '12'), ('May, 2016', '569'), ('May, 2017', '66'), ('May, 2018', '15'), ('November, 2010', '9'), ('November, 2011', '76'), ('November, 2012', '7'), ('November, 2014', '98'), ('November, 2015', '225'), ('November, 2016', '400'), ('November, 2017', '428'), ('October, 2009', '4'), ('October, 2010', '1'), ('October, 2011', '456'), ('October, 2014', '86'), ('October, 2015', '106'), ('October, 2016', '485'), ('October, 2017', '200'), ('September, 2011', '134'), ('September, 2012', '190'), ('September, 2014', '41'), ('September, 2015', '17'), ('September, 2016', '209'), ('September, 2017', '115')]
# GENOME ASSEMBLY (VISUALIZATION)
#      prod: [('GRCh38', '7315'), ('ce10', '838'), ('ce11', '897'), ('dm3', '835'), ('dm6', '811'), ('hg19', '7492'), ('mm10', '1508'), ('mm9', '338')]
# LAB
#      prod: [('Alexander Urban, Stanford', '3'), ('Ali Mortazavi, UCI', '231'), ('Andrew Z. Fire, Stanford', '4'), ('Barbara Wold, Caltech', '287'), ('Bing Ren, UCSD', '1379'), ('Bradley Bernstein, Broad', '1957'), ('Brenton Graveley, UConn', '789'), ('Brian Oliver, NIH', '27'), ('Chris Burge, MIT', '161'), ('Christina Leslie, MSKCC', '32'), ('David Gilbert, FSU', '77'), ('David MacAlpine, Duke', '39'), ('Eric Lécuyer, IRCM', '30'), ('Gene Yeo, UCSD', '366'), ('Gregory Crawford, Duke', '162'), ('Jason Lieb, UNC', '37'), ('Job Dekker, UMass', '26'), ('Joe Ecker, Salk', '193'), ('John Rinn, Broad', '35'), ('John Stamatoyannopoulos, UW', '1594'), ('Joseph Costello, UCSF', '595'), ('Kevin Struhl, HMS', '43'), ('Kevin White, UChicago', '1064'), ('Manuel Garber, UMass', '68'), ('Michael Snyder, Stanford', '2401'), ('Morgan Giddings, UNC', '14'), ('Paul Khavari, Stanford', '13'), ('Peggy Farnham, USC', '125'), ('Piero Carninci, RIKEN', '78'), ('Richard Myers, HAIB', '1423'), ('Ross Hardison, PennState', '128'), ('Scott Tenenbaum, SUNY-Albany', '42'), ('Sherman Weissman, Yale', '65'), ('Susan Celniker, LBNL', '239'), ('Terry Orr-Weaver, MIT', '2'), ('Thomas Gingeras, CSHL', '736'), ('Tim Reddy, Duke', '298'), ('Valerie Reinke, Yale', '361'), ('Vishwanath Iyer, UTA', '85'), ('Will Greenleaf, Stanford', '13'), ('Xiang-Dong Fu, UCSD', '97'), ('Yijun Ruan, JAX', '48')]
# ORGAN
#      prod: [('adipose tissue', '137'), ('adrenal gland', '105'), ('artery', '42'), ('blood', '2614'), ('blood vessel', '208'), ('bodily fluid', '2614'), ('bone element', '117'), ('bone marrow', '38'), ('brain', '937'), ('breast', '49'), ('bronchus', '20'), ('connective tissue', '571'), ('embryo', '984'), ('epithelium', '723'), ('esophagus', '117'), ('extraembryonic component', '203'), ('eye', '36'), ('gonad', '130'), ('heart', '340'), ('intestine', '559'), ('kidney', '571'), ('large intestine', '359'), ('limb', '356'), ('liver', '1184'), ('lung', '927'), ('lymph node', '169'), ('lymphatic vessel', '6'), ('lymphoid tissue', '41'), ('mammary gland', '427'), ('mouth', '25'), ('musculature of body', '553'), ('nerve', '39'), ('nose', '2'), ('ovary', '55'), ('pancreas', '146'), ('penis', '212'), ('pericardium', '4'), ('placenta', '65'), ('prostate gland', '118'), ('skeleton', '5'), ('skin of body', '565'), ('small intestine', '107'), ('spinal cord', '28'), ('spleen', '195'), ('stomach', '250'), ('testis', '69'), ('thymus', '53'), ('thyroid gland', '60'), ('tongue', '5'), ('trachea', '3'), ('ureter', '31'), ('urinary bladder', '21'), ('uterus', '230'), ('vagina', '29'), ('vasculature', '231'), ('vein', '69')]
# ORGANISM
#      prod: [('Caenorhabditis elegans', '975'), ('Drosophila ananassae', '1'), ('Drosophila melanogaster', '1435'), ('Drosophila mojavensis', '4'), ('Drosophila pseudoobscura', '12'), ('Drosophila simulans', '8'), ('Drosophila virilis', '1'), ('Drosophila yakuba', '1'), ('Homo sapiens', '10891'), ('Mus musculus', '1864')]
# PROJECT
#      prod: [('ENCODE', '9701'), ('GGR', '461'), ('Roadmap', '2761'), ('community', '7'), ('modENCODE', '1330'), ('modERN', '1107')]
# TARGET OF ASSAY
#      prod: [('RNA binding protein', '1466'), ('broad histone mark', '1727'), ('chromatin remodeller', '254'), ('control', '2568'), ('histone', '3102'), ('narrow histone mark', '1265'), ('nucleotide modification', '70'), ('other context', '58'), ('other post-translational modification', '76'), ('recombinant protein', '1271'), ('tag', '1'), ('transcription factor', '3971')]
#
# ---------------------------------- Annotation ----------------------------------
# Comparing data between URLs.
# As user: Public
# Browser: Chrome
# First URL: https://www.encodeproject.org
# Second URL: https://v71rc1-master.demo.encodedcc.org/
# Item type: /matrix/?type=Annotation
# ANNOTATION TYPE
#      prod: [('binding sites', '2'), ('blacklist', '3'), ('candidate regulatory elements', '2178'), ('chromatin state', '330'), ('enhancer predictions', '111'), ('gene expression', '14'), ('other', '3048'), ('overlap', '17'), ('representative DNase hypersensitivity sites', '6'), ('transcript expression', '14'), ('validated enhancers', '6')]
# AUDIT CATEGORY
#      prod: [('inconsistent assembly', '28')]
# AVAILABLE DATA
#      prod: [('bam', '3'), ('bed bed3', '4'), ('bed bed3+', '2164'), ('bed bed6', '2'), ('bed bed9', '91'), ('bed candidate enhancer predictions', '46'), ('bed enhancer predictions', '50'), ('bed enhancerAssay', '2'), ('bed narrowPeak', '2'), ('bed openChromCombinedPeaks', '17'), ('bigBed bed3+', '2154'), ('bigBed bed6', '2'), ('bigBed bed9', '218'), ('bigBed broadPeak', '1'), ('bigBed enhancerAssay', '2'), ('bigBed openChromCombinedPeaks', '17'), ('bigBed unknown', '9'), ('bigWig', '3049'), ('fasta', '1'), ('fastq', '20'), ('tsv', '39')]
# BIOSAMPLE TYPE
#      prod: [('cell line', '393'), ('in vitro differentiated cells', '124'), ('induced pluripotent stem cell line', '44'), ('primary cell', '603'), ('stem cell', '101'), ('tissue', '1362'), ('whole organisms', '6')]
# DATE RELEASED
#      prod: [('April, 2014', '3'), ('April, 2017', '3'), ('April, 2018', '3048'), ('August, 2015', '92'), ('August, 2016', '452'), ('August, 2017', '779'), ('December, 2011', '1'), ('February, 2012', '10'), ('February, 2015', '2'), ('July, 2013', '225'), ('July, 2016', '3'), ('June, 2011', '16'), ('June, 2015', '2'), ('June, 2016', '276'), ('March, 2014', '9'), ('March, 2016', '1'), ('November, 2016', '17'), ('October, 2011', '2'), ('October, 2015', '10'), ('September, 2012', '2'), ('September, 2014', '22'), ('September, 2015', '2'), ('September, 2017', '758')]
# ENCYCLOPEDIA VERSION
#      prod: [('1', '3'), ('2', '141'), ('3', '847'), ('4', '4587'), ('Blacklists', '2'), ('ENCODE2', '27'), ('ROADMAP', '127')]
# GENOME ASSEMBLY (VISUALIZATION)
#      prod: [('hg19', '4166'), ('mm10', '455'), ('mm9', '17')]
# ORGAN
#      prod: [('adipose tissue', '9'), ('adrenal gland', '21'), ('artery', '10'), ('blood', '228'), ('blood vessel', '52'), ('bodily fluid', '228'), ('bone element', '33'), ('bone marrow', '15'), ('brain', '331'), ('breast', '1'), ('bronchus', '8'), ('connective tissue', '200'), ('embryo', '217'), ('epithelium', '174'), ('esophagus', '17'), ('extraembryonic component', '52'), ('eye', '30'), ('gonad', '26'), ('heart', '109'), ('intestine', '156'), ('kidney', '123'), ('large intestine', '90'), ('limb', '108'), ('liver', '89'), ('lung', '162'), ('lymph node', '50'), ('lymphatic vessel', '2'), ('lymphoid tissue', '2'), ('mammary gland', '44'), ('mouth', '17'), ('musculature of body', '155'), ('ovary', '12'), ('pancreas', '33'), ('penis', '54'), ('placenta', '27'), ('prostate gland', '15'), ('skin of body', '129'), ('small intestine', '41'), ('spinal cord', '15'), ('spleen', '29'), ('stomach', '70'), ('testis', '13'), ('thymus', '34'), ('thyroid gland', '8'), ('tongue', '4'), ('ureter', '14'), ('urinary bladder', '2'), ('uterus', '22'), ('vagina', '3'), ('vasculature', '64'), ('vein', '15')]
# ORGANISM
#      prod: [('Homo sapiens', '4951'), ('Mus musculus', '784')]
# PROJECT
#      prod: [('ENCODE', '5510'), ('Roadmap', '225')]
# TARGET(S) OF ASSAY
#      prod: [('CTCF', '235'), ('H3K27ac', '684'), ('H3K4me1', '1'), ('H3K4me3', '860'), ('H3K9ac', '1')]

# %%
#qa.compare_facets(users=['encoded.test4@gmail.com'], browsers=['Chrome'], item_types=['/search/?type=Experiment'], browser_comparison=False)

# %%
#.find_differences(users=['encoded.test4@gmail.com'], browsers=['Safari'])

# %%
#qa.find_differences(users=['encoded.test4@gmail.com'], browsers=['Chrome'], item_types=['/experiments/ENCSR524OCB/'])

# %%
#qa.show_differences()

# %%
#qa.check_downloads(browsers=['Safari'], users=['Public'])

# %%
#qa.check_trackhubs(browsers=['Safari'], users=['Public'])

# %%
#qa.check_permissions(browsers=['Chrome'], users=['Public'])

# %%
#qa.check_permissions(browsers=['Chrome'], users=['encoded.test@gmail.com'])

# %%
#qa.check_permissions(browsers=['Chrome'], users=['encoded.test2@gmail.com'])

# %%
#qa.check_permissions(browsers=['Chrome'], users=['encoded.test4@gmail.com'])

# %%
#qa.check_requests()

# %%
#qa.check_tools()
