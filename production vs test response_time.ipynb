# %%
import qancode

# %%
qa = qancode.QANCODE(rc_url="https://test.encodedcc.org/")

# %%
#home page and search page
qa.check_response_time(item_types=["/","/search/?type=Experiment"], n=100)
# Out:
# Checking response time
#
# *** item_type: /
# ------------------------ https://www.encodeproject.org/ ------------------------
# Average es_time: 6.911 ± 1.197 ms (n=100)
# Average queue_time: 1.033 ± 0.663 ms (n=100)
# Average render_time: 8.719 ± 2.723 ms (n=100)
# Average wsgi_time: 25.4 ± 4.352 ms (n=100)
# Average total time: 42.063 ± 6.958 ms (n=100)
# ------------------------- https://test.encodedcc.org// -------------------------
# Average es_time: 10.877 ± 2.086 ms (n=100)
# Average queue_time: 0.96 ± 0.323 ms (n=100)
# Average render_time: 9.165 ± 2.812 ms (n=100)
# Average wsgi_time: 36.294 ± 69.093 ms (n=100)
# Average total time: 57.296 ± 68.994 ms (n=100)
#
#
# *** item_type: /search/?type=Experiment
# ------------ https://www.encodeproject.org/search/?type=Experiment -------------
# Average es_time: 115.562 ± 23.858 ms (n=100)
# Average queue_time: 1.402 ± 1.065 ms (n=100)
# Average render_time: 140.389 ± 14.646 ms (n=100)
# Average wsgi_time: 285.785 ± 27.807 ms (n=100)
# Average total time: 543.138 ± 55.329 ms (n=100)
# ------------- https://test.encodedcc.org//search/?type=Experiment --------------
# Average es_time: 99.151 ± 24.262 ms (n=100)
# Average queue_time: 1.065 ± 0.417 ms (n=100)
# Average render_time: 129.002 ± 13.281 ms (n=100)
# Average wsgi_time: 251.447 ± 28.403 ms (n=100)
# Average total time: 480.664 ± 56.16 ms (n=100)

# %%
#search terms
qa.check_response_time(item_types=["/search/?searchTerm=K562", "/search/?searchTerm=DNA+binding", "/search/?searchTerm=human", "/search/?searchTerm=H3K36me3", "/search/?searchTerm=CTCF"], n=100)
# Out:
# Checking response time
#
# *** item_type: /search/?searchTerm=K562
# ------------ https://www.encodeproject.org/search/?searchTerm=K562 -------------
# Average es_time: 272.246 ± 33.295 ms (n=100)
# Average queue_time: 1.703 ± 1.335 ms (n=100)
# Average render_time: 30.948 ± 6.69 ms (n=100)
# Average wsgi_time: 322.878 ± 33.364 ms (n=100)
# Average total time: 627.775 ± 66.959 ms (n=100)
# ------------- https://test.encodedcc.org//search/?searchTerm=K562 --------------
# Average es_time: 268.854 ± 31.349 ms (n=100)
# Average queue_time: 1.413 ± 0.715 ms (n=100)
# Average render_time: 32.271 ± 8.382 ms (n=100)
# Average wsgi_time: 317.856 ± 33.261 ms (n=100)
# Average total time: 620.394 ± 66.193 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=DNA+binding
# --------- https://www.encodeproject.org/search/?searchTerm=DNA+binding ---------
# Average es_time: 432.141 ± 43.81 ms (n=100)
# Average queue_time: 1.771 ± 1.34 ms (n=100)
# Average render_time: 29.0 ± 5.764 ms (n=100)
# Average wsgi_time: 483.484 ± 44.837 ms (n=100)
# Average total time: 946.395 ± 89.51 ms (n=100)
# ---------- https://test.encodedcc.org//search/?searchTerm=DNA+binding ----------
# Average es_time: 441.815 ± 45.716 ms (n=100)
# Average queue_time: 1.68 ± 0.847 ms (n=100)
# Average render_time: 31.812 ± 7.629 ms (n=100)
# Average wsgi_time: 493.924 ± 46.311 ms (n=100)
# Average total time: 969.231 ± 92.248 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=human
# ------------ https://www.encodeproject.org/search/?searchTerm=human ------------
# Average es_time: 284.886 ± 37.785 ms (n=100)
# Average queue_time: 1.702 ± 1.388 ms (n=100)
# Average render_time: 30.806 ± 6.876 ms (n=100)
# Average wsgi_time: 332.708 ± 39.4 ms (n=100)
# Average total time: 650.101 ± 78.347 ms (n=100)
# ------------- https://test.encodedcc.org//search/?searchTerm=human -------------
# Average es_time: 304.673 ± 55.409 ms (n=100)
# Average queue_time: 1.42 ± 0.848 ms (n=100)
# Average render_time: 37.041 ± 10.229 ms (n=100)
# Average wsgi_time: 356.886 ± 58.243 ms (n=100)
# Average total time: 700.02 ± 116.67 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=H3K36me3
# ---------- https://www.encodeproject.org/search/?searchTerm=H3K36me3 -----------
# Average es_time: 510.897 ± 52.152 ms (n=100)
# Average queue_time: 1.679 ± 1.106 ms (n=100)
# Average render_time: 123.121 ± 8.841 ms (n=100)
# Average wsgi_time: 724.452 ± 111.301 ms (n=100)
# Average total time: 1360.15 ± 140.515 ms (n=100)
# ----------- https://test.encodedcc.org//search/?searchTerm=H3K36me3 ------------
# Average es_time: 471.206 ± 33.622 ms (n=100)
# Average queue_time: 1.488 ± 0.692 ms (n=100)
# Average render_time: 125.091 ± 9.719 ms (n=100)
# Average wsgi_time: 666.52 ± 36.063 ms (n=100)
# Average total time: 1264.304 ± 71.291 ms (n=100)
#
#
# *** item_type: /search/?searchTerm=CTCF
# ------------ https://www.encodeproject.org/search/?searchTerm=CTCF -------------
# Average es_time: 303.91 ± 37.516 ms (n=100)
# Average queue_time: 2.0 ± 1.609 ms (n=100)
# Average render_time: 36.88 ± 6.585 ms (n=100)
# Average wsgi_time: 362.431 ± 38.69 ms (n=100)
# Average total time: 705.22 ± 77.459 ms (n=100)
# ------------- https://test.encodedcc.org//search/?searchTerm=CTCF --------------
# Average es_time: 294.482 ± 41.657 ms (n=100)
# Average queue_time: 1.749 ± 1.066 ms (n=100)
# Average render_time: 40.144 ± 9.831 ms (n=100)
# Average wsgi_time: 354.209 ± 42.395 ms (n=100)
# Average total time: 690.585 ± 85.094 ms (n=100)

# %%
#first set of datasets
qa.check_response_time(item_types=['/ENCSR255XZG/', '/ENCSR749ILN/', '/ENCSR688GVV/', '/ENCSR301HAG/','/ENCSR315NAC/', '/ENCSR856JJB/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR255XZG/
# ------------------ https://www.encodeproject.org/ENCSR255XZG/ ------------------
# Average es_time: 15.02 ± 1.777 ms (n=100)
# Average queue_time: 1.347 ± 1.205 ms (n=100)
# Average render_time: 125.8 ± 9.345 ms (n=100)
# Average wsgi_time: 273.75 ± 183.647 ms (n=100)
# Average total time: 415.916 ± 184.757 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR255XZG/ -------------------
# Average es_time: 23.248 ± 1.885 ms (n=100)
# Average queue_time: 1.82 ± 2.206 ms (n=100)
# Average render_time: 126.072 ± 10.444 ms (n=100)
# Average wsgi_time: 278.254 ± 169.042 ms (n=100)
# Average total time: 429.394 ± 171.351 ms (n=100)
#
#
# *** item_type: /ENCSR749ILN/
# ------------------ https://www.encodeproject.org/ENCSR749ILN/ ------------------
# Average es_time: 8.565 ± 1.441 ms (n=100)
# Average queue_time: 1.256 ± 0.773 ms (n=100)
# Average render_time: 32.055 ± 5.657 ms (n=100)
# Average wsgi_time: 64.769 ± 6.558 ms (n=100)
# Average total time: 106.645 ± 11.858 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR749ILN/ -------------------
# Average es_time: 15.718 ± 2.121 ms (n=100)
# Average queue_time: 1.397 ± 1.319 ms (n=100)
# Average render_time: 35.199 ± 9.287 ms (n=100)
# Average wsgi_time: 75.194 ± 10.323 ms (n=100)
# Average total time: 127.509 ± 19.75 ms (n=100)
#
#
# *** item_type: /ENCSR688GVV/
# ------------------ https://www.encodeproject.org/ENCSR688GVV/ ------------------
# Average es_time: 11.923 ± 4.88 ms (n=100)
# Average queue_time: 1.486 ± 1.466 ms (n=100)
# Average render_time: 61.884 ± 9.484 ms (n=100)
# Average wsgi_time: 131.734 ± 103.533 ms (n=100)
# Average total time: 207.027 ± 105.887 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR688GVV/ -------------------
# Average es_time: 18.782 ± 1.798 ms (n=100)
# Average queue_time: 1.566 ± 1.441 ms (n=100)
# Average render_time: 63.973 ± 8.927 ms (n=100)
# Average wsgi_time: 147.857 ± 116.934 ms (n=100)
# Average total time: 232.178 ± 118.074 ms (n=100)
#
#
# *** item_type: /ENCSR301HAG/
# ------------------ https://www.encodeproject.org/ENCSR301HAG/ ------------------
# Average es_time: 7.675 ± 1.352 ms (n=100)
# Average queue_time: 1.366 ± 1.155 ms (n=100)
# Average render_time: 13.277 ± 3.042 ms (n=100)
# Average wsgi_time: 35.093 ± 4.183 ms (n=100)
# Average total time: 57.411 ± 7.37 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR301HAG/ -------------------
# Average es_time: 15.389 ± 1.783 ms (n=100)
# Average queue_time: 1.325 ± 0.729 ms (n=100)
# Average render_time: 13.945 ± 3.442 ms (n=100)
# Average wsgi_time: 42.537 ± 5.569 ms (n=100)
# Average total time: 73.196 ± 9.433 ms (n=100)
#
#
# *** item_type: /ENCSR315NAC/
# ------------------ https://www.encodeproject.org/ENCSR315NAC/ ------------------
# Average es_time: 10.001 ± 1.621 ms (n=100)
# Average queue_time: 2.527 ± 7.787 ms (n=100)
# Average render_time: 53.277 ± 8.555 ms (n=100)
# Average wsgi_time: 111.238 ± 88.546 ms (n=100)
# Average total time: 177.044 ± 90.085 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR315NAC/ -------------------
# Average es_time: 18.114 ± 3.094 ms (n=100)
# Average queue_time: 1.424 ± 2.066 ms (n=100)
# Average render_time: 52.252 ± 8.753 ms (n=100)
# Average wsgi_time: 106.904 ± 9.87 ms (n=100)
# Average total time: 178.694 ± 19.064 ms (n=100)
#
#
# *** item_type: /ENCSR856JJB/
# ------------------ https://www.encodeproject.org/ENCSR856JJB/ ------------------
# Average es_time: 9.514 ± 1.545 ms (n=100)
# Average queue_time: 1.332 ± 1.005 ms (n=100)
# Average render_time: 44.989 ± 8.13 ms (n=100)
# Average wsgi_time: 97.364 ± 81.806 ms (n=100)
# Average total time: 153.199 ± 84.022 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR856JJB/ -------------------
# Average es_time: 17.277 ± 1.695 ms (n=100)
# Average queue_time: 1.365 ± 0.795 ms (n=100)
# Average render_time: 47.692 ± 9.826 ms (n=100)
# Average wsgi_time: 96.816 ± 10.802 ms (n=100)
# Average total time: 163.15 ± 20.851 ms (n=100)

# %%
#second set of datasets
qa.check_response_time(item_types=['/ENCSR480OHP/','/ENCSR000EMB/','/ENCSR323QIP/','/ENCSR718AXQ/','/ENCSR165BGV/','/ENCSR384KAN/','/ENCSR330FXL/','/ENCSR825UNV/','/ENCSR089EOA/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCSR480OHP/
# ------------------ https://www.encodeproject.org/ENCSR480OHP/ ------------------
# Average es_time: 8.786 ± 1.621 ms (n=100)
# Average queue_time: 1.5 ± 1.077 ms (n=100)
# Average render_time: 31.415 ± 5.098 ms (n=100)
# Average wsgi_time: 65.943 ± 6.608 ms (n=100)
# Average total time: 107.644 ± 11.704 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR480OHP/ -------------------
# Average es_time: 17.992 ± 20.362 ms (n=100)
# Average queue_time: 1.342 ± 1.295 ms (n=100)
# Average render_time: 33.758 ± 7.432 ms (n=100)
# Average wsgi_time: 84.611 ± 76.119 ms (n=100)
# Average total time: 137.703 ± 83.729 ms (n=100)
#
#
# *** item_type: /ENCSR000EMB/
# ------------------ https://www.encodeproject.org/ENCSR000EMB/ ------------------
# Average es_time: 9.648 ± 2.622 ms (n=100)
# Average queue_time: 1.264 ± 0.836 ms (n=100)
# Average render_time: 48.712 ± 6.703 ms (n=100)
# Average wsgi_time: 104.782 ± 88.014 ms (n=100)
# Average total time: 164.405 ± 88.309 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR000EMB/ -------------------
# Average es_time: 16.999 ± 1.781 ms (n=100)
# Average queue_time: 1.442 ± 1.017 ms (n=100)
# Average render_time: 50.798 ± 7.957 ms (n=100)
# Average wsgi_time: 111.147 ± 73.945 ms (n=100)
# Average total time: 180.386 ± 74.783 ms (n=100)
#
#
# *** item_type: /ENCSR323QIP/
# ------------------ https://www.encodeproject.org/ENCSR323QIP/ ------------------
# Average es_time: 19.37 ± 2.984 ms (n=100)
# Average queue_time: 1.559 ± 1.191 ms (n=100)
# Average render_time: 152.342 ± 35.359 ms (n=100)
# Average wsgi_time: 331.002 ± 201.242 ms (n=100)
# Average total time: 504.273 ± 212.212 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR323QIP/ -------------------
# Average es_time: 26.474 ± 4.471 ms (n=100)
# Average queue_time: 1.609 ± 1.994 ms (n=100)
# Average render_time: 152.958 ± 48.328 ms (n=100)
# Average wsgi_time: 322.336 ± 151.318 ms (n=100)
# Average total time: 503.377 ± 176.233 ms (n=100)
#
#
# *** item_type: /ENCSR718AXQ/
# ------------------ https://www.encodeproject.org/ENCSR718AXQ/ ------------------
# Average es_time: 8.117 ± 3.647 ms (n=100)
# Average queue_time: 0.946 ± 0.534 ms (n=100)
# Average render_time: 27.929 ± 45.136 ms (n=100)
# Average wsgi_time: 59.846 ± 79.224 ms (n=100)
# Average total time: 96.838 ± 111.298 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR718AXQ/ -------------------
# Average es_time: 14.511 ± 2.811 ms (n=100)
# Average queue_time: 1.272 ± 0.663 ms (n=100)
# Average render_time: 26.044 ± 9.688 ms (n=100)
# Average wsgi_time: 58.231 ± 11.597 ms (n=100)
# Average total time: 100.057 ± 21.883 ms (n=100)
#
#
# *** item_type: /ENCSR165BGV/
# ------------------ https://www.encodeproject.org/ENCSR165BGV/ ------------------
# Average es_time: 8.314 ± 2.786 ms (n=100)
# Average queue_time: 1.135 ± 0.541 ms (n=100)
# Average render_time: 27.909 ± 5.301 ms (n=100)
# Average wsgi_time: 57.218 ± 7.279 ms (n=100)
# Average total time: 94.576 ± 12.843 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR165BGV/ -------------------
# Average es_time: 15.175 ± 1.771 ms (n=100)
# Average queue_time: 1.221 ± 0.646 ms (n=100)
# Average render_time: 28.202 ± 7.93 ms (n=100)
# Average wsgi_time: 62.726 ± 9.533 ms (n=100)
# Average total time: 107.324 ± 17.555 ms (n=100)
#
#
# *** item_type: /ENCSR384KAN/
# ------------------ https://www.encodeproject.org/ENCSR384KAN/ ------------------
# Average es_time: 10.771 ± 8.275 ms (n=100)
# Average queue_time: 1.143 ± 0.931 ms (n=100)
# Average render_time: 45.273 ± 9.139 ms (n=100)
# Average wsgi_time: 89.195 ± 13.315 ms (n=100)
# Average total time: 146.382 ± 24.663 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR384KAN/ -------------------
# Average es_time: 16.663 ± 2.231 ms (n=100)
# Average queue_time: 1.127 ± 0.611 ms (n=100)
# Average render_time: 52.171 ± 50.006 ms (n=100)
# Average wsgi_time: 102.15 ± 52.02 ms (n=100)
# Average total time: 172.111 ± 102.401 ms (n=100)
#
#
# *** item_type: /ENCSR330FXL/
# ------------------ https://www.encodeproject.org/ENCSR330FXL/ ------------------
# Average es_time: 8.33 ± 1.87 ms (n=100)
# Average queue_time: 1.146 ± 0.722 ms (n=100)
# Average render_time: 31.447 ± 5.437 ms (n=100)
# Average wsgi_time: 62.02 ± 6.416 ms (n=100)
# Average total time: 102.943 ± 11.914 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR330FXL/ -------------------
# Average es_time: 14.251 ± 2.859 ms (n=100)
# Average queue_time: 1.154 ± 0.503 ms (n=100)
# Average render_time: 30.45 ± 6.017 ms (n=100)
# Average wsgi_time: 79.496 ± 89.069 ms (n=100)
# Average total time: 125.351 ± 89.793 ms (n=100)
#
#
# *** item_type: /ENCSR825UNV/
# ------------------ https://www.encodeproject.org/ENCSR825UNV/ ------------------
# Average es_time: 21.575 ± 2.689 ms (n=100)
# Average queue_time: 1.337 ± 1.288 ms (n=100)
# Average render_time: 177.885 ± 10.285 ms (n=100)
# Average wsgi_time: 381.181 ± 184.81 ms (n=100)
# Average total time: 581.978 ± 187.969 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR825UNV/ -------------------
# Average es_time: 27.964 ± 3.959 ms (n=100)
# Average queue_time: 1.152 ± 0.523 ms (n=100)
# Average render_time: 176.969 ± 10.895 ms (n=100)
# Average wsgi_time: 413.006 ± 213.883 ms (n=100)
# Average total time: 619.091 ± 215.833 ms (n=100)
#
#
# *** item_type: /ENCSR089EOA/
# ------------------ https://www.encodeproject.org/ENCSR089EOA/ ------------------
# Average es_time: 14.373 ± 20.356 ms (n=100)
# Average queue_time: 1.226 ± 0.868 ms (n=100)
# Average render_time: 11.934 ± 3.847 ms (n=100)
# Average wsgi_time: 44.993 ± 22.098 ms (n=100)
# Average total time: 72.526 ± 43.501 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCSR089EOA/ -------------------
# Average es_time: 19.391 ± 3.405 ms (n=100)
# Average queue_time: 1.169 ± 0.705 ms (n=100)
# Average render_time: 14.049 ± 4.547 ms (n=100)
# Average wsgi_time: 51.305 ± 6.635 ms (n=100)
# Average total time: 85.914 ± 12.389 ms (n=100)

# %%
#antibodies
qa.check_response_time(item_types=['/ENCAB830JLB/','/ENCAB000BKR/','/ENCAB284TTY/','/ENCAB294YUD/','/ENCAB000AOC/','/ENCAB301QZF/','/ENCAB000ANM/','/ENCAB000ANU/','/ENCAB445KMF/','/ENCAB000BAY/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCAB830JLB/
# ------------------ https://www.encodeproject.org/ENCAB830JLB/ ------------------
# Average es_time: 7.368 ± 1.292 ms (n=100)
# Average queue_time: 1.23 ± 0.926 ms (n=100)
# Average render_time: 24.932 ± 4.662 ms (n=100)
# Average wsgi_time: 49.236 ± 6.558 ms (n=100)
# Average total time: 82.766 ± 11.164 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB830JLB/ -------------------
# Average es_time: 14.072 ± 1.44 ms (n=100)
# Average queue_time: 1.059 ± 0.361 ms (n=100)
# Average render_time: 26.944 ± 4.436 ms (n=100)
# Average wsgi_time: 56.197 ± 5.577 ms (n=100)
# Average total time: 98.272 ± 10.085 ms (n=100)
#
#
# *** item_type: /ENCAB000BKR/
# ------------------ https://www.encodeproject.org/ENCAB000BKR/ ------------------
# Average es_time: 7.352 ± 1.767 ms (n=100)
# Average queue_time: 1.153 ± 0.605 ms (n=100)
# Average render_time: 15.494 ± 3.228 ms (n=100)
# Average wsgi_time: 33.622 ± 4.875 ms (n=100)
# Average total time: 57.62 ± 8.317 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB000BKR/ -------------------
# Average es_time: 12.787 ± 2.231 ms (n=100)
# Average queue_time: 1.004 ± 0.422 ms (n=100)
# Average render_time: 16.69 ± 4.136 ms (n=100)
# Average wsgi_time: 38.918 ± 5.298 ms (n=100)
# Average total time: 69.399 ± 9.954 ms (n=100)
#
#
# *** item_type: /ENCAB284TTY/
# ------------------ https://www.encodeproject.org/ENCAB284TTY/ ------------------
# Average es_time: 7.914 ± 2.847 ms (n=100)
# Average queue_time: 1.25 ± 0.736 ms (n=100)
# Average render_time: 22.476 ± 5.368 ms (n=100)
# Average wsgi_time: 45.33 ± 7.267 ms (n=100)
# Average total time: 76.97 ± 13.048 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB284TTY/ -------------------
# Average es_time: 13.769 ± 3.065 ms (n=100)
# Average queue_time: 1.011 ± 0.301 ms (n=100)
# Average render_time: 20.022 ± 3.528 ms (n=100)
# Average wsgi_time: 47.18 ± 5.608 ms (n=100)
# Average total time: 81.981 ± 10.426 ms (n=100)
#
#
# *** item_type: /ENCAB294YUD/
# ------------------ https://www.encodeproject.org/ENCAB294YUD/ ------------------
# Average es_time: 7.39 ± 1.707 ms (n=100)
# Average queue_time: 1.322 ± 0.91 ms (n=100)
# Average render_time: 10.989 ± 2.504 ms (n=100)
# Average wsgi_time: 27.61 ± 3.86 ms (n=100)
# Average total time: 47.311 ± 6.511 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB294YUD/ -------------------
# Average es_time: 13.507 ± 1.71 ms (n=100)
# Average queue_time: 1.131 ± 0.66 ms (n=100)
# Average render_time: 11.494 ± 2.592 ms (n=100)
# Average wsgi_time: 32.966 ± 3.678 ms (n=100)
# Average total time: 59.097 ± 6.963 ms (n=100)
#
#
# *** item_type: /ENCAB000AOC/
# ------------------ https://www.encodeproject.org/ENCAB000AOC/ ------------------
# Average es_time: 7.751 ± 2.422 ms (n=100)
# Average queue_time: 1.661 ± 1.348 ms (n=100)
# Average render_time: 26.703 ± 6.024 ms (n=100)
# Average wsgi_time: 49.938 ± 7.421 ms (n=100)
# Average total time: 86.053 ± 13.507 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB000AOC/ -------------------
# Average es_time: 13.401 ± 2.056 ms (n=100)
# Average queue_time: 1.076 ± 0.468 ms (n=100)
# Average render_time: 25.381 ± 5.533 ms (n=100)
# Average wsgi_time: 53.08 ± 5.908 ms (n=100)
# Average total time: 92.937 ± 11.661 ms (n=100)
#
#
# *** item_type: /ENCAB301QZF/
# ------------------ https://www.encodeproject.org/ENCAB301QZF/ ------------------
# Average es_time: 7.493 ± 1.394 ms (n=100)
# Average queue_time: 1.417 ± 1.32 ms (n=100)
# Average render_time: 18.511 ± 2.838 ms (n=100)
# Average wsgi_time: 37.645 ± 4.206 ms (n=100)
# Average total time: 65.065 ± 7.214 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB301QZF/ -------------------
# Average es_time: 13.717 ± 1.215 ms (n=100)
# Average queue_time: 0.988 ± 0.273 ms (n=100)
# Average render_time: 18.867 ± 3.689 ms (n=100)
# Average wsgi_time: 42.766 ± 4.319 ms (n=100)
# Average total time: 76.338 ± 8.08 ms (n=100)
#
#
# *** item_type: /ENCAB000ANM/
# ------------------ https://www.encodeproject.org/ENCAB000ANM/ ------------------
# Average es_time: 8.08 ± 4.142 ms (n=100)
# Average queue_time: 1.054 ± 0.613 ms (n=100)
# Average render_time: 20.471 ± 5.327 ms (n=100)
# Average wsgi_time: 39.998 ± 7.658 ms (n=100)
# Average total time: 69.603 ± 14.767 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB000ANM/ -------------------
# Average es_time: 13.001 ± 1.623 ms (n=100)
# Average queue_time: 1.041 ± 0.46 ms (n=100)
# Average render_time: 19.898 ± 3.303 ms (n=100)
# Average wsgi_time: 44.469 ± 4.303 ms (n=100)
# Average total time: 78.409 ± 7.865 ms (n=100)
#
#
# *** item_type: /ENCAB000ANU/
# ------------------ https://www.encodeproject.org/ENCAB000ANU/ ------------------
# Average es_time: 9.007 ± 4.68 ms (n=100)
# Average queue_time: 1.102 ± 0.604 ms (n=100)
# Average render_time: 16.1 ± 3.613 ms (n=100)
# Average wsgi_time: 35.657 ± 6.571 ms (n=100)
# Average total time: 61.866 ± 11.959 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB000ANU/ -------------------
# Average es_time: 13.121 ± 1.761 ms (n=100)
# Average queue_time: 1.04 ± 0.396 ms (n=100)
# Average render_time: 18.206 ± 3.323 ms (n=100)
# Average wsgi_time: 41.21 ± 4.336 ms (n=100)
# Average total time: 73.576 ± 7.961 ms (n=100)
#
#
# *** item_type: /ENCAB445KMF/
# ------------------ https://www.encodeproject.org/ENCAB445KMF/ ------------------
# Average es_time: 6.949 ± 2.284 ms (n=100)
# Average queue_time: 1.061 ± 0.725 ms (n=100)
# Average render_time: 17.893 ± 4.336 ms (n=100)
# Average wsgi_time: 36.454 ± 5.524 ms (n=100)
# Average total time: 62.357 ± 10.182 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB445KMF/ -------------------
# Average es_time: 14.514 ± 6.104 ms (n=100)
# Average queue_time: 0.95 ± 0.393 ms (n=100)
# Average render_time: 18.168 ± 4.376 ms (n=100)
# Average wsgi_time: 43.098 ± 7.987 ms (n=100)
# Average total time: 76.729 ± 15.465 ms (n=100)
#
#
# *** item_type: /ENCAB000BAY/
# ------------------ https://www.encodeproject.org/ENCAB000BAY/ ------------------
# Average es_time: 7.535 ± 2.334 ms (n=100)
# Average queue_time: 1.112 ± 0.61 ms (n=100)
# Average render_time: 24.755 ± 5.626 ms (n=100)
# Average wsgi_time: 46.996 ± 7.054 ms (n=100)
# Average total time: 80.399 ± 13.169 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCAB000BAY/ -------------------
# Average es_time: 13.512 ± 2.332 ms (n=100)
# Average queue_time: 1.045 ± 0.435 ms (n=100)
# Average render_time: 26.97 ± 6.035 ms (n=100)
# Average wsgi_time: 53.725 ± 6.83 ms (n=100)
# Average total time: 95.252 ± 13.288 ms (n=100)

# %%
#biosamples
qa.check_response_time(item_types=['/ENCBS787TFV/','/ENCBS676QAV/','/ENCBS996IWU/','/ENCBS913XJP/','/ENCBS565NTN/','/ENCBS896YZO/','/ENCBS280NYD/'], n=100)
# Out:
# Checking response time
#
# *** item_type: /ENCBS787TFV/
# ------------------ https://www.encodeproject.org/ENCBS787TFV/ ------------------
# Average es_time: 7.522 ± 1.601 ms (n=100)
# Average queue_time: 1.189 ± 0.793 ms (n=100)
# Average render_time: 12.481 ± 2.978 ms (n=100)
# Average wsgi_time: 29.658 ± 4.421 ms (n=100)
# Average total time: 50.85 ± 7.503 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCBS787TFV/ -------------------
# Average es_time: 12.704 ± 1.922 ms (n=100)
# Average queue_time: 0.964 ± 0.352 ms (n=100)
# Average render_time: 11.262 ± 1.959 ms (n=100)
# Average wsgi_time: 32.47 ± 3.235 ms (n=100)
# Average total time: 57.401 ± 5.998 ms (n=100)
#
#
# *** item_type: /ENCBS676QAV/
# ------------------ https://www.encodeproject.org/ENCBS676QAV/ ------------------
# Average es_time: 7.236 ± 1.266 ms (n=100)
# Average queue_time: 1.168 ± 0.735 ms (n=100)
# Average render_time: 12.769 ± 2.578 ms (n=100)
# Average wsgi_time: 29.341 ± 3.971 ms (n=100)
# Average total time: 50.514 ± 6.406 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCBS676QAV/ -------------------
# Average es_time: 13.217 ± 1.78 ms (n=100)
# Average queue_time: 0.995 ± 0.479 ms (n=100)
# Average render_time: 12.389 ± 1.795 ms (n=100)
# Average wsgi_time: 33.614 ± 2.981 ms (n=100)
# Average total time: 60.215 ± 5.377 ms (n=100)
#
#
# *** item_type: /ENCBS996IWU/
# ------------------ https://www.encodeproject.org/ENCBS996IWU/ ------------------
# Average es_time: 7.241 ± 1.666 ms (n=100)
# Average queue_time: 1.423 ± 1.091 ms (n=100)
# Average render_time: 13.702 ± 3.199 ms (n=100)
# Average wsgi_time: 30.543 ± 4.662 ms (n=100)
# Average total time: 52.91 ± 8.054 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCBS996IWU/ -------------------
# Average es_time: 12.913 ± 2.335 ms (n=100)
# Average queue_time: 0.954 ± 0.182 ms (n=100)
# Average render_time: 12.456 ± 2.179 ms (n=100)
# Average wsgi_time: 33.827 ± 4.347 ms (n=100)
# Average total time: 60.15 ± 7.936 ms (n=100)
#
#
# *** item_type: /ENCBS913XJP/
# ------------------ https://www.encodeproject.org/ENCBS913XJP/ ------------------
# Average es_time: 8.74 ± 6.205 ms (n=100)
# Average queue_time: 1.251 ± 0.908 ms (n=100)
# Average render_time: 11.477 ± 2.887 ms (n=100)
# Average wsgi_time: 30.024 ± 7.54 ms (n=100)
# Average total time: 51.491 ± 14.159 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCBS913XJP/ -------------------
# Average es_time: 13.629 ± 0.976 ms (n=100)
# Average queue_time: 0.95 ± 0.303 ms (n=100)
# Average render_time: 10.797 ± 1.471 ms (n=100)
# Average wsgi_time: 32.837 ± 2.581 ms (n=100)
# Average total time: 58.212 ± 4.402 ms (n=100)
#
#
# *** item_type: /ENCBS565NTN/
# ------------------ https://www.encodeproject.org/ENCBS565NTN/ ------------------
# Average es_time: 7.04 ± 4.566 ms (n=100)
# Average queue_time: 1.231 ± 2.053 ms (n=100)
# Average render_time: 11.666 ± 2.939 ms (n=100)
# Average wsgi_time: 26.523 ± 5.991 ms (n=100)
# Average total time: 46.461 ± 11.781 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCBS565NTN/ -------------------
# Average es_time: 12.443 ± 2.753 ms (n=100)
# Average queue_time: 1.026 ± 0.536 ms (n=100)
# Average render_time: 11.849 ± 2.033 ms (n=100)
# Average wsgi_time: 32.599 ± 4.152 ms (n=100)
# Average total time: 57.917 ± 7.778 ms (n=100)
#
#
# *** item_type: /ENCBS896YZO/
# ------------------ https://www.encodeproject.org/ENCBS896YZO/ ------------------
# Average es_time: 7.616 ± 1.589 ms (n=100)
# Average queue_time: 1.554 ± 1.278 ms (n=100)
# Average render_time: 21.364 ± 5.489 ms (n=100)
# Average wsgi_time: 41.706 ± 6.698 ms (n=100)
# Average total time: 72.24 ± 12.277 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCBS896YZO/ -------------------
# Average es_time: 13.316 ± 2.025 ms (n=100)
# Average queue_time: 1.032 ± 0.255 ms (n=100)
# Average render_time: 20.713 ± 4.203 ms (n=100)
# Average wsgi_time: 44.706 ± 5.381 ms (n=100)
# Average total time: 79.768 ± 9.976 ms (n=100)
#
#
# *** item_type: /ENCBS280NYD/
# ------------------ https://www.encodeproject.org/ENCBS280NYD/ ------------------
# Average es_time: 6.976 ± 1.535 ms (n=100)
# Average queue_time: 1.385 ± 1.222 ms (n=100)
# Average render_time: 12.159 ± 2.256 ms (n=100)
# Average wsgi_time: 28.734 ± 4.26 ms (n=100)
# Average total time: 49.255 ± 6.927 ms (n=100)
# ------------------- https://test.encodedcc.org//ENCBS280NYD/ -------------------
# Average es_time: 13.465 ± 1.979 ms (n=100)
# Average queue_time: 1.004 ± 0.349 ms (n=100)
# Average render_time: 12.036 ± 3.053 ms (n=100)
# Average wsgi_time: 34.397 ± 4.546 ms (n=100)
# Average total time: 60.903 ± 8.487 ms (n=100)
